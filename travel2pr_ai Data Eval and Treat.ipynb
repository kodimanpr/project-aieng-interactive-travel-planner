# %%
# Yo ensure that all required libraries were installed correctly

import pandas as pd
import numpy as np
import requests
import langchain
import reportlab
import qrcode
import redis
import celery

# %%
import os
from bs4 import BeautifulSoup

# Define the directory containing the HTML files
data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\data_test"

# %%
# List all files in the directory
files = os.listdir(data_path)
print(f"Found {len(files)} files.")
# Out:
# Found 25 files.

# %%
# Print each filename
print("List of files:")
for idx, file in enumerate(files, start=1):
    print(f"{idx}. {file}")
# Out:
# List of files:
# 1. aguadilla_ice_skating_arena.txt
# 2. arecibo_light.txt
# 3. arecibo_observatory.txt
# 4. baños_de_coamo.txt
# 5. blue_beach_(vieques).txt
# 6. cabo_rojo_national_wildlife_refuge.txt
# 7. café_rico.txt
# 8. caguas_museum_of_tobacco.txt
# 9. casa_de_españa.txt
# 10. castillo_san_cristóbal_(san_juan).txt
# 11. castillo_san_felipe_del_morro.txt
# 12. castillo_san_felipe_del_morro_lighthouse.txt
# 13. cathedral_of_rum.txt
# 14. cayo_icacos.txt
# 15. cerro_las_tetas.txt
# 16. coca-cola_music_hall.txt
# 17. el_yunque_national_forest.txt
# 18. guajataca_lake.txt
# 19. guavate,_cayey,_puerto_rico.txt
# 20. hacienda_buena_vista.txt
# 21. la_fortaleza.txt
# 22. museo_castillo_serrallés.txt
# 23. palmas_del_mar.txt
# 24. plaza_las_américas_(puerto_rico).txt
# 25. roosevelt_roads_naval_station.txt

# %%
# Process the first 3 files to analyze the structure

for file in files[:3]:  # Read only 3 files for initial evaluation
    file_path = os.path.join(data_path, file)
    
    # Read the HTML file
    with open(file_path, "r", encoding="utf-8") as f:
        html_content = f.read()
    
    # Use BeautifulSoup to parse the HTML
    soup = BeautifulSoup(html_content, "html.parser")
    
    # Extract the main text content without HTML tags
    extracted_text = soup.get_text(separator="\n", strip=True)
    
    print(f"\n--- {file} ---\n")
    print(extracted_text[:1000])  # Display only the first 1000 characters
    print("\n" + "-" * 50)
# Out:
# --- aguadilla_ice_skating_arena.txt ---
#
# b'
# \n
# \n
# \n
# \n
# Aguadilla Ice Skating Arena - Wikipedia
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# Jump to content
# \n
# \n\t
# \n\t\t
# \n\t\t\t
# \n\t\t\t\t\n
# \n\t
# \n\t
# \n\n
# Main menu
# \n\t
# \n\t
# \n\n\n\t\t\t\t
# \n\t\t\n
# \n\t
# \n\t
# Main menu
# \n\t
# move to sidebar
# \n\t
# hide
# \n
# \n\n\t\n
# \n\t
# \n\t\tNavigation\n\t
# \n\t
# \n\t\t\n\t\t
# \n\t\t\t\n\t\t\t
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# \n\t\t
# \n\t\t\n\t
# \n
# \n\n\t\n\t\n
# \n\t
# \n\t\tContribute\n\t
# \n\t
# \n\t\t\n\t\t
# \n\t\t\t\n\t\t\t
# Help
# Learn to edit
# Community portal
# Recent changes
# Upload file
# \n\t\t
# \n\t\t\n\t
# \n
# \n\n
# \n\n\t\t\t\t
# \n\n\t
# \n
# \n\n\t\t
# \n\t\t\t\n
# \n\t
# \n\t
# \n\t\t
# \n\t\t
# \n\t
# \n
# \n\n\t\t
# \n\t\t
# \n\t\t\t\n
# \n\t
# \n\n
# Search
# \n\t
# \n\t
# \n\t\t
# \n\t\t\t
# \n\t\t\t\t
# \n\t\t\t\t\t
# \n\t\t\t\t\t\t
# \n\t\t\t\t\t\t
# \n\t\t\t\t\t
# \n\t\t\t\t\t
# \n\t\t\t\t
# \n\t\t\t\t
# Search
# \n\t\t\t
# \n\t\t
# \n\t
# \n
# \n\n\t\t\t
# \n\t
# \n\t\n
# \n\t
# \n\t\t\n\t\t
# \n\t\t\t\n\t\t\t\n\t\t
#
# --------------------------------------------------
#
# --- arecibo_light.txt ---
#
# b'
# \n
# \n
# \n
# \n
# Arecibo Light - Wikipedia
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# Jump to content
# \n
# \n\t
# \n\t\t
# \n\t\t\t
# \n\t\t\t\t\n
# \n\t
# \n\t
# \n\n
# Main menu
# \n\t
# \n\t
# \n\n\n\t\t\t\t
# \n\t\t\n
# \n\t
# \n\t
# Main menu
# \n\t
# move to sidebar
# \n\t
# hide
# \n
# \n\n\t\n
# \n\t
# \n\t\tNavigation\n\t
# \n\t
# \n\t\t\n\t\t
# \n\t\t\t\n\t\t\t
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# \n\t\t
# \n\t\t\n\t
# \n
# \n\n\t\n\t\n
# \n\t
# \n\t\tContribute\n\t
# \n\t
# \n\t\t\n\t\t
# \n\t\t\t\n\t\t\t
# Help
# Learn to edit
# Community portal
# Recent changes
# Upload file
# \n\t\t
# \n\t\t\n\t
# \n
# \n\n
# \n\n\t\t\t\t
# \n\n\t
# \n
# \n\n\t\t
# \n\t\t\t\n
# \n\t
# \n\t
# \n\t\t
# \n\t\t
# \n\t
# \n
# \n\n\t\t
# \n\t\t
# \n\t\t\t\n
# \n\t
# \n\n
# Search
# \n\t
# \n\t
# \n\t\t
# \n\t\t\t
# \n\t\t\t\t
# \n\t\t\t\t\t
# \n\t\t\t\t\t\t
# \n\t\t\t\t\t\t
# \n\t\t\t\t\t
# \n\t\t\t\t\t
# \n\t\t\t\t
# \n\t\t\t\t
# Search
# \n\t\t\t
# \n\t\t
# \n\t
# \n
# \n\n\t\t\t
# \n\t
# \n\t\n
# \n\t
# \n\t\t\n\t\t
# \n\t\t\t\n\t\t\t\n\t\t
# \n\t\t\n\t
#
# --------------------------------------------------
#
# --- arecibo_observatory.txt ---
#
# b'
# \n
# \n
# \n
# \n
# Arecibo Observatory - Wikipedia
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# \n
# Jump to content
# \n
# \n\t
# \n\t\t
# \n\t\t\t
# \n\t\t\t\t\n
# \n\t
# \n\t
# \n\n
# Main menu
# \n\t
# \n\t
# \n\n\n\t\t\t\t
# \n\t\t\n
# \n\t
# \n\t
# Main menu
# \n\t
# move to sidebar
# \n\t
# hide
# \n
# \n\n\t\n
# \n\t
# \n\t\tNavigation\n\t
# \n\t
# \n\t\t\n\t\t
# \n\t\t\t\n\t\t\t
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# \n\t\t
# \n\t\t\n\t
# \n
# \n\n\t\n\t\n
# \n\t
# \n\t\tContribute\n\t
# \n\t
# \n\t\t\n\t\t
# \n\t\t\t\n\t\t\t
# Help
# Learn to edit
# Community portal
# Recent changes
# Upload file
# \n\t\t
# \n\t\t\n\t
# \n
# \n\n
# \n\n\t\t\t\t
# \n\n\t
# \n
# \n\n\t\t
# \n\t\t\t\n
# \n\t
# \n\t
# \n\t\t
# \n\t\t
# \n\t
# \n
# \n\n\t\t
# \n\t\t
# \n\t\t\t\n
# \n\t
# \n\n
# Search
# \n\t
# \n\t
# \n\t\t
# \n\t\t\t
# \n\t\t\t\t
# \n\t\t\t\t\t
# \n\t\t\t\t\t\t
# \n\t\t\t\t\t\t
# \n\t\t\t\t\t
# \n\t\t\t\t\t
# \n\t\t\t\t
# \n\t\t\t\t
# Search
# \n\t\t\t
# \n\t\t
# \n\t
# \n
# \n\n\t\t\t
# \n\t
# \n\t\n
# \n\t
# \n\t\t\n\t\t
# \n\t\t\t\n\t\t\t\n\t\t
# \n\t
#
# --------------------------------------------------

# %% [markdown]
# # **Cleaning Test No. 01 - Relevant content extracted but relevant links were eliminated**
# import os
# from bs4 import BeautifulSoup
#
# # Define the directories
# data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\data_test"
# output_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\cleaned_data"
#
# # Create output directory if it doesn't exist
# if not os.path.exists(output_path):
#     os.makedirs(output_path)
#
# # Function to clean and extract meaningful content
# def clean_html(file_path):
#     with open(file_path, "r", encoding="utf-8") as f:
#         html_content = f.read()
#
#     # Parse the HTML content with BeautifulSoup
#     soup = BeautifulSoup(html_content, "html.parser")
#
#     # Extract text from relevant tags (e.g., <p>, <h1>, <h2>)
#     paragraphs = soup.find_all(['h1', 'h2', 'p'])
#
#     # Combine and clean extracted text
#     cleaned_text = "\n".join([para.get_text(strip=True) for para in paragraphs])
#     return cleaned_text
#
# # Process and save cleaned content
# for file in os.listdir(data_path):
#     file_path = os.path.join(data_path, file)
#     cleaned_content = clean_html(file_path)
#
#     # Save cleaned content to a new file
#     output_file_path = os.path.join(output_path, file)
#     with open(output_file_path, "w", encoding="utf-8") as out_file:
#         out_file.write(cleaned_content)
#
#     print(f"Cleaned and saved: {file}")

# %%
# **Cleaning Test No. 02 - Relevant content extracted and relevant links were include but it was found that geolocation info were eliminated**
import os
import requests
from bs4 import BeautifulSoup

# Define the directories
data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\data_test"
output_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\cleaned_data"

# Create output directory if it doesn't exist
if not os.path.exists(output_path):
    os.makedirs(output_path)

# Function to validate links
def validate_link(url):
    try:
        response = requests.head(url, timeout=5)  # Perform a HEAD request
        return response.status_code == 200
    except requests.RequestException:
        return False

# Function to clean and extract meaningful content and links
def clean_html(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        html_content = f.read()
    
    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(html_content, "html.parser")
    
    # Extract text from relevant tags (e.g., <p>, <h1>, <h2>)
    paragraphs = soup.find_all(['h1', 'h2', 'p'])
    cleaned_text = "\n".join([para.get_text(strip=True) for para in paragraphs])
    
    # Extract and validate hyperlinks
    links = [a['href'] for a in soup.find_all('a', href=True)]
    valid_links = [link for link in links if validate_link(link)]
    
    # Combine content and validated links in structured format
    combined_content = f"Main Content:\n{cleaned_text}\n\nRelevant Links:\n{valid_links}"
    return combined_content

# Process and save cleaned content
for file in os.listdir(data_path):
    file_path = os.path.join(data_path, file)
    cleaned_content = clean_html(file_path)
    
    # Save combined content (cleaned text + links) to a new file
    output_file_path = os.path.join(output_path, file)
    with open(output_file_path, "w", encoding="utf-8") as out_file:
        out_file.write(cleaned_content)
    
    print(f"Cleaned and saved: {file}")

# %% [markdown]
# # **Defining and testing geo_metadata ectracion process**

# %%
import re
import json

# Define the path to the single test file
test_file_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\data_test\arecibo_light.txt"
geo_extract_output = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\geo_extract_test.txt"

# Function to extract geospatial metadata without strict JSON parsing
def extract_geo_metadata_loose(content):
    geo_metadata = {}
    
    # Find coordinates
    coordinates_pattern = r'"coordinates":\s*\[.*?\]'
    coordinates_match = re.search(coordinates_pattern, content)
    if coordinates_match:
        try:
            # Extract and parse the coordinates
            coordinates = json.loads(coordinates_match.group(0).split(":")[1].strip())
            geo_metadata["coordinates"] = coordinates
        except json.JSONDecodeError:
            geo_metadata["coordinates"] = "Invalid format"

    # Find title
    title_pattern = r'"title":\s*".*?"'
    title_match = re.search(title_pattern, content)
    if title_match:
        geo_metadata["title"] = title_match.group(0).split(":")[1].strip().strip('"')

    # Find marker type
    marker_pattern = r'"marker-symbol":\s*".*?"'
    marker_match = re.search(marker_pattern, content)
    if marker_match:
        geo_metadata["type"] = marker_match.group(0).split(":")[1].strip().strip('"')

    return geo_metadata

# Read the test file and extract geo metadata
with open(test_file_path, "r", encoding="utf-8") as f:
    raw_content = f.read()

# Apply the extraction function
geo_metadata = extract_geo_metadata_loose(raw_content)

# Save the extracted metadata to a test file
with open(geo_extract_output, "w", encoding="utf-8") as out_file:
    out_file.write(json.dumps(geo_metadata, indent=4))

print(f"Geo metadata extracted and saved to: {geo_extract_output}")
print("Extracted Geo Metadata:", geo_metadata)
# Out:
# Geo metadata extracted and saved to: C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\geo_extract_test.txt
# Extracted Geo Metadata: {'coordinates': [-66.69870416666667, 18.481965555555554], 'title': 'Arecibo Light', 'type': 'lighthouse'}

# %% [markdown]
# # **Cleaning Test No. 03 - Relevant content extracted, including relevant links and geolocation info.**

# %%
import os
import json
import re
import requests
from bs4 import BeautifulSoup

# Define the directories
data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\data_test"
output_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\cleaned_data"

# Create output directory if it doesn't exist
if not os.path.exists(output_path):
    os.makedirs(output_path)

# Function to validate links
def validate_link(url):
    try:
        response = requests.head(url, timeout=5)
        return response.status_code == 200
    except requests.RequestException:
        return False

# Function to extract geospatial metadata without strict JSON parsing
def extract_geo_metadata_loose(content):
    geo_metadata = {}
    
    # Find coordinates
    coordinates_pattern = r'"coordinates":\s*\[.*?\]'
    coordinates_match = re.search(coordinates_pattern, content)
    if coordinates_match:
        try:
            coordinates = json.loads(coordinates_match.group(0).split(":")[1].strip())
            geo_metadata["coordinates"] = coordinates
        except json.JSONDecodeError:
            geo_metadata["coordinates"] = "Invalid format"

    # Find title
    title_pattern = r'"title":\s*".*?"'
    title_match = re.search(title_pattern, content)
    if title_match:
        geo_metadata["title"] = title_match.group(0).split(":")[1].strip().strip('"')

    # Find marker type
    marker_pattern = r'"marker-symbol":\s*".*?"'
    marker_match = re.search(marker_pattern, content)
    if marker_match:
        geo_metadata["type"] = marker_match.group(0).split(":")[1].strip().strip('"')

    return geo_metadata if geo_metadata else None

# Function to clean and extract meaningful content, links, and geospatial data
def clean_html(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        raw_content = f.read()
    
    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(raw_content, "html.parser")
    
    # Extract text from relevant tags (e.g., <p>, <h1>, <h2>)
    paragraphs = soup.find_all(['h1', 'h2', 'p'])
    cleaned_text = "\n".join([para.get_text(strip=True) for para in paragraphs])
    
    # Extract hyperlinks
    links = [a['href'] for a in soup.find_all('a', href=True)]
    valid_links = [link for link in links if validate_link(link)]
    
    # Extract geospatial metadata
    geo_metadata = extract_geo_metadata_loose(raw_content)
    
    # Combine all data
    combined_content = {
        "main_content": cleaned_text,
        "relevant_links": valid_links,
        "geo_metadata": geo_metadata
    }
    return combined_content

# Process and save cleaned content
for file in os.listdir(data_path):
    file_path = os.path.join(data_path, file)
    cleaned_data = clean_html(file_path)
    
    # Save combined content to a new file
    output_file_path = os.path.join(output_path, file)
    with open(output_file_path, "w", encoding="utf-8") as out_file:
        out_file.write(json.dumps(cleaned_data, indent=4))
    
    print(f"Cleaned and saved: {file}")

# %%
# !pip install ftfy
# Out:
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: wcwidth in c:\users\larry\anaconda3\envs\travel2pr_ai\lib\site-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1

# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8

# %% [markdown]
# # **Cleaning Test No. 04 - Testing for special characters handling**
# # Define the directories
# cleaned_data_path = r"C:\\Users\\larry\\OneDrive\\Documents\\GitHub\\project-aieng-interactive-travel-planner\\data\\landmarks\\cleaned_data"
# final_output_path = r"C:\\Users\\larry\\OneDrive\\Documents\\GitHub\\project-aieng-interactive-travel-planner\\data\\landmarks\\final_data"
#
# # Create final output directory if it doesn't exist
# if not os.path.exists(final_output_path):
#     os.makedirs(final_output_path)
#
# # Define special character replacements
# special_chars_mapping = {
#     "\\xc3\\xa1": "á",
#     "\\xc3\\xa9": "é",
#     "\\xc3\\xad": "í",
#     "\\xc3\\xb3": "ó",
#     "\\xc3\\xba": "ú",
#     "\\xc3\\xb1": "ñ",
#     "\\xc3\\x9c": "Ü",
#     "\\xc3\\xbc": "ü",
#     "\\xe2\\x80\\x99": "'",
#     "\\xe2\\x80\\x9c": "\"",
#     "\\xe2\\x80\\x9d": "\""
# }
#
# # Function to replace special characters
# def fix_special_characters(text):
#     for wrong, correct in special_chars_mapping.items():
#         text = text.replace(wrong, correct)
#     return text
#
# # Process files to apply character mapping
# for file in os.listdir(cleaned_data_path):
#     file_path = os.path.join(cleaned_data_path, file)
#     with open(file_path, "r", encoding="utf-8") as f:
#         content = f.read()
#         cleaned_content = fix_special_characters(content)
#
#     # Save the updated file
#     final_file_path = os.path.join(final_output_path, file)
#     with open(final_file_path, "w", encoding="utf-8") as out_file:
#         out_file.write(cleaned_content)
#
#     print(f"Processed special characters for: {file}")

# %% [markdown]
# # **Step 1: Removal of html codes, manage spaces issues, management of geo_metadata and special characters handling**

# %%
import os
import json
import re
import requests
from bs4 import BeautifulSoup

# Define the directories
data_path = r"C:\\Users\\larry\\OneDrive\\Documents\\GitHub\\project-aieng-interactive-travel-planner\\data\\landmarks"#\\data_test"
output_path = r"C:\\Users\\larry\\OneDrive\\Documents\\GitHub\\project-aieng-interactive-travel-planner\\data\\landmarks_cleanng\\step1_cleaned_data"

# Create output directory if it doesn't exist
if not os.path.exists(output_path):
    os.makedirs(output_path)

# Step 1: Define Mapping
special_chars_mapping = {
    "\\xc3\\xa1": "á",
    "\\xc3\\xa9": "é",
    "\\xc3\\xad": "í",
    "\\xc3\\xb3": "ó",
    "\\xc3\\xba": "ú",
    "\\xc3\\xb1": "ñ",
    "\\xc3\\x9c": "Ü",
    "\\xc3\\xbc": "ü",
    "\\xe2\\x80\\x99": "'",
    "\\xe2\\x80\\x9c": "\"",
    "\\xe2\\x80\\x9d": "\""
}

# Step 2: Function for Fixing Special Characters
def fix_special_characters(text):
    for wrong, correct in special_chars_mapping.items():
        text = text.replace(wrong, correct)
    return text

# Step 3: Clean Function
def clean_html(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        raw_content = f.read()

    # Parse with BeautifulSoup
    soup = BeautifulSoup(raw_content, "html.parser")

    # Insert space after <a> tags and remove duplicates
    for a in soup.find_all("a"):
        a.insert_after(" ")

    # Extract text
    paragraphs = soup.find_all(['h1', 'h2', 'p'])
    cleaned_text = "\n".join([para.get_text(" ", strip=True) for para in paragraphs])
    
    # Apply character replacement
    cleaned_text = fix_special_characters(cleaned_text)

    # Extract links and validate
    links = list(set([a['href'] for a in soup.find_all('a', href=True)]))

    # Extract geo metadata
    geo_metadata = extract_geo_metadata_loose(raw_content)

    # Combine all data
    return {
        "main_content": cleaned_text,
        "relevant_links": links,
        "geo_metadata": geo_metadata
    }

# Apply to All Files
for file in os.listdir(data_path):
    file_path = os.path.join(data_path, file)
    cleaned_data = clean_html(file_path)
    output_file_path = os.path.join(output_path, file)

    with open(output_file_path, "w", encoding="utf-8") as out_file:
        json.dump(cleaned_data, out_file, indent=4, ensure_ascii=False)

    print(f"Processed: {file}")
# Out:
# Processed: academia_del_perpetuo_socorro.txt
# Processed: academia_interamericana_metro.txt
# Processed: academia_maria_reina.txt
# Processed: academia_san_jorge.txt
# Processed: adjuntas_barrio-pueblo.txt
# Processed: aguada_barrio-pueblo.txt
# Processed: aguada_transmission_station.txt
# Processed: aguadilla_barrio-pueblo.txt
# Processed: aguadilla_ice_skating_arena.txt
# Processed: aguas_buenas_barrio-pueblo.txt
# Processed: aguas_buenas_cave_system.txt
# Processed: aguirre_state_forest.txt
# Processed: aibonito_barrio-pueblo.txt
# Processed: aibonito_festival_of_flowers.txt
# Processed: albergue_olímpico.txt
# Processed: albizu_university.txt
# Processed: ana_g._méndez_university.txt
# Processed: antiguo_casino_de_ponce.txt
# Processed: antiguo_cuartel_militar_español_de_ponce.txt
# Processed: antiguo_hospital_militar_español_de_ponce.txt
# Processed: archivo_general_de_puerto_rico.txt
# Processed: arecibo_barrio-pueblo.txt
# Processed: arecibo_light.txt
# Processed: arecibo_observatory.txt
# Processed: arecibo_telescope.txt
# Processed: arenas_bridge.txt
# Processed: arroyo_barrio-pueblo.txt
# Processed: asilo_de_pobres.txt
# Processed: ateneo_puertorriqueño.txt
# Processed: auditorio_juan_pachín_vicéns.txt
# Processed: añasco_barrio-pueblo.txt
# Processed: bacardi.txt
# Processed: bahía_de_jobos.txt
# Processed: ballajá_barracks.txt
# Processed: balneario_de_rincón.txt
# Processed: banco_crédito_y_ahorro_ponceño_(building).txt
# Processed: banco_de_ponce_(building).txt
# Processed: barceloneta_barrio-pueblo.txt
# Processed: barranquitas_barrio-pueblo.txt
# Processed: basílica_menor_de_la_virgen_de_monserrate.txt
# Processed: bayamón_barrio-pueblo.txt
# Processed: bayamón_city_hall.txt
# Processed: bayamón_river.txt
# Processed: baños_de_coamo.txt
# Processed: biblical_magi.txt
# Processed: biblioteca_carnegie.txt
# Processed: biblioteca_municipal_de_ponce.txt
# Processed: birth_of_the_new_world.txt
# Processed: black_sand.txt
# Processed: blue_beach_(vieques).txt
# Processed: bobbin_lace.txt
# Processed: bolera_caribe.txt
# Processed: boquerón,_cabo_rojo,_puerto_rico.txt
# Processed: boquerón_state_forest.txt
# Processed: braulio_castillo.txt
# Processed: buyé_beach.txt
# Processed: cabo_rojo_barrio-pueblo.txt
# Processed: cabo_rojo_national_wildlife_refuge.txt
# Processed: café_rico.txt
# Processed: caguana_ceremonial_ball_courts_site.txt
# Processed: caguas_barrio-pueblo.txt
# Processed: caguas_city_hall.txt
# Processed: caguas_museum_of_art.txt
# Processed: caguas_museum_of_folk_arts.txt
# Processed: caguas_museum_of_tobacco.txt
# Processed: caguas_valley.txt
# Processed: caja_de_muertos.txt
# Processed: calle_25_de_enero.txt
# Processed: cambalache_forest_reserve.txt
# Processed: campamento_santiago.txt
# Processed: campo_atlético_charles_h._terry.txt
# Processed: camuy_barrio-pueblo.txt
# Processed: camuy_river.txt
# Processed: canóvanas_barrio-pueblo.txt
# Processed: caparra_archaeological_site.txt
# Processed: cape_san_juan_light.txt
# Processed: capilla_del_cristo.txt
# Processed: capitol_of_puerto_rico.txt
# Processed: caracas_beach_(vieques).txt
# Processed: cardona_(ponce).txt
# Processed: cardona_residence.txt
# Processed: caribe_hilton_hotel.txt
# Processed: carite_lake.txt
# Processed: carite_state_forest.txt
# Processed: carolina_barrio-pueblo.txt
# Processed: carraízo_dam.txt
# Processed: casa_alonso.txt
# Processed: casa_blanca_(san_juan).txt
# Processed: casa_cautiño.txt
# Processed: casa_del_rey.txt
# Processed: casa_de_españa.txt
# Processed: casa_dra._concha_melendez_ramirez.txt
# Processed: casa_fernando_luis_toro.txt
# Processed: casa_font-ubides.txt
# Processed: casa_franceschi_antongiorgi.txt
# Processed: casa_natal_de_luis_muñoz_rivera.txt
# Processed: casa_nemesio_canales.txt
# Processed: casa_oppenheimer.txt
# Processed: casa_paoli.txt
# Processed: casa_pueblo_puerto_rico.txt
# Processed: casa_roig_museum.txt
# Processed: casa_rosa.txt
# Processed: casa_rosita_serrallés.txt
# Processed: casa_salazar-candal.txt
# Processed: casa_serralles.txt
# Processed: casa_wiechers-villaronga.txt
# Processed: casona_césari.txt
# Processed: castillo_san_cristóbal_(san_juan).txt
# Processed: castillo_san_felipe_del_morro.txt
# Processed: castillo_san_felipe_del_morro_lighthouse.txt
# Processed: castillo_serrallés.txt
# Processed: cataño_barrio-pueblo.txt
# Processed: catedral_de_nuestra_señora_de_guadalupe.txt
# Processed: catedral_de_san_felipe_apóstol_(arecibo,_puerto_rico).txt
# Processed: catedral_dulce_nombre_de_jesús_(caguas,_puerto_rico).txt
# Processed: catedral_metropolitana_basílica_de_san_juan_bautista_(san_juan,_puerto_rico).txt
# Processed: cathedral_of_rum.txt
# Processed: cayey_barrio-pueblo.txt
# Processed: cayos_de_caña_gorda.txt
# Processed: cayo_icacos.txt
# Processed: cayo_luis_peña.txt
# Processed: caño_tiburones.txt
# Processed: ceiba_barrio-pueblo.txt
# Processed: cementerio_católico_san_vicente_de_paul.txt
# Processed: cementerio_civil_de_ponce.txt
# Processed: center_for_advanced_studies_on_puerto_rico_and_the_caribbean.txt
# Processed: central_aguirre_historic_district.txt
# Processed: central_cortada.txt
# Processed: central_guánica.txt
# Processed: central_high_school_(san_juan,_puerto_rico).txt
# Processed: centro_ceremonial_indígena_de_tibes.txt
# Processed: centro_cultural_baudilio_vega_berríos.txt
# Processed: centro_cultural_de_ponce_carmen_solá_de_pereira.txt
# Processed: centro_del_sur_mall.txt
# Processed: centro_de_convenciones_de_ponce.txt
# Processed: cerrillos_state_forest.txt
# Processed: cerro_de_punta.txt
# Processed: cerro_las_tetas.txt
# Processed: cerro_maravilla.txt
# Processed: cerro_morales_(utuado,_puerto_rico).txt
# Processed: cerro_rosa.txt
# Processed: cervecería_india.txt
# Processed: chalet_amill.txt
# Processed: christopher_columbus.txt
# Processed: church_of_saint_francis_of_assisi,_san_juan.txt
# Processed: church_of_san_francisco_de_asís.txt
# Processed: church_of_san_mateo_de_cangrejos_of_santurce.txt
# Processed: church_san_blas_de_illescas_of_coamo.txt
# Processed: church_san_josé_of_aibonito.txt
# Processed: church_san_miguel_arcángel_of_utuado.txt
# Processed: ciales_barrio-pueblo.txt
# Processed: cidra_barrio-pueblo.txt
# Processed: ciudad_deportiva_millito_navarro.txt
# Processed: club_deportivo_del_oeste.txt
# Processed: club_nautico_de_ponce.txt
# Processed: club_náutico_de_ponce.txt
# Processed: coamo_barrio-pueblo.txt
# Processed: coca-cola_music_hall.txt
# Processed: colegio_ponceño.txt
# Processed: colegio_san_conrado.txt
# Processed: coliseo_manuel_iguina.txt
# Processed: coliseo_rubén_rodríguez.txt
# Processed: coloso_sugar_cane_refinery.txt
# Processed: comerío_barrio-pueblo.txt
# Processed: complejo_recreativo_y_cultural_la_guancha.txt
# Processed: concatedral_dulce_nombre_de_jesús_(humacao,_puerto_rico).txt
# Processed: condado_(santurce).txt
# Processed: condado_lagoon.txt
# Processed: condado_vanderbilt_hotel.txt
# Processed: conservatory_of_music_of_puerto_rico.txt
# Processed: corozal_barrio-pueblo.txt
# Processed: couroupita_nicaraguarensis.txt
# Processed: crash_boat_beach.txt
# Processed: cruceta_del_vigía.txt
# Processed: cuevas_las_cabachuelas.txt
# Processed: cueva_del_indio_(arecibo).txt
# Processed: cueva_del_indio_(las_piedras).txt
# Processed: cueva_lucero.txt
# Processed: cueva_ventana.txt
# Processed: culebra_barrio-pueblo.txt
# Processed: culebra_national_wildlife_refuge.txt
# Processed: culebrita.txt
# Processed: dead_dog_beach.txt
# Processed: desecheo_national_wildlife_refuge.txt
# Processed: destilería_serrallés.txt
# Processed: district_courthouse_(aguadilla,_puerto_rico).txt
# Processed: domes_beach.txt
# Processed: dorado_barrio-pueblo.txt
# Processed: dos_bocas_lake.txt
# Processed: dos_hermanos_bridge.txt
# Processed: dr._juan_a._rivero_zoo.txt
# Processed: edificio_aboy.txt
# Processed: edificio_comunidad_de_orgullo_gay_de_puerto_rico.txt
# Processed: edificio_del_valle.txt
# Processed: edificio_josé_de_diego.txt
# Processed: edificio_oliver.txt
# Processed: edificio_patio_español.txt
# Processed: edificio_victory_garden.txt
# Processed: el_falansterio_de_puerta_de_tierra.txt
# Processed: el_gigante_dormido.txt
# Processed: el_monumento_de_la_recordación.txt
# Processed: el_parterre.txt
# Processed: el_toro_wilderness.txt
# Processed: el_tuque.txt
# Processed: el_yunque_national_forest.txt
# Processed: enrique_laguerre.txt
# Processed: ensenada_honda_(culebra,_puerto_rico).txt
# Processed: episcopal_cathedral_of_st._john_the_baptist_(san_juan,_puerto_rico).txt
# Processed: ermita_nuestra_señora_de_la_valvanera.txt
# Processed: escuela_brambaugh.txt
# Processed: escuela_de_artes_plásticas_y_diseño_de_puerto_rico.txt
# Processed: esperanza_beach.txt
# Processed: estadio_country_club.txt
# Processed: estadio_francisco_montaner.txt
# Processed: estadio_sixto_escobar.txt
# Processed: fajardo_barrio-pueblo.txt
# Processed: farmers'_market.txt
# Processed: faro_del_puerto_de_ponce.txt
# Processed: faro_de_la_isla_de_caja_de_muertos.txt
# Processed: filardi_house.txt
# Processed: flamenco_beach.txt
# Processed: florida,_puerto_rico.txt
# Processed: fort_buchanan,_puerto_rico.txt
# Processed: fortín_de_san_gerónimo.txt
# Processed: fortín_san_antonio.txt
# Processed: fortín_san_juan_de_la_cruz.txt
# Processed: francisco_oller.txt
# Processed: fuerte_de_la_concepción.txt
# Processed: fuerte_de_vieques.txt
# Processed: galería_nacional.txt
# Processed: gatas_(ponce).txt
# Processed: general_norzagaray_bridge.txt
# Processed: general_store.txt
# Processed: guajataca_lake.txt
# Processed: guajataca_state_forest.txt
# Processed: guajataca_tunnel.txt
# Processed: guavate,_cayey,_puerto_rico.txt
# Processed: guayama_barrio-pueblo.txt
# Processed: guayanilla_barrio-pueblo.txt
# Processed: guaynabo_barrio-pueblo.txt
# Processed: guilarte_state_forest.txt
# Processed: gurabo_barrio-pueblo.txt
# Processed: guánica_barrio-pueblo.txt
# Processed: guánica_light.txt
# Processed: guánica_state_forest.txt
# Processed: gómez_residence.txt
# Processed: hacienda_azucarera_la_esperanza.txt
# Processed: hacienda_buena_vista.txt
# Processed: hacienda_el_jibarito.txt
# Processed: hacienda_juanita.txt
# Processed: hacienda_lealtad.txt
# Processed: hacienda_santa_rita.txt
# Processed: hacienda_san_francisco.txt
# Processed: hatillo_barrio-pueblo.txt
# Processed: henry_klumb_house.txt
# Processed: hermitage_of_san_antonio_de_padua_de_la_tuna.txt
# Processed: hipódromo_camarero.txt
# Processed: hiram_bithorn_stadium.txt
# Processed: hormigueros_barrio-pueblo.txt
# Processed: horse_racing.txt
# Processed: hotel_el_convento.txt
# Processed: hotel_melia.txt
# Processed: hotel_ponce_intercontinental.txt
# Processed: hotel_ponce_ramada.txt
# Processed: house_at_659_concordia_street.txt
# Processed: house_at_659_la_paz_street.txt
# Processed: house_at_663_la_paz_street.txt
# Processed: house_at_665_mckinley_street.txt
# Processed: humacao_barrio-pueblo.txt
# Processed: humacao_nature_reserve.txt
# Processed: húcares.txt
# Processed: iglesia_de_la_santísima_trinidad.txt
# Processed: iglesia_de_nuestra_señora_del_carmen.txt
# Processed: iglesia_de_san_antonio_de_padua.txt
# Processed: iglesia_san_germán_de_auxerre.txt
# Processed: iglesia_san_sebastián_mártir.txt
# Processed: industrias_vassallo.txt
# Processed: institute_of_puerto_rican_culture.txt
# Processed: interamerican_university_of_puerto_rico.txt
# Processed: interamerican_university_of_puerto_rico_at_ponce.txt
# Processed: isabela_barrio-pueblo.txt
# Processed: isabel_ii_barrio-pueblo.txt
# Processed: isla_del_frío.txt
# Processed: isla_de_cabras.txt
# Processed: isla_de_jueyes.txt
# Processed: isla_de_mona.txt
# Processed: isla_de_ratones_(cabo_rojo,_puerto_rico).txt
# Processed: isla_de_ratones_(ponce,_puerto_rico).txt
# Processed: isla_magueyes.txt
# Processed: isla_mata_la_gata.txt
# Processed: isla_palomino.txt
# Processed: isla_verde,_puerto_rico.txt
# Processed: jayuya_barrio-pueblo.txt
# Processed: jesús_izcoa_moure_bridge.txt
# Processed: jesús_t._piñero_house.txt
# Processed: jobos_beach.txt
# Processed: jose_v._toledo_federal_building_and_united_states_courthouse.txt
# Processed: josé_celso_barbosa.txt
# Processed: josé_miguel_agrelot_coliseum.txt
# Processed: joyuda,_puerto_rico.txt
# Processed: joyuda_lagoon.txt
# Processed: juana_díaz_barrio-pueblo.txt
# Processed: juan_boria.txt
# Processed: juan_ramón_loubriel_stadium.txt
# Processed: julia_de_burgos.txt
# Processed: julio_enrique_monagas_park.txt
# Processed: juncos_barrio-pueblo.txt
# Processed: lago_dos_bocas.txt
# Processed: laguna_cartagena_national_wildlife_refuge.txt
# Processed: lajas_barrio-pueblo.txt
# Processed: lake_luchetti.txt
# Processed: lares_barrio-pueblo.txt
# Processed: lares_ice_cream_parlor.txt
# Processed: las_cabañas_bridge.txt
# Processed: las_cascadas_water_park.txt
# Processed: las_catalinas_mall.txt
# Processed: las_marías_barrio-pueblo.txt
# Processed: las_piedras_barrio-pueblo.txt
# Processed: la_bombonera_(san_juan).txt
# Processed: la_concha_renaissance_san_juan_resort.txt
# Processed: la_cordillera_reef_nature_reserve.txt
# Processed: la_fortaleza.txt
# Processed: la_giralda_(san_juan,_puerto_rico).txt
# Processed: la_guancha_(ponce,_puerto_rico).txt
# Processed: la_liendre_bridge.txt
# Processed: la_mallorquina.txt
# Processed: la_parguera.txt
# Processed: la_perla,_san_juan,_puerto_rico.txt
# Processed: la_placita_de_santurce.txt
# Processed: la_plata_lake.txt
# Processed: la_pocita_de_las_golondrinas_beach.txt
# Processed: la_ventana_al_mar.txt
# Processed: lechon.txt
# Processed: legend_of_diego_salcedo.txt
# Processed: letras_de_ponce.txt
# Processed: lin-manuel_miranda.txt
# Processed: logia_masónica_hijos_de_la_luz.txt
# Processed: los_chinos_de_ponce.txt
# Processed: los_morrillos_lighthouse.txt
# Processed: los_tres_picachos.txt
# Processed: los_tres_picachos_state_forest.txt
# Processed: los_túneles_subterráneos_de_san_germán.txt
# Processed: loverbar.txt
# Processed: loíza_barrio-pueblo.txt
# Processed: loíza_lake.txt
# Processed: luis_a._ferré_performing_arts_center.txt
# Processed: luis_a._ferré_united_states_courthouse_and_post_office_building.txt
# Processed: luis_muñoz_marín_international_airport.txt
# Processed: luis_muñoz_marín_park.txt
# Processed: luis_muñoz_rivera_park.txt
# Processed: luquillo_barrio-pueblo.txt
# Processed: luquillo_beach.txt
# Processed: línea_avanzada.txt
# Processed: lópez_residence.txt
# Processed: manatí_barrio-pueblo.txt
# Processed: manatí_bridge_at_mata_de_plátano.txt
# Processed: maricao_barrio-pueblo.txt
# Processed: maricao_fish_hatchery.txt
# Processed: maricao_state_forest.txt
# Processed: mario_morales_coliseum.txt
# Processed: martín_peña_bridge.txt
# Processed: mar_bella_beach.txt
# Processed: maunabo_barrio-pueblo.txt
# Processed: mavilla_bridge.txt
# Processed: mayagüez_barrio-pueblo.txt
# Processed: mayagüez_city_hall.txt
# Processed: mayagüez_resort_&_casino.txt
# Processed: mccabe_memorial_church.txt
# Processed: miramar_(santurce).txt
# Processed: mizpa_pentecostal_university.txt
# Processed: moca_barrio-pueblo.txt
# Processed: mona_ground_iguana.txt
# Processed: monte_jayuya.txt
# Processed: monumento_al_jíbaro_puertorriqueño.txt
# Processed: monumento_a_la_abolición_de_la_exclavitud.txt
# Processed: monumento_a_los_heroes_de_el_polvorín_(obelisk).txt
# Processed: monumento_a_los_heroes_de_el_polvorín_(tomb).txt
# Processed: morovis_barrio-pueblo.txt
# Processed: morovis_national_cemetery.txt
# Processed: morrillito.txt
# Processed: museo_castillo_serrallés.txt
# Processed: museo_del_autonomismo_puertorriqueño.txt
# Processed: museo_de_arte_de_ponce.txt
# Processed: museo_de_la_arquitectura_ponceña.txt
# Processed: museo_de_la_historia_de_ponce.txt
# Processed: museo_de_la_masacre_de_ponce.txt
# Processed: museo_de_la_música_puertorriqueña.txt
# Processed: museo_de_vida_silvestre.txt
# Processed: museum_of_art_of_puerto_rico.txt
# Processed: museum_of_transportation_of_puerto_rico.txt
# Processed: naguabo_barrio-pueblo.txt
# Processed: naranjito_barrio-pueblo.txt
# Processed: normandie_hotel.txt
# Processed: nuestra_señora_de_lourdes_chapel.txt
# Processed: nuevo_milenio_state_forest.txt
# Processed: ocean_park_(santurce).txt
# Processed: old_piedras_river_aqueduct.txt
# Processed: old_san_juan.txt
# Processed: orocovis.txt
# Processed: orocovis_barrio-pueblo.txt
# Processed: orthodox_judaism.txt
# Processed: our_lady_of_lourdes.txt
# Processed: pablo_casals_museum.txt
# Processed: palacete_los_moreau.txt
# Processed: palmas_del_mar.txt
# Processed: panteón_nacional_román_baldorioty_de_castro.txt
# Processed: parque_del_litoral.txt
# Processed: parque_del_retiro.txt
# Processed: parque_del_tricentenario_(ponce,_puerto_rico).txt
# Processed: parque_de_bombas.txt
# Processed: parque_de_bombas_maximiliano_merced.txt
# Processed: parque_de_las_ciencias.txt
# Processed: parque_de_la_abolición.txt
# Processed: parque_de_la_ceiba.txt
# Processed: parque_ecológico_urbano.txt
# Processed: parque_familiar_julio_enrique_monagas.txt
# Processed: parque_lineal_veredas_del_labrador.txt
# Processed: parque_luis_a._wito_morales.txt
# Processed: parque_nacional_de_las_cavernas_del_río_camuy.txt
# Processed: parque_pedro_albizu_campos.txt
# Processed: parque_urbano_dora_colón_clavell.txt
# Processed: parroquia_del_espíritu_santo_y_san_patricio.txt
# Processed: paseo_atocha.txt
# Processed: paseo_de_la_princesa.txt
# Processed: paseo_tablado_la_guancha.txt
# Processed: paseo_víctor_rojas.txt
# Processed: patillas_barrio-pueblo.txt
# Processed: peñuelas_barrio-pueblo.txt
# Processed: pico_piedra.txt
# Processed: pico_rodadero.txt
# Processed: picó_pomar_residence.txt
# Processed: piñones_state_forest.txt
# Processed: playa_espinar.txt
# Processed: playita_del_condado.txt
# Processed: plaza_carolina.txt
# Processed: plaza_colón.txt
# Processed: plaza_colón_(san_juan).txt
# Processed: plaza_degetau.txt
# Processed: plaza_del_caribe.txt
# Processed: plaza_del_mercado_de_ponce.txt
# Processed: plaza_del_norte.txt
# Processed: plaza_del_quinto_centenario.txt
# Processed: plaza_del_sol_(puerto_rico).txt
# Processed: plaza_de_armas,_san_juan.txt
# Processed: plaza_de_la_catedral_(san_juan).txt
# Processed: plaza_de_san_josé.txt
# Processed: plaza_juan_ponce_de_león.txt
# Processed: plaza_las_américas_(puerto_rico).txt
# Processed: plaza_las_delicias.txt
# Processed: plaza_muñoz_rivera.txt
# Processed: plaza_rio_hondo.txt
# Processed: polvorín_de_miraflores.txt
# Processed: polytechnic_university_of_puerto_rico.txt
# Processed: ponce_cement,_inc..txt
# Processed: ponce_city_hall.txt
# Processed: ponce_high_school.txt
# Processed: ponce_historic_zone.txt
# Processed: ponce_school_of_medicine.txt
# Processed: ponce_ymca_building.txt
# Processed: pontificia_universidad_católica_de_puerto_rico.txt
# Processed: porta_coeli_(puerto_rico).txt
# Processed: pozo_de_jacinto.txt
# Processed: primera_iglesia_bautista_de_caguas.txt
# Processed: primera_iglesia_metodista_unida_de_ponce.txt
# Processed: pueblo,_san_juan,_puerto_rico.txt
# Processed: puente_blanco.txt
# Processed: puente_de_coloso.txt
# Processed: puente_de_las_calabazas.txt
# Processed: puente_no._6.txt
# Processed: puerta_de_tierra,_san_juan.txt
# Processed: puerto_del_rey_marina.txt
# Processed: puerto_rico.txt
# Processed: puerto_rico_convention_center.txt
# Processed: puerto_rico_iron_works.txt
# Processed: puerto_rico_museum_of_contemporary_art.txt
# Processed: puerto_rico_national_library.txt
# Processed: punta_borinquen_light.txt
# Processed: punta_de_las_figuras_light.txt
# Processed: punta_higuero_light.txt
# Processed: punta_mulas_light.txt
# Processed: punta_santiago,_humacao,_puerto_rico.txt
# Processed: punta_tuna_light.txt
# Processed: quebradillas_barrio-pueblo.txt
# Processed: rafael_hernández_marín.txt
# Processed: ramón_rivero_(diplo).txt
# Processed: residencia_aboy-lompré.txt
# Processed: residencia_armstrong-poventud.txt
# Processed: residencia_rosaly-batiz.txt
# Processed: residencia_subirá.txt
# Processed: rincón_barrio-pueblo.txt
# Processed: roberto_clemente_coliseum.txt
# Processed: roberto_clemente_stadium.txt
# Processed: roosevelt_roads_naval_station.txt
# Processed: rovira_biscuits_corporation.txt
# Processed: rum.txt
# Processed: rum_planetarium.txt
# Processed: río_abajo_state_forest.txt
# Processed: río_grande_barrio-pueblo.txt
# Processed: río_grande_de_loíza.txt
# Processed: río_matón_bridge.txt
# Processed: río_piedras_bridge.txt
# Processed: sabana_grande_barrio-pueblo.txt
# Processed: sabana_grande_masonic_cemetery.txt
# Processed: saint_john's_school_(san_juan).txt
# Processed: saliente_river.txt
# Processed: salinas_barrio-pueblo.txt
# Processed: samuel_morse.txt
# Processed: santa_ana_church_(san_juan).txt
# Processed: santa_isabel_barrio-pueblo.txt
# Processed: santa_maría_magdalena_de_pazzis_cemetery.txt
# Processed: santurce,_san_juan,_puerto_rico.txt
# Processed: san_cristóbal_canyon.txt
# Processed: san_germán_historic_district.txt
# Processed: san_josé_church.txt
# Processed: san_juan_botanical_garden.txt
# Processed: san_juan_city_hall.txt
# Processed: san_juan_marriott_resort_&_stellaris_casino.txt
# Processed: san_juan_natatorium.txt
# Processed: san_juan_puerto_rico_temple.txt
# Processed: san_lorenzo_barrio-pueblo.txt
# Processed: san_miguel_arcángel_church_(cabo_rojo).txt
# Processed: san_patricio_plaza.txt
# Processed: san_patricio_state_forest.txt
# Processed: san_sebastián_barrio-pueblo.txt
# Processed: school_of_tropical_medicine_(puerto_rico).txt
# Processed: sixto_escobar.txt
# Processed: stud_farm.txt
# Processed: supreme_court_building_(puerto_rico).txt
# Processed: susúa_state_forest.txt
# Processed: t-mobile_district.txt
# Processed: teatro_fox_delicias.txt
# Processed: teatro_la_perla.txt
# Processed: teatro_tapia.txt
# Processed: teatro_yagüez.txt
# Processed: teodoro_moscoso_bridge.txt
# Processed: the_mall_of_san_juan.txt
# Processed: tito_puente_amphitheatre.txt
# Processed: toa_alta_barrio-pueblo.txt
# Processed: toa_baja_barrio-pueblo.txt
# Processed: toro_negro_state_forest.txt
# Processed: tortuguero_lagoon.txt
# Processed: train_of_the_south.txt
# Processed: trujillo_alto_barrio-pueblo.txt
# Processed: u.s._custom_house_(san_juan,_puerto_rico).txt
# Processed: u.s._post_office_and_courthouse_(mayagüez,_puerto_rico).txt
# Processed: united_states_customs_house_(fajardo,_puerto_rico).txt
# Processed: united_states_customs_house_(ponce,_puerto_rico).txt
# Processed: united_states_district_court_for_the_district_of_puerto_rico.txt
# Processed: universidad_del_sagrado_corazón.txt
# Processed: university_gardens_high_school.txt
# Processed: university_high_school_(san_juan).txt
# Processed: university_of_puerto_rico,_medical_sciences_campus.txt
# Processed: university_of_puerto_rico,_río_piedras_campus.txt
# Processed: university_of_puerto_rico_at_cayey.txt
# Processed: university_of_puerto_rico_at_humacao.txt
# Processed: university_of_puerto_rico_at_mayagüez.txt
# Processed: university_of_puerto_rico_at_ponce.txt
# Processed: university_of_puerto_rico_school_of_medicine.txt
# Processed: uss_killen_(dd-593).txt
# Processed: utuado_barrio-pueblo.txt
# Processed: vega_alta_barrio-pueblo.txt
# Processed: vega_baja_barrio-pueblo.txt
# Processed: vega_state_forest.txt
# Processed: vieques_national_wildlife_refuge.txt
# Processed: villalba,_puerto_rico.txt
# Processed: villalba_barrio-pueblo.txt
# Processed: villa_pesquera.txt
# Processed: west_indian_manatee.txt
# Processed: whale_watching.txt
# Processed: william_miranda_marín_botanical_and_cultural_garden.txt
# Processed: world_war_ii.txt
# Processed: yabucoa_barrio-pueblo.txt
# Processed: yauco_barrio-pueblo.txt
# Processed: zona_historica_de_ponce.txt

# %% [markdown]
# # **Step 2: Removal of duplicate and broken links**

# %%
import os
import json
import requests

# Define directories
cleaned_data_path = r"C:\\Users\\larry\\OneDrive\\Documents\\GitHub\\project-aieng-interactive-travel-planner\\data\\landmarks_cleanng\\step1_cleaned_data"#cleaned_data"
final_data_path = r"C:\\Users\\larry\\OneDrive\\Documents\\GitHub\\project-aieng-interactive-travel-planner\\data\\landmarks_cleanng\\step2_cleaned_data"#final_data"

# Create the final output directory if it doesn't exist
if not os.path.exists(final_data_path):
    os.makedirs(final_data_path)

# Function to validate and deduplicate links
def process_relevant_links(links):
    """
    Validates and deduplicates a list of relevant links.
    Only keeps unique, valid links that start with "http".
    """
    # Filter for HTTP(S) links
    http_links = [link for link in links if link.startswith("http")]
    
    # Deduplicate links
    unique_links = list(set(http_links))
    
    # Validate links
    valid_links = []
    for link in unique_links:
        try:
            response = requests.head(link, timeout=5)
            if response.status_code == 200:
                valid_links.append(link)
        except requests.RequestException:
            continue

    return valid_links

# Process each file in the cleaned_data directory
for file_name in os.listdir(cleaned_data_path):
    file_path = os.path.join(cleaned_data_path, file_name)
    with open(file_path, "r", encoding="utf-8") as file:
        data = json.load(file)

    # Process relevant links if they exist
    if "relevant_links" in data:
        data["relevant_links"] = process_relevant_links(data["relevant_links"])

    # Save the updated data into the final_data directory
    final_file_path = os.path.join(final_data_path, file_name)
    with open(final_file_path, "w", encoding="utf-8") as final_file:
        json.dump(data, final_file, indent=4, ensure_ascii=False)

    print(f"Processed and saved: {file_name}")
# Out:
# Processed and saved: academia_del_perpetuo_socorro.txt
# Processed and saved: academia_interamericana_metro.txt
# Processed and saved: academia_maria_reina.txt
# Processed and saved: academia_san_jorge.txt
# Processed and saved: adjuntas_barrio-pueblo.txt
# Processed and saved: aguada_barrio-pueblo.txt
# Processed and saved: aguada_transmission_station.txt
# Processed and saved: aguadilla_barrio-pueblo.txt
# Processed and saved: aguadilla_ice_skating_arena.txt
# Processed and saved: aguas_buenas_barrio-pueblo.txt
# Processed and saved: aguas_buenas_cave_system.txt
# Processed and saved: aguirre_state_forest.txt
# Processed and saved: aibonito_barrio-pueblo.txt
# Processed and saved: aibonito_festival_of_flowers.txt
# Processed and saved: albergue_olímpico.txt
# Processed and saved: albizu_university.txt
# Processed and saved: ana_g._méndez_university.txt
# Processed and saved: antiguo_casino_de_ponce.txt
# Processed and saved: antiguo_cuartel_militar_español_de_ponce.txt
# Processed and saved: antiguo_hospital_militar_español_de_ponce.txt
# Processed and saved: archivo_general_de_puerto_rico.txt
# Processed and saved: arecibo_barrio-pueblo.txt
# Processed and saved: arecibo_light.txt
# Processed and saved: arecibo_observatory.txt
# Processed and saved: arecibo_telescope.txt
# Processed and saved: arenas_bridge.txt
# Processed and saved: arroyo_barrio-pueblo.txt
# Processed and saved: asilo_de_pobres.txt
# Processed and saved: ateneo_puertorriqueño.txt
# Processed and saved: auditorio_juan_pachín_vicéns.txt
# Processed and saved: añasco_barrio-pueblo.txt
# Processed and saved: bacardi.txt
# Processed and saved: bahía_de_jobos.txt
# Processed and saved: ballajá_barracks.txt
# Processed and saved: balneario_de_rincón.txt
# Processed and saved: banco_crédito_y_ahorro_ponceño_(building).txt
# Processed and saved: banco_de_ponce_(building).txt
# Processed and saved: barceloneta_barrio-pueblo.txt
# Processed and saved: barranquitas_barrio-pueblo.txt
# Processed and saved: basílica_menor_de_la_virgen_de_monserrate.txt
# Processed and saved: bayamón_barrio-pueblo.txt
# Processed and saved: bayamón_city_hall.txt
# Processed and saved: bayamón_river.txt
# Processed and saved: baños_de_coamo.txt
# Processed and saved: biblical_magi.txt
# Processed and saved: biblioteca_carnegie.txt
# Processed and saved: biblioteca_municipal_de_ponce.txt
# Processed and saved: birth_of_the_new_world.txt
# Processed and saved: black_sand.txt
# Processed and saved: blue_beach_(vieques).txt
# Processed and saved: bobbin_lace.txt
# Processed and saved: bolera_caribe.txt
# Processed and saved: boquerón,_cabo_rojo,_puerto_rico.txt
# Processed and saved: boquerón_state_forest.txt
# Processed and saved: braulio_castillo.txt
# Processed and saved: buyé_beach.txt
# Processed and saved: cabo_rojo_barrio-pueblo.txt
# Processed and saved: cabo_rojo_national_wildlife_refuge.txt
# Processed and saved: café_rico.txt
# Processed and saved: caguana_ceremonial_ball_courts_site.txt
# Processed and saved: caguas_barrio-pueblo.txt
# Processed and saved: caguas_city_hall.txt
# Processed and saved: caguas_museum_of_art.txt
# Processed and saved: caguas_museum_of_folk_arts.txt
# Processed and saved: caguas_museum_of_tobacco.txt
# Processed and saved: caguas_valley.txt
# Processed and saved: caja_de_muertos.txt
# Processed and saved: calle_25_de_enero.txt
# Processed and saved: cambalache_forest_reserve.txt
# Processed and saved: campamento_santiago.txt
# Processed and saved: campo_atlético_charles_h._terry.txt
# Processed and saved: camuy_barrio-pueblo.txt
# Processed and saved: camuy_river.txt
# Processed and saved: canóvanas_barrio-pueblo.txt
# Processed and saved: caparra_archaeological_site.txt
# Processed and saved: cape_san_juan_light.txt
# Processed and saved: capilla_del_cristo.txt
# Processed and saved: capitol_of_puerto_rico.txt
# Processed and saved: caracas_beach_(vieques).txt
# Processed and saved: cardona_(ponce).txt
# Processed and saved: cardona_residence.txt
# Processed and saved: caribe_hilton_hotel.txt
# Processed and saved: carite_lake.txt
# Processed and saved: carite_state_forest.txt
# Processed and saved: carolina_barrio-pueblo.txt
# Processed and saved: carraízo_dam.txt
# Processed and saved: casa_alonso.txt
# Processed and saved: casa_blanca_(san_juan).txt
# Processed and saved: casa_cautiño.txt
# Processed and saved: casa_del_rey.txt
# Processed and saved: casa_de_españa.txt
# Processed and saved: casa_dra._concha_melendez_ramirez.txt
# Processed and saved: casa_fernando_luis_toro.txt
# Processed and saved: casa_font-ubides.txt
# Processed and saved: casa_franceschi_antongiorgi.txt
# Processed and saved: casa_natal_de_luis_muñoz_rivera.txt
# Processed and saved: casa_nemesio_canales.txt
# Processed and saved: casa_oppenheimer.txt
# Processed and saved: casa_paoli.txt
# Processed and saved: casa_pueblo_puerto_rico.txt
# Processed and saved: casa_roig_museum.txt
# Processed and saved: casa_rosa.txt
# Processed and saved: casa_rosita_serrallés.txt
# Processed and saved: casa_salazar-candal.txt
# Processed and saved: casa_serralles.txt
# Processed and saved: casa_wiechers-villaronga.txt
# Processed and saved: casona_césari.txt
# Processed and saved: castillo_san_cristóbal_(san_juan).txt
# Processed and saved: castillo_san_felipe_del_morro.txt
# Processed and saved: castillo_san_felipe_del_morro_lighthouse.txt
# Processed and saved: castillo_serrallés.txt
# Processed and saved: cataño_barrio-pueblo.txt
# Processed and saved: catedral_de_nuestra_señora_de_guadalupe.txt
# Processed and saved: catedral_de_san_felipe_apóstol_(arecibo,_puerto_rico).txt
# Processed and saved: catedral_dulce_nombre_de_jesús_(caguas,_puerto_rico).txt
# Processed and saved: catedral_metropolitana_basílica_de_san_juan_bautista_(san_juan,_puerto_rico).txt
# Processed and saved: cathedral_of_rum.txt
# Processed and saved: cayey_barrio-pueblo.txt
# Processed and saved: cayos_de_caña_gorda.txt
# Processed and saved: cayo_icacos.txt
# Processed and saved: cayo_luis_peña.txt
# Processed and saved: caño_tiburones.txt
# Processed and saved: ceiba_barrio-pueblo.txt
# Processed and saved: cementerio_católico_san_vicente_de_paul.txt
# Processed and saved: cementerio_civil_de_ponce.txt
# Processed and saved: center_for_advanced_studies_on_puerto_rico_and_the_caribbean.txt
# Processed and saved: central_aguirre_historic_district.txt
# Processed and saved: central_cortada.txt
# Processed and saved: central_guánica.txt
# Processed and saved: central_high_school_(san_juan,_puerto_rico).txt
# Processed and saved: centro_ceremonial_indígena_de_tibes.txt
# Processed and saved: centro_cultural_baudilio_vega_berríos.txt
# Processed and saved: centro_cultural_de_ponce_carmen_solá_de_pereira.txt
# Processed and saved: centro_del_sur_mall.txt
# Processed and saved: centro_de_convenciones_de_ponce.txt
# Processed and saved: cerrillos_state_forest.txt
# Processed and saved: cerro_de_punta.txt
# Processed and saved: cerro_las_tetas.txt
# Processed and saved: cerro_maravilla.txt
# Processed and saved: cerro_morales_(utuado,_puerto_rico).txt
# Processed and saved: cerro_rosa.txt
# Processed and saved: cervecería_india.txt
# Processed and saved: chalet_amill.txt
# Processed and saved: christopher_columbus.txt
# Processed and saved: church_of_saint_francis_of_assisi,_san_juan.txt
# Processed and saved: church_of_san_francisco_de_asís.txt
# Processed and saved: church_of_san_mateo_de_cangrejos_of_santurce.txt
# Processed and saved: church_san_blas_de_illescas_of_coamo.txt
# Processed and saved: church_san_josé_of_aibonito.txt
# Processed and saved: church_san_miguel_arcángel_of_utuado.txt
# Processed and saved: ciales_barrio-pueblo.txt
# Processed and saved: cidra_barrio-pueblo.txt
# Processed and saved: ciudad_deportiva_millito_navarro.txt
# Processed and saved: club_deportivo_del_oeste.txt
# Processed and saved: club_nautico_de_ponce.txt
# Processed and saved: club_náutico_de_ponce.txt
# Processed and saved: coamo_barrio-pueblo.txt
# Processed and saved: coca-cola_music_hall.txt
# Processed and saved: colegio_ponceño.txt
# Processed and saved: colegio_san_conrado.txt
# Processed and saved: coliseo_manuel_iguina.txt
# Processed and saved: coliseo_rubén_rodríguez.txt
# Processed and saved: coloso_sugar_cane_refinery.txt
# Processed and saved: comerío_barrio-pueblo.txt
# Processed and saved: complejo_recreativo_y_cultural_la_guancha.txt
# Processed and saved: concatedral_dulce_nombre_de_jesús_(humacao,_puerto_rico).txt
# Processed and saved: condado_(santurce).txt
# Processed and saved: condado_lagoon.txt
# Processed and saved: condado_vanderbilt_hotel.txt
# Processed and saved: conservatory_of_music_of_puerto_rico.txt
# Processed and saved: corozal_barrio-pueblo.txt
# Processed and saved: couroupita_nicaraguarensis.txt
# Processed and saved: crash_boat_beach.txt
# Processed and saved: cruceta_del_vigía.txt
# Processed and saved: cuevas_las_cabachuelas.txt
# Processed and saved: cueva_del_indio_(arecibo).txt
# Processed and saved: cueva_del_indio_(las_piedras).txt
# Processed and saved: cueva_lucero.txt
# Processed and saved: cueva_ventana.txt
# Processed and saved: culebra_barrio-pueblo.txt
# Processed and saved: culebra_national_wildlife_refuge.txt
# Processed and saved: culebrita.txt
# Processed and saved: dead_dog_beach.txt
# Processed and saved: desecheo_national_wildlife_refuge.txt
# Processed and saved: destilería_serrallés.txt
# Processed and saved: district_courthouse_(aguadilla,_puerto_rico).txt
# Processed and saved: domes_beach.txt
# Processed and saved: dorado_barrio-pueblo.txt
# Processed and saved: dos_bocas_lake.txt
# Processed and saved: dos_hermanos_bridge.txt
# Processed and saved: dr._juan_a._rivero_zoo.txt
# Processed and saved: edificio_aboy.txt
# Processed and saved: edificio_comunidad_de_orgullo_gay_de_puerto_rico.txt
# Processed and saved: edificio_del_valle.txt
# Processed and saved: edificio_josé_de_diego.txt
# Processed and saved: edificio_oliver.txt
# Processed and saved: edificio_patio_español.txt
# Processed and saved: edificio_victory_garden.txt
# Processed and saved: el_falansterio_de_puerta_de_tierra.txt
# Processed and saved: el_gigante_dormido.txt
# Processed and saved: el_monumento_de_la_recordación.txt
# Processed and saved: el_parterre.txt
# Processed and saved: el_toro_wilderness.txt
# Processed and saved: el_tuque.txt
# Processed and saved: el_yunque_national_forest.txt
# Processed and saved: enrique_laguerre.txt
# Processed and saved: ensenada_honda_(culebra,_puerto_rico).txt
# Processed and saved: episcopal_cathedral_of_st._john_the_baptist_(san_juan,_puerto_rico).txt
# Processed and saved: ermita_nuestra_señora_de_la_valvanera.txt
# Processed and saved: escuela_brambaugh.txt
# Processed and saved: escuela_de_artes_plásticas_y_diseño_de_puerto_rico.txt
# Processed and saved: esperanza_beach.txt
# Processed and saved: estadio_country_club.txt
# Processed and saved: estadio_francisco_montaner.txt
# Processed and saved: estadio_sixto_escobar.txt
# Processed and saved: fajardo_barrio-pueblo.txt
# Processed and saved: farmers'_market.txt
# Processed and saved: faro_del_puerto_de_ponce.txt
# Processed and saved: faro_de_la_isla_de_caja_de_muertos.txt
# Processed and saved: filardi_house.txt
# Processed and saved: flamenco_beach.txt
# Processed and saved: florida,_puerto_rico.txt
# Processed and saved: fort_buchanan,_puerto_rico.txt
# Processed and saved: fortín_de_san_gerónimo.txt
# Processed and saved: fortín_san_antonio.txt
# Processed and saved: fortín_san_juan_de_la_cruz.txt
# Processed and saved: francisco_oller.txt
# Processed and saved: fuerte_de_la_concepción.txt
# Processed and saved: fuerte_de_vieques.txt
# Processed and saved: galería_nacional.txt
# Processed and saved: gatas_(ponce).txt
# Processed and saved: general_norzagaray_bridge.txt
# Processed and saved: general_store.txt
# Processed and saved: guajataca_lake.txt
# Processed and saved: guajataca_state_forest.txt
# Processed and saved: guajataca_tunnel.txt
# Processed and saved: guavate,_cayey,_puerto_rico.txt
# Processed and saved: guayama_barrio-pueblo.txt
# Processed and saved: guayanilla_barrio-pueblo.txt
# Processed and saved: guaynabo_barrio-pueblo.txt
# Processed and saved: guilarte_state_forest.txt
# Processed and saved: gurabo_barrio-pueblo.txt
# Processed and saved: guánica_barrio-pueblo.txt
# Processed and saved: guánica_light.txt
# Processed and saved: guánica_state_forest.txt
# Processed and saved: gómez_residence.txt
# Processed and saved: hacienda_azucarera_la_esperanza.txt
# Processed and saved: hacienda_buena_vista.txt
# Processed and saved: hacienda_el_jibarito.txt
# Processed and saved: hacienda_juanita.txt
# Processed and saved: hacienda_lealtad.txt
# Processed and saved: hacienda_santa_rita.txt
# Processed and saved: hacienda_san_francisco.txt
# Processed and saved: hatillo_barrio-pueblo.txt
# Processed and saved: henry_klumb_house.txt
# Processed and saved: hermitage_of_san_antonio_de_padua_de_la_tuna.txt
# Processed and saved: hipódromo_camarero.txt
# Processed and saved: hiram_bithorn_stadium.txt
# Processed and saved: hormigueros_barrio-pueblo.txt
# Processed and saved: horse_racing.txt
# Processed and saved: hotel_el_convento.txt
# Processed and saved: hotel_melia.txt
# Processed and saved: hotel_ponce_intercontinental.txt
# Processed and saved: hotel_ponce_ramada.txt
# Processed and saved: house_at_659_concordia_street.txt
# Processed and saved: house_at_659_la_paz_street.txt
# Processed and saved: house_at_663_la_paz_street.txt
# Processed and saved: house_at_665_mckinley_street.txt
# Processed and saved: humacao_barrio-pueblo.txt
# Processed and saved: humacao_nature_reserve.txt
# Processed and saved: húcares.txt
# Processed and saved: iglesia_de_la_santísima_trinidad.txt
# Processed and saved: iglesia_de_nuestra_señora_del_carmen.txt
# Processed and saved: iglesia_de_san_antonio_de_padua.txt
# Processed and saved: iglesia_san_germán_de_auxerre.txt
# Processed and saved: iglesia_san_sebastián_mártir.txt
# Processed and saved: industrias_vassallo.txt
# Processed and saved: institute_of_puerto_rican_culture.txt
# Processed and saved: interamerican_university_of_puerto_rico.txt
# Processed and saved: interamerican_university_of_puerto_rico_at_ponce.txt
# Processed and saved: isabela_barrio-pueblo.txt
# Processed and saved: isabel_ii_barrio-pueblo.txt
# Processed and saved: isla_del_frío.txt
# Processed and saved: isla_de_cabras.txt
# Processed and saved: isla_de_jueyes.txt
# Processed and saved: isla_de_mona.txt
# Processed and saved: isla_de_ratones_(cabo_rojo,_puerto_rico).txt
# Processed and saved: isla_de_ratones_(ponce,_puerto_rico).txt
# Processed and saved: isla_magueyes.txt
# Processed and saved: isla_mata_la_gata.txt
# Processed and saved: isla_palomino.txt
# Processed and saved: isla_verde,_puerto_rico.txt
# Processed and saved: jayuya_barrio-pueblo.txt
# Processed and saved: jesús_izcoa_moure_bridge.txt
# Processed and saved: jesús_t._piñero_house.txt
# Processed and saved: jobos_beach.txt
# Processed and saved: jose_v._toledo_federal_building_and_united_states_courthouse.txt
# Processed and saved: josé_celso_barbosa.txt
# Processed and saved: josé_miguel_agrelot_coliseum.txt
# Processed and saved: joyuda,_puerto_rico.txt
# Processed and saved: joyuda_lagoon.txt
# Processed and saved: juana_díaz_barrio-pueblo.txt
# Processed and saved: juan_boria.txt
# Processed and saved: juan_ramón_loubriel_stadium.txt
# Processed and saved: julia_de_burgos.txt
# Processed and saved: julio_enrique_monagas_park.txt
# Processed and saved: juncos_barrio-pueblo.txt
# Processed and saved: lago_dos_bocas.txt
# Processed and saved: laguna_cartagena_national_wildlife_refuge.txt
# Processed and saved: lajas_barrio-pueblo.txt
# Processed and saved: lake_luchetti.txt
# Processed and saved: lares_barrio-pueblo.txt
# Processed and saved: lares_ice_cream_parlor.txt
# Processed and saved: las_cabañas_bridge.txt
# Processed and saved: las_cascadas_water_park.txt
# Processed and saved: las_catalinas_mall.txt
# Processed and saved: las_marías_barrio-pueblo.txt
# Processed and saved: las_piedras_barrio-pueblo.txt
# Processed and saved: la_bombonera_(san_juan).txt
# Processed and saved: la_concha_renaissance_san_juan_resort.txt
# Processed and saved: la_cordillera_reef_nature_reserve.txt
# Processed and saved: la_fortaleza.txt
# Processed and saved: la_giralda_(san_juan,_puerto_rico).txt
# Processed and saved: la_guancha_(ponce,_puerto_rico).txt
# Processed and saved: la_liendre_bridge.txt
# Processed and saved: la_mallorquina.txt
# Processed and saved: la_parguera.txt
# Processed and saved: la_perla,_san_juan,_puerto_rico.txt
# Processed and saved: la_placita_de_santurce.txt
# Processed and saved: la_plata_lake.txt
# Processed and saved: la_pocita_de_las_golondrinas_beach.txt
# Processed and saved: la_ventana_al_mar.txt
# Processed and saved: lechon.txt
# Processed and saved: legend_of_diego_salcedo.txt
# Processed and saved: letras_de_ponce.txt
# Processed and saved: lin-manuel_miranda.txt
# Processed and saved: logia_masónica_hijos_de_la_luz.txt
# Processed and saved: los_chinos_de_ponce.txt
# Processed and saved: los_morrillos_lighthouse.txt
# Processed and saved: los_tres_picachos.txt
# Processed and saved: los_tres_picachos_state_forest.txt
# Processed and saved: los_túneles_subterráneos_de_san_germán.txt
# Processed and saved: loverbar.txt
# Processed and saved: loíza_barrio-pueblo.txt
# Processed and saved: loíza_lake.txt
# Processed and saved: luis_a._ferré_performing_arts_center.txt
# Processed and saved: luis_a._ferré_united_states_courthouse_and_post_office_building.txt
# Processed and saved: luis_muñoz_marín_international_airport.txt
# Processed and saved: luis_muñoz_marín_park.txt
# Processed and saved: luis_muñoz_rivera_park.txt
# Processed and saved: luquillo_barrio-pueblo.txt
# Processed and saved: luquillo_beach.txt
# Processed and saved: línea_avanzada.txt
# Processed and saved: lópez_residence.txt
# Processed and saved: manatí_barrio-pueblo.txt
# Processed and saved: manatí_bridge_at_mata_de_plátano.txt
# Processed and saved: maricao_barrio-pueblo.txt
# Processed and saved: maricao_fish_hatchery.txt
# Processed and saved: maricao_state_forest.txt
# Processed and saved: mario_morales_coliseum.txt
# Processed and saved: martín_peña_bridge.txt
# Processed and saved: mar_bella_beach.txt
# Processed and saved: maunabo_barrio-pueblo.txt
# Processed and saved: mavilla_bridge.txt
# Processed and saved: mayagüez_barrio-pueblo.txt
# Processed and saved: mayagüez_city_hall.txt
# Processed and saved: mayagüez_resort_&_casino.txt
# Processed and saved: mccabe_memorial_church.txt
# Processed and saved: miramar_(santurce).txt
# Processed and saved: mizpa_pentecostal_university.txt
# Processed and saved: moca_barrio-pueblo.txt
# Processed and saved: mona_ground_iguana.txt
# Processed and saved: monte_jayuya.txt
# Processed and saved: monumento_al_jíbaro_puertorriqueño.txt
# Processed and saved: monumento_a_la_abolición_de_la_exclavitud.txt
# Processed and saved: monumento_a_los_heroes_de_el_polvorín_(obelisk).txt
# Processed and saved: monumento_a_los_heroes_de_el_polvorín_(tomb).txt
# Processed and saved: morovis_barrio-pueblo.txt
# Processed and saved: morovis_national_cemetery.txt
# Processed and saved: morrillito.txt
# Processed and saved: museo_castillo_serrallés.txt
# Processed and saved: museo_del_autonomismo_puertorriqueño.txt
# Processed and saved: museo_de_arte_de_ponce.txt
# Processed and saved: museo_de_la_arquitectura_ponceña.txt
# Processed and saved: museo_de_la_historia_de_ponce.txt
# Processed and saved: museo_de_la_masacre_de_ponce.txt
# Processed and saved: museo_de_la_música_puertorriqueña.txt
# Processed and saved: museo_de_vida_silvestre.txt
# Processed and saved: museum_of_art_of_puerto_rico.txt
# Processed and saved: museum_of_transportation_of_puerto_rico.txt
# Processed and saved: naguabo_barrio-pueblo.txt
# Processed and saved: naranjito_barrio-pueblo.txt
# Processed and saved: normandie_hotel.txt
# Processed and saved: nuestra_señora_de_lourdes_chapel.txt
# Processed and saved: nuevo_milenio_state_forest.txt
# Processed and saved: ocean_park_(santurce).txt
# Processed and saved: old_piedras_river_aqueduct.txt
# Processed and saved: old_san_juan.txt
# Processed and saved: orocovis.txt
# Processed and saved: orocovis_barrio-pueblo.txt
# Processed and saved: orthodox_judaism.txt
# Processed and saved: our_lady_of_lourdes.txt
# Processed and saved: pablo_casals_museum.txt
# Processed and saved: palacete_los_moreau.txt
# Processed and saved: palmas_del_mar.txt
# Processed and saved: panteón_nacional_román_baldorioty_de_castro.txt
# Processed and saved: parque_del_litoral.txt
# Processed and saved: parque_del_retiro.txt
# Processed and saved: parque_del_tricentenario_(ponce,_puerto_rico).txt
# Processed and saved: parque_de_bombas.txt
# Processed and saved: parque_de_bombas_maximiliano_merced.txt
# Processed and saved: parque_de_las_ciencias.txt
# Processed and saved: parque_de_la_abolición.txt
# Processed and saved: parque_de_la_ceiba.txt
# Processed and saved: parque_ecológico_urbano.txt
# Processed and saved: parque_familiar_julio_enrique_monagas.txt
# Processed and saved: parque_lineal_veredas_del_labrador.txt
# Processed and saved: parque_luis_a._wito_morales.txt
# Processed and saved: parque_nacional_de_las_cavernas_del_río_camuy.txt
# Processed and saved: parque_pedro_albizu_campos.txt
# Processed and saved: parque_urbano_dora_colón_clavell.txt
# Processed and saved: parroquia_del_espíritu_santo_y_san_patricio.txt
# Processed and saved: paseo_atocha.txt
# Processed and saved: paseo_de_la_princesa.txt
# Processed and saved: paseo_tablado_la_guancha.txt
# Processed and saved: paseo_víctor_rojas.txt
# Processed and saved: patillas_barrio-pueblo.txt
# Processed and saved: peñuelas_barrio-pueblo.txt
# Processed and saved: pico_piedra.txt
# Processed and saved: pico_rodadero.txt
# Processed and saved: picó_pomar_residence.txt
# Processed and saved: piñones_state_forest.txt
# Processed and saved: playa_espinar.txt
# Processed and saved: playita_del_condado.txt
# Processed and saved: plaza_carolina.txt
# Processed and saved: plaza_colón.txt
# Processed and saved: plaza_colón_(san_juan).txt
# Processed and saved: plaza_degetau.txt
# Processed and saved: plaza_del_caribe.txt
# Processed and saved: plaza_del_mercado_de_ponce.txt
# Processed and saved: plaza_del_norte.txt
# Processed and saved: plaza_del_quinto_centenario.txt
# Processed and saved: plaza_del_sol_(puerto_rico).txt
# Processed and saved: plaza_de_armas,_san_juan.txt
# Processed and saved: plaza_de_la_catedral_(san_juan).txt
# Processed and saved: plaza_de_san_josé.txt
# Processed and saved: plaza_juan_ponce_de_león.txt
# Processed and saved: plaza_las_américas_(puerto_rico).txt
# Processed and saved: plaza_las_delicias.txt
# Processed and saved: plaza_muñoz_rivera.txt
# Processed and saved: plaza_rio_hondo.txt
# Processed and saved: polvorín_de_miraflores.txt
# Processed and saved: polytechnic_university_of_puerto_rico.txt
# Processed and saved: ponce_cement,_inc..txt
# Processed and saved: ponce_city_hall.txt
# Processed and saved: ponce_high_school.txt
# Processed and saved: ponce_historic_zone.txt
# Processed and saved: ponce_school_of_medicine.txt
# Processed and saved: ponce_ymca_building.txt
# Processed and saved: pontificia_universidad_católica_de_puerto_rico.txt
# Processed and saved: porta_coeli_(puerto_rico).txt
# Processed and saved: pozo_de_jacinto.txt
# Processed and saved: primera_iglesia_bautista_de_caguas.txt
# Processed and saved: primera_iglesia_metodista_unida_de_ponce.txt
# Processed and saved: pueblo,_san_juan,_puerto_rico.txt
# Processed and saved: puente_blanco.txt
# Processed and saved: puente_de_coloso.txt
# Processed and saved: puente_de_las_calabazas.txt
# Processed and saved: puente_no._6.txt
# Processed and saved: puerta_de_tierra,_san_juan.txt
# Processed and saved: puerto_del_rey_marina.txt
# Processed and saved: puerto_rico.txt
# Processed and saved: puerto_rico_convention_center.txt
# Processed and saved: puerto_rico_iron_works.txt
# Processed and saved: puerto_rico_museum_of_contemporary_art.txt
# Processed and saved: puerto_rico_national_library.txt
# Processed and saved: punta_borinquen_light.txt
# Processed and saved: punta_de_las_figuras_light.txt
# Processed and saved: punta_higuero_light.txt
# Processed and saved: punta_mulas_light.txt
# Processed and saved: punta_santiago,_humacao,_puerto_rico.txt
# Processed and saved: punta_tuna_light.txt
# Processed and saved: quebradillas_barrio-pueblo.txt
# Processed and saved: rafael_hernández_marín.txt
# Processed and saved: ramón_rivero_(diplo).txt
# Processed and saved: residencia_aboy-lompré.txt
# Processed and saved: residencia_armstrong-poventud.txt
# Processed and saved: residencia_rosaly-batiz.txt
# Processed and saved: residencia_subirá.txt
# Processed and saved: rincón_barrio-pueblo.txt
# Processed and saved: roberto_clemente_coliseum.txt
# Processed and saved: roberto_clemente_stadium.txt
# Processed and saved: roosevelt_roads_naval_station.txt
# Processed and saved: rovira_biscuits_corporation.txt
# Processed and saved: rum.txt
# Processed and saved: rum_planetarium.txt
# Processed and saved: río_abajo_state_forest.txt
# Processed and saved: río_grande_barrio-pueblo.txt
# Processed and saved: río_grande_de_loíza.txt
# Processed and saved: río_matón_bridge.txt
# Processed and saved: río_piedras_bridge.txt
# Processed and saved: sabana_grande_barrio-pueblo.txt
# Processed and saved: sabana_grande_masonic_cemetery.txt
# Processed and saved: saint_john's_school_(san_juan).txt
# Processed and saved: saliente_river.txt
# Processed and saved: salinas_barrio-pueblo.txt
# Processed and saved: samuel_morse.txt
# Processed and saved: santa_ana_church_(san_juan).txt
# Processed and saved: santa_isabel_barrio-pueblo.txt
# Processed and saved: santa_maría_magdalena_de_pazzis_cemetery.txt
# Processed and saved: santurce,_san_juan,_puerto_rico.txt
# Processed and saved: san_cristóbal_canyon.txt
# Processed and saved: san_germán_historic_district.txt
# Processed and saved: san_josé_church.txt
# Processed and saved: san_juan_botanical_garden.txt
# Processed and saved: san_juan_city_hall.txt
# Processed and saved: san_juan_marriott_resort_&_stellaris_casino.txt
# Processed and saved: san_juan_natatorium.txt
# Processed and saved: san_juan_puerto_rico_temple.txt
# Processed and saved: san_lorenzo_barrio-pueblo.txt
# Processed and saved: san_miguel_arcángel_church_(cabo_rojo).txt
# Processed and saved: san_patricio_plaza.txt
# Processed and saved: san_patricio_state_forest.txt
# Processed and saved: san_sebastián_barrio-pueblo.txt
# Processed and saved: school_of_tropical_medicine_(puerto_rico).txt
# Processed and saved: sixto_escobar.txt
# Processed and saved: stud_farm.txt
# Processed and saved: supreme_court_building_(puerto_rico).txt
# Processed and saved: susúa_state_forest.txt
# Processed and saved: t-mobile_district.txt
# Processed and saved: teatro_fox_delicias.txt
# Processed and saved: teatro_la_perla.txt
# Processed and saved: teatro_tapia.txt
# Processed and saved: teatro_yagüez.txt
# Processed and saved: teodoro_moscoso_bridge.txt
# Processed and saved: the_mall_of_san_juan.txt
# Processed and saved: tito_puente_amphitheatre.txt
# Processed and saved: toa_alta_barrio-pueblo.txt
# Processed and saved: toa_baja_barrio-pueblo.txt
# Processed and saved: toro_negro_state_forest.txt
# Processed and saved: tortuguero_lagoon.txt
# Processed and saved: train_of_the_south.txt
# Processed and saved: trujillo_alto_barrio-pueblo.txt
# Processed and saved: u.s._custom_house_(san_juan,_puerto_rico).txt
# Processed and saved: u.s._post_office_and_courthouse_(mayagüez,_puerto_rico).txt
# Processed and saved: united_states_customs_house_(fajardo,_puerto_rico).txt
# Processed and saved: united_states_customs_house_(ponce,_puerto_rico).txt
# Processed and saved: united_states_district_court_for_the_district_of_puerto_rico.txt
# Processed and saved: universidad_del_sagrado_corazón.txt
# Processed and saved: university_gardens_high_school.txt
# Processed and saved: university_high_school_(san_juan).txt
# Processed and saved: university_of_puerto_rico,_medical_sciences_campus.txt
# Processed and saved: university_of_puerto_rico,_río_piedras_campus.txt
# Processed and saved: university_of_puerto_rico_at_cayey.txt
# Processed and saved: university_of_puerto_rico_at_humacao.txt
# Processed and saved: university_of_puerto_rico_at_mayagüez.txt
# Processed and saved: university_of_puerto_rico_at_ponce.txt
# Processed and saved: university_of_puerto_rico_school_of_medicine.txt
# Processed and saved: uss_killen_(dd-593).txt
# Processed and saved: utuado_barrio-pueblo.txt
# Processed and saved: vega_alta_barrio-pueblo.txt
# Processed and saved: vega_baja_barrio-pueblo.txt
# Processed and saved: vega_state_forest.txt
# Processed and saved: vieques_national_wildlife_refuge.txt
# Processed and saved: villalba,_puerto_rico.txt
# Processed and saved: villalba_barrio-pueblo.txt
# Processed and saved: villa_pesquera.txt
# Processed and saved: west_indian_manatee.txt
# Processed and saved: whale_watching.txt
# Processed and saved: william_miranda_marín_botanical_and_cultural_garden.txt
# Processed and saved: world_war_ii.txt
# Processed and saved: yabucoa_barrio-pueblo.txt
# Processed and saved: yauco_barrio-pueblo.txt
# Processed and saved: zona_historica_de_ponce.txt

# %% [markdown]
# # **Step 3: Removal of links references and not relevant links**
# Note: Removal of link references does not works within this code. LWD 06Feb25

# %%
import os
import json
import re

# Define input and output directories
final_data_path = r"C:\\Users\\larry\\OneDrive\\Documents\\GitHub\\project-aieng-interactive-travel-planner\\data\\landmarks_cleanng\\step2_cleaned_data"#final_data"
final_cleaned_data_path = r"C:\\Users\\larry\\OneDrive\\Documents\\GitHub\\project-aieng-interactive-travel-planner\\data\\landmarks_cleanng\\step3_cleaned_data"

# Create final cleaned output directory if it doesn't exist
if not os.path.exists(final_cleaned_data_path):
    os.makedirs(final_cleaned_data_path)

# Define trusted sources for relevant links
TRUSTED_DOMAINS = [
    "wikipedia.org",
    "wikivoyage.org",
    "discoverpuertorico.com",
    "travel.usnews.com",
    "tripadvisor.com",
    "skyscanner.com",
    "lonelyplanet.com",
    "puertorico.com"
]

# Function to filter relevant links
def filter_relevant_links(links):
    filtered_links = []
    for link in links:
        if any(domain in link for domain in TRUSTED_DOMAINS):
            filtered_links.append(link)
    return list(set(filtered_links))  # Remove duplicates

# Function to remove citation numbers like "[1]" from text
def remove_citation_numbers(text):
    return re.sub(r"\[\d+\]", "", text)

# Process each file in the final_data directory
for file_name in os.listdir(final_data_path):
    file_path = os.path.join(final_data_path, file_name)

    with open(file_path, "r", encoding="utf-8") as file:
        data = json.load(file)

    # Clean relevant links
    if "relevant_links" in data:
        data["relevant_links"] = filter_relevant_links(data["relevant_links"])

    # Clean main content from citation numbers
    if "main_content" in data:
        data["main_content"] = remove_citation_numbers(data["main_content"])

    # Save the cleaned file to final_cleaned_data directory
    output_file_path = os.path.join(final_cleaned_data_path, file_name)
    with open(output_file_path, "w", encoding="utf-8") as output_file:
        json.dump(data, output_file, indent=4, ensure_ascii=False)

    print(f"Final cleaned and saved: {file_name}")
# Out:
# Final cleaned and saved: academia_del_perpetuo_socorro.txt
# Final cleaned and saved: academia_interamericana_metro.txt
# Final cleaned and saved: academia_maria_reina.txt
# Final cleaned and saved: academia_san_jorge.txt
# Final cleaned and saved: adjuntas_barrio-pueblo.txt
# Final cleaned and saved: aguada_barrio-pueblo.txt
# Final cleaned and saved: aguada_transmission_station.txt
# Final cleaned and saved: aguadilla_barrio-pueblo.txt
# Final cleaned and saved: aguadilla_ice_skating_arena.txt
# Final cleaned and saved: aguas_buenas_barrio-pueblo.txt
# Final cleaned and saved: aguas_buenas_cave_system.txt
# Final cleaned and saved: aguirre_state_forest.txt
# Final cleaned and saved: aibonito_barrio-pueblo.txt
# Final cleaned and saved: aibonito_festival_of_flowers.txt
# Final cleaned and saved: albergue_olímpico.txt
# Final cleaned and saved: albizu_university.txt
# Final cleaned and saved: ana_g._méndez_university.txt
# Final cleaned and saved: antiguo_casino_de_ponce.txt
# Final cleaned and saved: antiguo_cuartel_militar_español_de_ponce.txt
# Final cleaned and saved: antiguo_hospital_militar_español_de_ponce.txt
# Final cleaned and saved: archivo_general_de_puerto_rico.txt
# Final cleaned and saved: arecibo_barrio-pueblo.txt
# Final cleaned and saved: arecibo_light.txt
# Final cleaned and saved: arecibo_observatory.txt
# Final cleaned and saved: arecibo_telescope.txt
# Final cleaned and saved: arenas_bridge.txt
# Final cleaned and saved: arroyo_barrio-pueblo.txt
# Final cleaned and saved: asilo_de_pobres.txt
# Final cleaned and saved: ateneo_puertorriqueño.txt
# Final cleaned and saved: auditorio_juan_pachín_vicéns.txt
# Final cleaned and saved: añasco_barrio-pueblo.txt
# Final cleaned and saved: bacardi.txt
# Final cleaned and saved: bahía_de_jobos.txt
# Final cleaned and saved: ballajá_barracks.txt
# Final cleaned and saved: balneario_de_rincón.txt
# Final cleaned and saved: banco_crédito_y_ahorro_ponceño_(building).txt
# Final cleaned and saved: banco_de_ponce_(building).txt
# Final cleaned and saved: barceloneta_barrio-pueblo.txt
# Final cleaned and saved: barranquitas_barrio-pueblo.txt
# Final cleaned and saved: basílica_menor_de_la_virgen_de_monserrate.txt
# Final cleaned and saved: bayamón_barrio-pueblo.txt
# Final cleaned and saved: bayamón_city_hall.txt
# Final cleaned and saved: bayamón_river.txt
# Final cleaned and saved: baños_de_coamo.txt
# Final cleaned and saved: biblical_magi.txt
# Final cleaned and saved: biblioteca_carnegie.txt
# Final cleaned and saved: biblioteca_municipal_de_ponce.txt
# Final cleaned and saved: birth_of_the_new_world.txt
# Final cleaned and saved: black_sand.txt
# Final cleaned and saved: blue_beach_(vieques).txt
# Final cleaned and saved: bobbin_lace.txt
# Final cleaned and saved: bolera_caribe.txt
# Final cleaned and saved: boquerón,_cabo_rojo,_puerto_rico.txt
# Final cleaned and saved: boquerón_state_forest.txt
# Final cleaned and saved: braulio_castillo.txt
# Final cleaned and saved: buyé_beach.txt
# Final cleaned and saved: cabo_rojo_barrio-pueblo.txt
# Final cleaned and saved: cabo_rojo_national_wildlife_refuge.txt
# Final cleaned and saved: café_rico.txt
# Final cleaned and saved: caguana_ceremonial_ball_courts_site.txt
# Final cleaned and saved: caguas_barrio-pueblo.txt
# Final cleaned and saved: caguas_city_hall.txt
# Final cleaned and saved: caguas_museum_of_art.txt
# Final cleaned and saved: caguas_museum_of_folk_arts.txt
# Final cleaned and saved: caguas_museum_of_tobacco.txt
# Final cleaned and saved: caguas_valley.txt
# Final cleaned and saved: caja_de_muertos.txt
# Final cleaned and saved: calle_25_de_enero.txt
# Final cleaned and saved: cambalache_forest_reserve.txt
# Final cleaned and saved: campamento_santiago.txt
# Final cleaned and saved: campo_atlético_charles_h._terry.txt
# Final cleaned and saved: camuy_barrio-pueblo.txt
# Final cleaned and saved: camuy_river.txt
# Final cleaned and saved: canóvanas_barrio-pueblo.txt
# Final cleaned and saved: caparra_archaeological_site.txt
# Final cleaned and saved: cape_san_juan_light.txt
# Final cleaned and saved: capilla_del_cristo.txt
# Final cleaned and saved: capitol_of_puerto_rico.txt
# Final cleaned and saved: caracas_beach_(vieques).txt
# Final cleaned and saved: cardona_(ponce).txt
# Final cleaned and saved: cardona_residence.txt
# Final cleaned and saved: caribe_hilton_hotel.txt
# Final cleaned and saved: carite_lake.txt
# Final cleaned and saved: carite_state_forest.txt
# Final cleaned and saved: carolina_barrio-pueblo.txt
# Final cleaned and saved: carraízo_dam.txt
# Final cleaned and saved: casa_alonso.txt
# Final cleaned and saved: casa_blanca_(san_juan).txt
# Final cleaned and saved: casa_cautiño.txt
# Final cleaned and saved: casa_del_rey.txt
# Final cleaned and saved: casa_de_españa.txt
# Final cleaned and saved: casa_dra._concha_melendez_ramirez.txt
# Final cleaned and saved: casa_fernando_luis_toro.txt
# Final cleaned and saved: casa_font-ubides.txt
# Final cleaned and saved: casa_franceschi_antongiorgi.txt
# Final cleaned and saved: casa_natal_de_luis_muñoz_rivera.txt
# Final cleaned and saved: casa_nemesio_canales.txt
# Final cleaned and saved: casa_oppenheimer.txt
# Final cleaned and saved: casa_paoli.txt
# Final cleaned and saved: casa_pueblo_puerto_rico.txt
# Final cleaned and saved: casa_roig_museum.txt
# Final cleaned and saved: casa_rosa.txt
# Final cleaned and saved: casa_rosita_serrallés.txt
# Final cleaned and saved: casa_salazar-candal.txt
# Final cleaned and saved: casa_serralles.txt
# Final cleaned and saved: casa_wiechers-villaronga.txt
# Final cleaned and saved: casona_césari.txt
# Final cleaned and saved: castillo_san_cristóbal_(san_juan).txt
# Final cleaned and saved: castillo_san_felipe_del_morro.txt
# Final cleaned and saved: castillo_san_felipe_del_morro_lighthouse.txt
# Final cleaned and saved: castillo_serrallés.txt
# Final cleaned and saved: cataño_barrio-pueblo.txt
# Final cleaned and saved: catedral_de_nuestra_señora_de_guadalupe.txt
# Final cleaned and saved: catedral_de_san_felipe_apóstol_(arecibo,_puerto_rico).txt
# Final cleaned and saved: catedral_dulce_nombre_de_jesús_(caguas,_puerto_rico).txt
# Final cleaned and saved: catedral_metropolitana_basílica_de_san_juan_bautista_(san_juan,_puerto_rico).txt
# Final cleaned and saved: cathedral_of_rum.txt
# Final cleaned and saved: cayey_barrio-pueblo.txt
# Final cleaned and saved: cayos_de_caña_gorda.txt
# Final cleaned and saved: cayo_icacos.txt
# Final cleaned and saved: cayo_luis_peña.txt
# Final cleaned and saved: caño_tiburones.txt
# Final cleaned and saved: ceiba_barrio-pueblo.txt
# Final cleaned and saved: cementerio_católico_san_vicente_de_paul.txt
# Final cleaned and saved: cementerio_civil_de_ponce.txt
# Final cleaned and saved: center_for_advanced_studies_on_puerto_rico_and_the_caribbean.txt
# Final cleaned and saved: central_aguirre_historic_district.txt
# Final cleaned and saved: central_cortada.txt
# Final cleaned and saved: central_guánica.txt
# Final cleaned and saved: central_high_school_(san_juan,_puerto_rico).txt
# Final cleaned and saved: centro_ceremonial_indígena_de_tibes.txt
# Final cleaned and saved: centro_cultural_baudilio_vega_berríos.txt
# Final cleaned and saved: centro_cultural_de_ponce_carmen_solá_de_pereira.txt
# Final cleaned and saved: centro_del_sur_mall.txt
# Final cleaned and saved: centro_de_convenciones_de_ponce.txt
# Final cleaned and saved: cerrillos_state_forest.txt
# Final cleaned and saved: cerro_de_punta.txt
# Final cleaned and saved: cerro_las_tetas.txt
# Final cleaned and saved: cerro_maravilla.txt
# Final cleaned and saved: cerro_morales_(utuado,_puerto_rico).txt
# Final cleaned and saved: cerro_rosa.txt
# Final cleaned and saved: cervecería_india.txt
# Final cleaned and saved: chalet_amill.txt
# Final cleaned and saved: christopher_columbus.txt
# Final cleaned and saved: church_of_saint_francis_of_assisi,_san_juan.txt
# Final cleaned and saved: church_of_san_francisco_de_asís.txt
# Final cleaned and saved: church_of_san_mateo_de_cangrejos_of_santurce.txt
# Final cleaned and saved: church_san_blas_de_illescas_of_coamo.txt
# Final cleaned and saved: church_san_josé_of_aibonito.txt
# Final cleaned and saved: church_san_miguel_arcángel_of_utuado.txt
# Final cleaned and saved: ciales_barrio-pueblo.txt
# Final cleaned and saved: cidra_barrio-pueblo.txt
# Final cleaned and saved: ciudad_deportiva_millito_navarro.txt
# Final cleaned and saved: club_deportivo_del_oeste.txt
# Final cleaned and saved: club_nautico_de_ponce.txt
# Final cleaned and saved: club_náutico_de_ponce.txt
# Final cleaned and saved: coamo_barrio-pueblo.txt
# Final cleaned and saved: coca-cola_music_hall.txt
# Final cleaned and saved: colegio_ponceño.txt
# Final cleaned and saved: colegio_san_conrado.txt
# Final cleaned and saved: coliseo_manuel_iguina.txt
# Final cleaned and saved: coliseo_rubén_rodríguez.txt
# Final cleaned and saved: coloso_sugar_cane_refinery.txt
# Final cleaned and saved: comerío_barrio-pueblo.txt
# Final cleaned and saved: complejo_recreativo_y_cultural_la_guancha.txt
# Final cleaned and saved: concatedral_dulce_nombre_de_jesús_(humacao,_puerto_rico).txt
# Final cleaned and saved: condado_(santurce).txt
# Final cleaned and saved: condado_lagoon.txt
# Final cleaned and saved: condado_vanderbilt_hotel.txt
# Final cleaned and saved: conservatory_of_music_of_puerto_rico.txt
# Final cleaned and saved: corozal_barrio-pueblo.txt
# Final cleaned and saved: couroupita_nicaraguarensis.txt
# Final cleaned and saved: crash_boat_beach.txt
# Final cleaned and saved: cruceta_del_vigía.txt
# Final cleaned and saved: cuevas_las_cabachuelas.txt
# Final cleaned and saved: cueva_del_indio_(arecibo).txt
# Final cleaned and saved: cueva_del_indio_(las_piedras).txt
# Final cleaned and saved: cueva_lucero.txt
# Final cleaned and saved: cueva_ventana.txt
# Final cleaned and saved: culebra_barrio-pueblo.txt
# Final cleaned and saved: culebra_national_wildlife_refuge.txt
# Final cleaned and saved: culebrita.txt
# Final cleaned and saved: dead_dog_beach.txt
# Final cleaned and saved: desecheo_national_wildlife_refuge.txt
# Final cleaned and saved: destilería_serrallés.txt
# Final cleaned and saved: district_courthouse_(aguadilla,_puerto_rico).txt
# Final cleaned and saved: domes_beach.txt
# Final cleaned and saved: dorado_barrio-pueblo.txt
# Final cleaned and saved: dos_bocas_lake.txt
# Final cleaned and saved: dos_hermanos_bridge.txt
# Final cleaned and saved: dr._juan_a._rivero_zoo.txt
# Final cleaned and saved: edificio_aboy.txt
# Final cleaned and saved: edificio_comunidad_de_orgullo_gay_de_puerto_rico.txt
# Final cleaned and saved: edificio_del_valle.txt
# Final cleaned and saved: edificio_josé_de_diego.txt
# Final cleaned and saved: edificio_oliver.txt
# Final cleaned and saved: edificio_patio_español.txt
# Final cleaned and saved: edificio_victory_garden.txt
# Final cleaned and saved: el_falansterio_de_puerta_de_tierra.txt
# Final cleaned and saved: el_gigante_dormido.txt
# Final cleaned and saved: el_monumento_de_la_recordación.txt
# Final cleaned and saved: el_parterre.txt
# Final cleaned and saved: el_toro_wilderness.txt
# Final cleaned and saved: el_tuque.txt
# Final cleaned and saved: el_yunque_national_forest.txt
# Final cleaned and saved: enrique_laguerre.txt
# Final cleaned and saved: ensenada_honda_(culebra,_puerto_rico).txt
# Final cleaned and saved: episcopal_cathedral_of_st._john_the_baptist_(san_juan,_puerto_rico).txt
# Final cleaned and saved: ermita_nuestra_señora_de_la_valvanera.txt
# Final cleaned and saved: escuela_brambaugh.txt
# Final cleaned and saved: escuela_de_artes_plásticas_y_diseño_de_puerto_rico.txt
# Final cleaned and saved: esperanza_beach.txt
# Final cleaned and saved: estadio_country_club.txt
# Final cleaned and saved: estadio_francisco_montaner.txt
# Final cleaned and saved: estadio_sixto_escobar.txt
# Final cleaned and saved: fajardo_barrio-pueblo.txt
# Final cleaned and saved: farmers'_market.txt
# Final cleaned and saved: faro_del_puerto_de_ponce.txt
# Final cleaned and saved: faro_de_la_isla_de_caja_de_muertos.txt
# Final cleaned and saved: filardi_house.txt
# Final cleaned and saved: flamenco_beach.txt
# Final cleaned and saved: florida,_puerto_rico.txt
# Final cleaned and saved: fort_buchanan,_puerto_rico.txt
# Final cleaned and saved: fortín_de_san_gerónimo.txt
# Final cleaned and saved: fortín_san_antonio.txt
# Final cleaned and saved: fortín_san_juan_de_la_cruz.txt
# Final cleaned and saved: francisco_oller.txt
# Final cleaned and saved: fuerte_de_la_concepción.txt
# Final cleaned and saved: fuerte_de_vieques.txt
# Final cleaned and saved: galería_nacional.txt
# Final cleaned and saved: gatas_(ponce).txt
# Final cleaned and saved: general_norzagaray_bridge.txt
# Final cleaned and saved: general_store.txt
# Final cleaned and saved: guajataca_lake.txt
# Final cleaned and saved: guajataca_state_forest.txt
# Final cleaned and saved: guajataca_tunnel.txt
# Final cleaned and saved: guavate,_cayey,_puerto_rico.txt
# Final cleaned and saved: guayama_barrio-pueblo.txt
# Final cleaned and saved: guayanilla_barrio-pueblo.txt
# Final cleaned and saved: guaynabo_barrio-pueblo.txt
# Final cleaned and saved: guilarte_state_forest.txt
# Final cleaned and saved: gurabo_barrio-pueblo.txt
# Final cleaned and saved: guánica_barrio-pueblo.txt
# Final cleaned and saved: guánica_light.txt
# Final cleaned and saved: guánica_state_forest.txt
# Final cleaned and saved: gómez_residence.txt
# Final cleaned and saved: hacienda_azucarera_la_esperanza.txt
# Final cleaned and saved: hacienda_buena_vista.txt
# Final cleaned and saved: hacienda_el_jibarito.txt
# Final cleaned and saved: hacienda_juanita.txt
# Final cleaned and saved: hacienda_lealtad.txt
# Final cleaned and saved: hacienda_santa_rita.txt
# Final cleaned and saved: hacienda_san_francisco.txt
# Final cleaned and saved: hatillo_barrio-pueblo.txt
# Final cleaned and saved: henry_klumb_house.txt
# Final cleaned and saved: hermitage_of_san_antonio_de_padua_de_la_tuna.txt
# Final cleaned and saved: hipódromo_camarero.txt
# Final cleaned and saved: hiram_bithorn_stadium.txt
# Final cleaned and saved: hormigueros_barrio-pueblo.txt
# Final cleaned and saved: horse_racing.txt
# Final cleaned and saved: hotel_el_convento.txt
# Final cleaned and saved: hotel_melia.txt
# Final cleaned and saved: hotel_ponce_intercontinental.txt
# Final cleaned and saved: hotel_ponce_ramada.txt
# Final cleaned and saved: house_at_659_concordia_street.txt
# Final cleaned and saved: house_at_659_la_paz_street.txt
# Final cleaned and saved: house_at_663_la_paz_street.txt
# Final cleaned and saved: house_at_665_mckinley_street.txt
# Final cleaned and saved: humacao_barrio-pueblo.txt
# Final cleaned and saved: humacao_nature_reserve.txt
# Final cleaned and saved: húcares.txt
# Final cleaned and saved: iglesia_de_la_santísima_trinidad.txt
# Final cleaned and saved: iglesia_de_nuestra_señora_del_carmen.txt
# Final cleaned and saved: iglesia_de_san_antonio_de_padua.txt
# Final cleaned and saved: iglesia_san_germán_de_auxerre.txt
# Final cleaned and saved: iglesia_san_sebastián_mártir.txt
# Final cleaned and saved: industrias_vassallo.txt
# Final cleaned and saved: institute_of_puerto_rican_culture.txt
# Final cleaned and saved: interamerican_university_of_puerto_rico.txt
# Final cleaned and saved: interamerican_university_of_puerto_rico_at_ponce.txt
# Final cleaned and saved: isabela_barrio-pueblo.txt
# Final cleaned and saved: isabel_ii_barrio-pueblo.txt
# Final cleaned and saved: isla_del_frío.txt
# Final cleaned and saved: isla_de_cabras.txt
# Final cleaned and saved: isla_de_jueyes.txt
# Final cleaned and saved: isla_de_mona.txt
# Final cleaned and saved: isla_de_ratones_(cabo_rojo,_puerto_rico).txt
# Final cleaned and saved: isla_de_ratones_(ponce,_puerto_rico).txt
# Final cleaned and saved: isla_magueyes.txt
# Final cleaned and saved: isla_mata_la_gata.txt
# Final cleaned and saved: isla_palomino.txt
# Final cleaned and saved: isla_verde,_puerto_rico.txt
# Final cleaned and saved: jayuya_barrio-pueblo.txt
# Final cleaned and saved: jesús_izcoa_moure_bridge.txt
# Final cleaned and saved: jesús_t._piñero_house.txt
# Final cleaned and saved: jobos_beach.txt
# Final cleaned and saved: jose_v._toledo_federal_building_and_united_states_courthouse.txt
# Final cleaned and saved: josé_celso_barbosa.txt
# Final cleaned and saved: josé_miguel_agrelot_coliseum.txt
# Final cleaned and saved: joyuda,_puerto_rico.txt
# Final cleaned and saved: joyuda_lagoon.txt
# Final cleaned and saved: juana_díaz_barrio-pueblo.txt
# Final cleaned and saved: juan_boria.txt
# Final cleaned and saved: juan_ramón_loubriel_stadium.txt
# Final cleaned and saved: julia_de_burgos.txt
# Final cleaned and saved: julio_enrique_monagas_park.txt
# Final cleaned and saved: juncos_barrio-pueblo.txt
# Final cleaned and saved: lago_dos_bocas.txt
# Final cleaned and saved: laguna_cartagena_national_wildlife_refuge.txt
# Final cleaned and saved: lajas_barrio-pueblo.txt
# Final cleaned and saved: lake_luchetti.txt
# Final cleaned and saved: lares_barrio-pueblo.txt
# Final cleaned and saved: lares_ice_cream_parlor.txt
# Final cleaned and saved: las_cabañas_bridge.txt
# Final cleaned and saved: las_cascadas_water_park.txt
# Final cleaned and saved: las_catalinas_mall.txt
# Final cleaned and saved: las_marías_barrio-pueblo.txt
# Final cleaned and saved: las_piedras_barrio-pueblo.txt
# Final cleaned and saved: la_bombonera_(san_juan).txt
# Final cleaned and saved: la_concha_renaissance_san_juan_resort.txt
# Final cleaned and saved: la_cordillera_reef_nature_reserve.txt
# Final cleaned and saved: la_fortaleza.txt
# Final cleaned and saved: la_giralda_(san_juan,_puerto_rico).txt
# Final cleaned and saved: la_guancha_(ponce,_puerto_rico).txt
# Final cleaned and saved: la_liendre_bridge.txt
# Final cleaned and saved: la_mallorquina.txt
# Final cleaned and saved: la_parguera.txt
# Final cleaned and saved: la_perla,_san_juan,_puerto_rico.txt
# Final cleaned and saved: la_placita_de_santurce.txt
# Final cleaned and saved: la_plata_lake.txt
# Final cleaned and saved: la_pocita_de_las_golondrinas_beach.txt
# Final cleaned and saved: la_ventana_al_mar.txt
# Final cleaned and saved: lechon.txt
# Final cleaned and saved: legend_of_diego_salcedo.txt
# Final cleaned and saved: letras_de_ponce.txt
# Final cleaned and saved: lin-manuel_miranda.txt
# Final cleaned and saved: logia_masónica_hijos_de_la_luz.txt
# Final cleaned and saved: los_chinos_de_ponce.txt
# Final cleaned and saved: los_morrillos_lighthouse.txt
# Final cleaned and saved: los_tres_picachos.txt
# Final cleaned and saved: los_tres_picachos_state_forest.txt
# Final cleaned and saved: los_túneles_subterráneos_de_san_germán.txt
# Final cleaned and saved: loverbar.txt
# Final cleaned and saved: loíza_barrio-pueblo.txt
# Final cleaned and saved: loíza_lake.txt
# Final cleaned and saved: luis_a._ferré_performing_arts_center.txt
# Final cleaned and saved: luis_a._ferré_united_states_courthouse_and_post_office_building.txt
# Final cleaned and saved: luis_muñoz_marín_international_airport.txt
# Final cleaned and saved: luis_muñoz_marín_park.txt
# Final cleaned and saved: luis_muñoz_rivera_park.txt
# Final cleaned and saved: luquillo_barrio-pueblo.txt
# Final cleaned and saved: luquillo_beach.txt
# Final cleaned and saved: línea_avanzada.txt
# Final cleaned and saved: lópez_residence.txt
# Final cleaned and saved: manatí_barrio-pueblo.txt
# Final cleaned and saved: manatí_bridge_at_mata_de_plátano.txt
# Final cleaned and saved: maricao_barrio-pueblo.txt
# Final cleaned and saved: maricao_fish_hatchery.txt
# Final cleaned and saved: maricao_state_forest.txt
# Final cleaned and saved: mario_morales_coliseum.txt
# Final cleaned and saved: martín_peña_bridge.txt
# Final cleaned and saved: mar_bella_beach.txt
# Final cleaned and saved: maunabo_barrio-pueblo.txt
# Final cleaned and saved: mavilla_bridge.txt
# Final cleaned and saved: mayagüez_barrio-pueblo.txt
# Final cleaned and saved: mayagüez_city_hall.txt
# Final cleaned and saved: mayagüez_resort_&_casino.txt
# Final cleaned and saved: mccabe_memorial_church.txt
# Final cleaned and saved: miramar_(santurce).txt
# Final cleaned and saved: mizpa_pentecostal_university.txt
# Final cleaned and saved: moca_barrio-pueblo.txt
# Final cleaned and saved: mona_ground_iguana.txt
# Final cleaned and saved: monte_jayuya.txt
# Final cleaned and saved: monumento_al_jíbaro_puertorriqueño.txt
# Final cleaned and saved: monumento_a_la_abolición_de_la_exclavitud.txt
# Final cleaned and saved: monumento_a_los_heroes_de_el_polvorín_(obelisk).txt
# Final cleaned and saved: monumento_a_los_heroes_de_el_polvorín_(tomb).txt
# Final cleaned and saved: morovis_barrio-pueblo.txt
# Final cleaned and saved: morovis_national_cemetery.txt
# Final cleaned and saved: morrillito.txt
# Final cleaned and saved: museo_castillo_serrallés.txt
# Final cleaned and saved: museo_del_autonomismo_puertorriqueño.txt
# Final cleaned and saved: museo_de_arte_de_ponce.txt
# Final cleaned and saved: museo_de_la_arquitectura_ponceña.txt
# Final cleaned and saved: museo_de_la_historia_de_ponce.txt
# Final cleaned and saved: museo_de_la_masacre_de_ponce.txt
# Final cleaned and saved: museo_de_la_música_puertorriqueña.txt
# Final cleaned and saved: museo_de_vida_silvestre.txt
# Final cleaned and saved: museum_of_art_of_puerto_rico.txt
# Final cleaned and saved: museum_of_transportation_of_puerto_rico.txt
# Final cleaned and saved: naguabo_barrio-pueblo.txt
# Final cleaned and saved: naranjito_barrio-pueblo.txt
# Final cleaned and saved: normandie_hotel.txt
# Final cleaned and saved: nuestra_señora_de_lourdes_chapel.txt
# Final cleaned and saved: nuevo_milenio_state_forest.txt
# Final cleaned and saved: ocean_park_(santurce).txt
# Final cleaned and saved: old_piedras_river_aqueduct.txt
# Final cleaned and saved: old_san_juan.txt
# Final cleaned and saved: orocovis.txt
# Final cleaned and saved: orocovis_barrio-pueblo.txt
# Final cleaned and saved: orthodox_judaism.txt
# Final cleaned and saved: our_lady_of_lourdes.txt
# Final cleaned and saved: pablo_casals_museum.txt
# Final cleaned and saved: palacete_los_moreau.txt
# Final cleaned and saved: palmas_del_mar.txt
# Final cleaned and saved: panteón_nacional_román_baldorioty_de_castro.txt
# Final cleaned and saved: parque_del_litoral.txt
# Final cleaned and saved: parque_del_retiro.txt
# Final cleaned and saved: parque_del_tricentenario_(ponce,_puerto_rico).txt
# Final cleaned and saved: parque_de_bombas.txt
# Final cleaned and saved: parque_de_bombas_maximiliano_merced.txt
# Final cleaned and saved: parque_de_las_ciencias.txt
# Final cleaned and saved: parque_de_la_abolición.txt
# Final cleaned and saved: parque_de_la_ceiba.txt
# Final cleaned and saved: parque_ecológico_urbano.txt
# Final cleaned and saved: parque_familiar_julio_enrique_monagas.txt
# Final cleaned and saved: parque_lineal_veredas_del_labrador.txt
# Final cleaned and saved: parque_luis_a._wito_morales.txt
# Final cleaned and saved: parque_nacional_de_las_cavernas_del_río_camuy.txt
# Final cleaned and saved: parque_pedro_albizu_campos.txt
# Final cleaned and saved: parque_urbano_dora_colón_clavell.txt
# Final cleaned and saved: parroquia_del_espíritu_santo_y_san_patricio.txt
# Final cleaned and saved: paseo_atocha.txt
# Final cleaned and saved: paseo_de_la_princesa.txt
# Final cleaned and saved: paseo_tablado_la_guancha.txt
# Final cleaned and saved: paseo_víctor_rojas.txt
# Final cleaned and saved: patillas_barrio-pueblo.txt
# Final cleaned and saved: peñuelas_barrio-pueblo.txt
# Final cleaned and saved: pico_piedra.txt
# Final cleaned and saved: pico_rodadero.txt
# Final cleaned and saved: picó_pomar_residence.txt
# Final cleaned and saved: piñones_state_forest.txt
# Final cleaned and saved: playa_espinar.txt
# Final cleaned and saved: playita_del_condado.txt
# Final cleaned and saved: plaza_carolina.txt
# Final cleaned and saved: plaza_colón.txt
# Final cleaned and saved: plaza_colón_(san_juan).txt
# Final cleaned and saved: plaza_degetau.txt
# Final cleaned and saved: plaza_del_caribe.txt
# Final cleaned and saved: plaza_del_mercado_de_ponce.txt
# Final cleaned and saved: plaza_del_norte.txt
# Final cleaned and saved: plaza_del_quinto_centenario.txt
# Final cleaned and saved: plaza_del_sol_(puerto_rico).txt
# Final cleaned and saved: plaza_de_armas,_san_juan.txt
# Final cleaned and saved: plaza_de_la_catedral_(san_juan).txt
# Final cleaned and saved: plaza_de_san_josé.txt
# Final cleaned and saved: plaza_juan_ponce_de_león.txt
# Final cleaned and saved: plaza_las_américas_(puerto_rico).txt
# Final cleaned and saved: plaza_las_delicias.txt
# Final cleaned and saved: plaza_muñoz_rivera.txt
# Final cleaned and saved: plaza_rio_hondo.txt
# Final cleaned and saved: polvorín_de_miraflores.txt
# Final cleaned and saved: polytechnic_university_of_puerto_rico.txt
# Final cleaned and saved: ponce_cement,_inc..txt
# Final cleaned and saved: ponce_city_hall.txt
# Final cleaned and saved: ponce_high_school.txt
# Final cleaned and saved: ponce_historic_zone.txt
# Final cleaned and saved: ponce_school_of_medicine.txt
# Final cleaned and saved: ponce_ymca_building.txt
# Final cleaned and saved: pontificia_universidad_católica_de_puerto_rico.txt
# Final cleaned and saved: porta_coeli_(puerto_rico).txt
# Final cleaned and saved: pozo_de_jacinto.txt
# Final cleaned and saved: primera_iglesia_bautista_de_caguas.txt
# Final cleaned and saved: primera_iglesia_metodista_unida_de_ponce.txt
# Final cleaned and saved: pueblo,_san_juan,_puerto_rico.txt
# Final cleaned and saved: puente_blanco.txt
# Final cleaned and saved: puente_de_coloso.txt
# Final cleaned and saved: puente_de_las_calabazas.txt
# Final cleaned and saved: puente_no._6.txt
# Final cleaned and saved: puerta_de_tierra,_san_juan.txt
# Final cleaned and saved: puerto_del_rey_marina.txt
# Final cleaned and saved: puerto_rico.txt
# Final cleaned and saved: puerto_rico_convention_center.txt
# Final cleaned and saved: puerto_rico_iron_works.txt
# Final cleaned and saved: puerto_rico_museum_of_contemporary_art.txt
# Final cleaned and saved: puerto_rico_national_library.txt
# Final cleaned and saved: punta_borinquen_light.txt
# Final cleaned and saved: punta_de_las_figuras_light.txt
# Final cleaned and saved: punta_higuero_light.txt
# Final cleaned and saved: punta_mulas_light.txt
# Final cleaned and saved: punta_santiago,_humacao,_puerto_rico.txt
# Final cleaned and saved: punta_tuna_light.txt
# Final cleaned and saved: quebradillas_barrio-pueblo.txt
# Final cleaned and saved: rafael_hernández_marín.txt
# Final cleaned and saved: ramón_rivero_(diplo).txt
# Final cleaned and saved: residencia_aboy-lompré.txt
# Final cleaned and saved: residencia_armstrong-poventud.txt
# Final cleaned and saved: residencia_rosaly-batiz.txt
# Final cleaned and saved: residencia_subirá.txt
# Final cleaned and saved: rincón_barrio-pueblo.txt
# Final cleaned and saved: roberto_clemente_coliseum.txt
# Final cleaned and saved: roberto_clemente_stadium.txt
# Final cleaned and saved: roosevelt_roads_naval_station.txt
# Final cleaned and saved: rovira_biscuits_corporation.txt
# Final cleaned and saved: rum.txt
# Final cleaned and saved: rum_planetarium.txt
# Final cleaned and saved: río_abajo_state_forest.txt
# Final cleaned and saved: río_grande_barrio-pueblo.txt
# Final cleaned and saved: río_grande_de_loíza.txt
# Final cleaned and saved: río_matón_bridge.txt
# Final cleaned and saved: río_piedras_bridge.txt
# Final cleaned and saved: sabana_grande_barrio-pueblo.txt
# Final cleaned and saved: sabana_grande_masonic_cemetery.txt
# Final cleaned and saved: saint_john's_school_(san_juan).txt
# Final cleaned and saved: saliente_river.txt
# Final cleaned and saved: salinas_barrio-pueblo.txt
# Final cleaned and saved: samuel_morse.txt
# Final cleaned and saved: santa_ana_church_(san_juan).txt
# Final cleaned and saved: santa_isabel_barrio-pueblo.txt
# Final cleaned and saved: santa_maría_magdalena_de_pazzis_cemetery.txt
# Final cleaned and saved: santurce,_san_juan,_puerto_rico.txt
# Final cleaned and saved: san_cristóbal_canyon.txt
# Final cleaned and saved: san_germán_historic_district.txt
# Final cleaned and saved: san_josé_church.txt
# Final cleaned and saved: san_juan_botanical_garden.txt
# Final cleaned and saved: san_juan_city_hall.txt
# Final cleaned and saved: san_juan_marriott_resort_&_stellaris_casino.txt
# Final cleaned and saved: san_juan_natatorium.txt
# Final cleaned and saved: san_juan_puerto_rico_temple.txt
# Final cleaned and saved: san_lorenzo_barrio-pueblo.txt
# Final cleaned and saved: san_miguel_arcángel_church_(cabo_rojo).txt
# Final cleaned and saved: san_patricio_plaza.txt
# Final cleaned and saved: san_patricio_state_forest.txt
# Final cleaned and saved: san_sebastián_barrio-pueblo.txt
# Final cleaned and saved: school_of_tropical_medicine_(puerto_rico).txt
# Final cleaned and saved: sixto_escobar.txt
# Final cleaned and saved: stud_farm.txt
# Final cleaned and saved: supreme_court_building_(puerto_rico).txt
# Final cleaned and saved: susúa_state_forest.txt
# Final cleaned and saved: t-mobile_district.txt
# Final cleaned and saved: teatro_fox_delicias.txt
# Final cleaned and saved: teatro_la_perla.txt
# Final cleaned and saved: teatro_tapia.txt
# Final cleaned and saved: teatro_yagüez.txt
# Final cleaned and saved: teodoro_moscoso_bridge.txt
# Final cleaned and saved: the_mall_of_san_juan.txt
# Final cleaned and saved: tito_puente_amphitheatre.txt
# Final cleaned and saved: toa_alta_barrio-pueblo.txt
# Final cleaned and saved: toa_baja_barrio-pueblo.txt
# Final cleaned and saved: toro_negro_state_forest.txt
# Final cleaned and saved: tortuguero_lagoon.txt
# Final cleaned and saved: train_of_the_south.txt
# Final cleaned and saved: trujillo_alto_barrio-pueblo.txt
# Final cleaned and saved: u.s._custom_house_(san_juan,_puerto_rico).txt
# Final cleaned and saved: u.s._post_office_and_courthouse_(mayagüez,_puerto_rico).txt
# Final cleaned and saved: united_states_customs_house_(fajardo,_puerto_rico).txt
# Final cleaned and saved: united_states_customs_house_(ponce,_puerto_rico).txt
# Final cleaned and saved: united_states_district_court_for_the_district_of_puerto_rico.txt
# Final cleaned and saved: universidad_del_sagrado_corazón.txt
# Final cleaned and saved: university_gardens_high_school.txt
# Final cleaned and saved: university_high_school_(san_juan).txt
# Final cleaned and saved: university_of_puerto_rico,_medical_sciences_campus.txt
# Final cleaned and saved: university_of_puerto_rico,_río_piedras_campus.txt
# Final cleaned and saved: university_of_puerto_rico_at_cayey.txt
# Final cleaned and saved: university_of_puerto_rico_at_humacao.txt
# Final cleaned and saved: university_of_puerto_rico_at_mayagüez.txt
# Final cleaned and saved: university_of_puerto_rico_at_ponce.txt
# Final cleaned and saved: university_of_puerto_rico_school_of_medicine.txt
# Final cleaned and saved: uss_killen_(dd-593).txt
# Final cleaned and saved: utuado_barrio-pueblo.txt
# Final cleaned and saved: vega_alta_barrio-pueblo.txt
# Final cleaned and saved: vega_baja_barrio-pueblo.txt
# Final cleaned and saved: vega_state_forest.txt
# Final cleaned and saved: vieques_national_wildlife_refuge.txt
# Final cleaned and saved: villalba,_puerto_rico.txt
# Final cleaned and saved: villalba_barrio-pueblo.txt
# Final cleaned and saved: villa_pesquera.txt
# Final cleaned and saved: west_indian_manatee.txt
# Final cleaned and saved: whale_watching.txt
# Final cleaned and saved: william_miranda_marín_botanical_and_cultural_garden.txt
# Final cleaned and saved: world_war_ii.txt
# Final cleaned and saved: yabucoa_barrio-pueblo.txt
# Final cleaned and saved: yauco_barrio-pueblo.txt
# Final cleaned and saved: zona_historica_de_ponce.txt

# %% [markdown]
# # **Step 4: Removal of links references**

# %%
import os
import json
import re

# Define directories
cleaned_data_path = r"C:\\Users\\larry\\OneDrive\\Documents\\GitHub\\project-aieng-interactive-travel-planner\\data\\landmarks_cleanng\\step3_cleaned_data"
final_data_path = r"C:\\Users\\larry\\OneDrive\\Documents\\GitHub\\project-aieng-interactive-travel-planner\\data\\landmarks_cleanng\\final_step_cleaned_data"

# Create output directory if it doesn't exist
if not os.path.exists(final_data_path):
    os.makedirs(final_data_path)

# Function to clean the relevant_links list
def clean_relevant_links(links):
    unique_links = list(set(links))  # Remove duplicates
    return unique_links

# Function to remove reference numbers like [3], [15], etc.
def remove_reference_numbers(text):
    return re.sub(r"\[ \d+\ ]", "", text)

# Process each file in cleaned_data
for file in os.listdir(cleaned_data_path):
    file_path = os.path.join(cleaned_data_path, file)

    with open(file_path, "r", encoding="utf-8") as f:
        content = json.load(f)

    # Clean the relevant_links
    if "relevant_links" in content:
        content["relevant_links"] = clean_relevant_links(content["relevant_links"])

    # Remove reference numbers from main content
    if "main_content" in content:
        content["main_content"] = remove_reference_numbers(content["main_content"])

    # Save the final cleaned content
    output_file_path = os.path.join(final_data_path, file)
    with open(output_file_path, "w", encoding="utf-8") as out_file:
        json.dump(content, out_file, indent=4, ensure_ascii=False)

    print(f"Final cleaned file saved: {file}")
# Out:
# Final cleaned file saved: academia_del_perpetuo_socorro.txt
# Final cleaned file saved: academia_interamericana_metro.txt
# Final cleaned file saved: academia_maria_reina.txt
# Final cleaned file saved: academia_san_jorge.txt
# Final cleaned file saved: adjuntas_barrio-pueblo.txt
# Final cleaned file saved: aguada_barrio-pueblo.txt
# Final cleaned file saved: aguada_transmission_station.txt
# Final cleaned file saved: aguadilla_barrio-pueblo.txt
# Final cleaned file saved: aguadilla_ice_skating_arena.txt
# Final cleaned file saved: aguas_buenas_barrio-pueblo.txt
# Final cleaned file saved: aguas_buenas_cave_system.txt
# Final cleaned file saved: aguirre_state_forest.txt
# Final cleaned file saved: aibonito_barrio-pueblo.txt
# Final cleaned file saved: aibonito_festival_of_flowers.txt
# Final cleaned file saved: albergue_olímpico.txt
# Final cleaned file saved: albizu_university.txt
# Final cleaned file saved: ana_g._méndez_university.txt
# Final cleaned file saved: antiguo_casino_de_ponce.txt
# Final cleaned file saved: antiguo_cuartel_militar_español_de_ponce.txt
# Final cleaned file saved: antiguo_hospital_militar_español_de_ponce.txt
# Final cleaned file saved: archivo_general_de_puerto_rico.txt
# Final cleaned file saved: arecibo_barrio-pueblo.txt
# Final cleaned file saved: arecibo_light.txt
# Final cleaned file saved: arecibo_observatory.txt
# Final cleaned file saved: arecibo_telescope.txt
# Final cleaned file saved: arenas_bridge.txt
# Final cleaned file saved: arroyo_barrio-pueblo.txt
# Final cleaned file saved: asilo_de_pobres.txt
# Final cleaned file saved: ateneo_puertorriqueño.txt
# Final cleaned file saved: auditorio_juan_pachín_vicéns.txt
# Final cleaned file saved: añasco_barrio-pueblo.txt
# Final cleaned file saved: bacardi.txt
# Final cleaned file saved: bahía_de_jobos.txt
# Final cleaned file saved: ballajá_barracks.txt
# Final cleaned file saved: balneario_de_rincón.txt
# Final cleaned file saved: banco_crédito_y_ahorro_ponceño_(building).txt
# Final cleaned file saved: banco_de_ponce_(building).txt
# Final cleaned file saved: barceloneta_barrio-pueblo.txt
# Final cleaned file saved: barranquitas_barrio-pueblo.txt
# Final cleaned file saved: basílica_menor_de_la_virgen_de_monserrate.txt
# Final cleaned file saved: bayamón_barrio-pueblo.txt
# Final cleaned file saved: bayamón_city_hall.txt
# Final cleaned file saved: bayamón_river.txt
# Final cleaned file saved: baños_de_coamo.txt
# Final cleaned file saved: biblical_magi.txt
# Final cleaned file saved: biblioteca_carnegie.txt
# Final cleaned file saved: biblioteca_municipal_de_ponce.txt
# Final cleaned file saved: birth_of_the_new_world.txt
# Final cleaned file saved: black_sand.txt
# Final cleaned file saved: blue_beach_(vieques).txt
# Final cleaned file saved: bobbin_lace.txt
# Final cleaned file saved: bolera_caribe.txt
# Final cleaned file saved: boquerón,_cabo_rojo,_puerto_rico.txt
# Final cleaned file saved: boquerón_state_forest.txt
# Final cleaned file saved: braulio_castillo.txt
# Final cleaned file saved: buyé_beach.txt
# Final cleaned file saved: cabo_rojo_barrio-pueblo.txt
# Final cleaned file saved: cabo_rojo_national_wildlife_refuge.txt
# Final cleaned file saved: café_rico.txt
# Final cleaned file saved: caguana_ceremonial_ball_courts_site.txt
# Final cleaned file saved: caguas_barrio-pueblo.txt
# Final cleaned file saved: caguas_city_hall.txt
# Final cleaned file saved: caguas_museum_of_art.txt
# Final cleaned file saved: caguas_museum_of_folk_arts.txt
# Final cleaned file saved: caguas_museum_of_tobacco.txt
# Final cleaned file saved: caguas_valley.txt
# Final cleaned file saved: caja_de_muertos.txt
# Final cleaned file saved: calle_25_de_enero.txt
# Final cleaned file saved: cambalache_forest_reserve.txt
# Final cleaned file saved: campamento_santiago.txt
# Final cleaned file saved: campo_atlético_charles_h._terry.txt
# Final cleaned file saved: camuy_barrio-pueblo.txt
# Final cleaned file saved: camuy_river.txt
# Final cleaned file saved: canóvanas_barrio-pueblo.txt
# Final cleaned file saved: caparra_archaeological_site.txt
# Final cleaned file saved: cape_san_juan_light.txt
# Final cleaned file saved: capilla_del_cristo.txt
# Final cleaned file saved: capitol_of_puerto_rico.txt
# Final cleaned file saved: caracas_beach_(vieques).txt
# Final cleaned file saved: cardona_(ponce).txt
# Final cleaned file saved: cardona_residence.txt
# Final cleaned file saved: caribe_hilton_hotel.txt
# Final cleaned file saved: carite_lake.txt
# Final cleaned file saved: carite_state_forest.txt
# Final cleaned file saved: carolina_barrio-pueblo.txt
# Final cleaned file saved: carraízo_dam.txt
# Final cleaned file saved: casa_alonso.txt
# Final cleaned file saved: casa_blanca_(san_juan).txt
# Final cleaned file saved: casa_cautiño.txt
# Final cleaned file saved: casa_del_rey.txt
# Final cleaned file saved: casa_de_españa.txt
# Final cleaned file saved: casa_dra._concha_melendez_ramirez.txt
# Final cleaned file saved: casa_fernando_luis_toro.txt
# Final cleaned file saved: casa_font-ubides.txt
# Final cleaned file saved: casa_franceschi_antongiorgi.txt
# Final cleaned file saved: casa_natal_de_luis_muñoz_rivera.txt
# Final cleaned file saved: casa_nemesio_canales.txt
# Final cleaned file saved: casa_oppenheimer.txt
# Final cleaned file saved: casa_paoli.txt
# Final cleaned file saved: casa_pueblo_puerto_rico.txt
# Final cleaned file saved: casa_roig_museum.txt
# Final cleaned file saved: casa_rosa.txt
# Final cleaned file saved: casa_rosita_serrallés.txt
# Final cleaned file saved: casa_salazar-candal.txt
# Final cleaned file saved: casa_serralles.txt
# Final cleaned file saved: casa_wiechers-villaronga.txt
# Final cleaned file saved: casona_césari.txt
# Final cleaned file saved: castillo_san_cristóbal_(san_juan).txt
# Final cleaned file saved: castillo_san_felipe_del_morro.txt
# Final cleaned file saved: castillo_san_felipe_del_morro_lighthouse.txt
# Final cleaned file saved: castillo_serrallés.txt
# Final cleaned file saved: cataño_barrio-pueblo.txt
# Final cleaned file saved: catedral_de_nuestra_señora_de_guadalupe.txt
# Final cleaned file saved: catedral_de_san_felipe_apóstol_(arecibo,_puerto_rico).txt
# Final cleaned file saved: catedral_dulce_nombre_de_jesús_(caguas,_puerto_rico).txt
# Final cleaned file saved: catedral_metropolitana_basílica_de_san_juan_bautista_(san_juan,_puerto_rico).txt
# Final cleaned file saved: cathedral_of_rum.txt
# Final cleaned file saved: cayey_barrio-pueblo.txt
# Final cleaned file saved: cayos_de_caña_gorda.txt
# Final cleaned file saved: cayo_icacos.txt
# Final cleaned file saved: cayo_luis_peña.txt
# Final cleaned file saved: caño_tiburones.txt
# Final cleaned file saved: ceiba_barrio-pueblo.txt
# Final cleaned file saved: cementerio_católico_san_vicente_de_paul.txt
# Final cleaned file saved: cementerio_civil_de_ponce.txt
# Final cleaned file saved: center_for_advanced_studies_on_puerto_rico_and_the_caribbean.txt
# Final cleaned file saved: central_aguirre_historic_district.txt
# Final cleaned file saved: central_cortada.txt
# Final cleaned file saved: central_guánica.txt
# Final cleaned file saved: central_high_school_(san_juan,_puerto_rico).txt
# Final cleaned file saved: centro_ceremonial_indígena_de_tibes.txt
# Final cleaned file saved: centro_cultural_baudilio_vega_berríos.txt
# Final cleaned file saved: centro_cultural_de_ponce_carmen_solá_de_pereira.txt
# Final cleaned file saved: centro_del_sur_mall.txt
# Final cleaned file saved: centro_de_convenciones_de_ponce.txt
# Final cleaned file saved: cerrillos_state_forest.txt
# Final cleaned file saved: cerro_de_punta.txt
# Final cleaned file saved: cerro_las_tetas.txt
# Final cleaned file saved: cerro_maravilla.txt
# Final cleaned file saved: cerro_morales_(utuado,_puerto_rico).txt
# Final cleaned file saved: cerro_rosa.txt
# Final cleaned file saved: cervecería_india.txt
# Final cleaned file saved: chalet_amill.txt
# Final cleaned file saved: christopher_columbus.txt
# Final cleaned file saved: church_of_saint_francis_of_assisi,_san_juan.txt
# Final cleaned file saved: church_of_san_francisco_de_asís.txt
# Final cleaned file saved: church_of_san_mateo_de_cangrejos_of_santurce.txt
# Final cleaned file saved: church_san_blas_de_illescas_of_coamo.txt
# Final cleaned file saved: church_san_josé_of_aibonito.txt
# Final cleaned file saved: church_san_miguel_arcángel_of_utuado.txt
# Final cleaned file saved: ciales_barrio-pueblo.txt
# Final cleaned file saved: cidra_barrio-pueblo.txt
# Final cleaned file saved: ciudad_deportiva_millito_navarro.txt
# Final cleaned file saved: club_deportivo_del_oeste.txt
# Final cleaned file saved: club_nautico_de_ponce.txt
# Final cleaned file saved: club_náutico_de_ponce.txt
# Final cleaned file saved: coamo_barrio-pueblo.txt
# Final cleaned file saved: coca-cola_music_hall.txt
# Final cleaned file saved: colegio_ponceño.txt
# Final cleaned file saved: colegio_san_conrado.txt
# Final cleaned file saved: coliseo_manuel_iguina.txt
# Final cleaned file saved: coliseo_rubén_rodríguez.txt
# Final cleaned file saved: coloso_sugar_cane_refinery.txt
# Final cleaned file saved: comerío_barrio-pueblo.txt
# Final cleaned file saved: complejo_recreativo_y_cultural_la_guancha.txt
# Final cleaned file saved: concatedral_dulce_nombre_de_jesús_(humacao,_puerto_rico).txt
# Final cleaned file saved: condado_(santurce).txt
# Final cleaned file saved: condado_lagoon.txt
# Final cleaned file saved: condado_vanderbilt_hotel.txt
# Final cleaned file saved: conservatory_of_music_of_puerto_rico.txt
# Final cleaned file saved: corozal_barrio-pueblo.txt
# Final cleaned file saved: couroupita_nicaraguarensis.txt
# Final cleaned file saved: crash_boat_beach.txt
# Final cleaned file saved: cruceta_del_vigía.txt
# Final cleaned file saved: cuevas_las_cabachuelas.txt
# Final cleaned file saved: cueva_del_indio_(arecibo).txt
# Final cleaned file saved: cueva_del_indio_(las_piedras).txt
# Final cleaned file saved: cueva_lucero.txt
# Final cleaned file saved: cueva_ventana.txt
# Final cleaned file saved: culebra_barrio-pueblo.txt
# Final cleaned file saved: culebra_national_wildlife_refuge.txt
# Final cleaned file saved: culebrita.txt
# Final cleaned file saved: dead_dog_beach.txt
# Final cleaned file saved: desecheo_national_wildlife_refuge.txt
# Final cleaned file saved: destilería_serrallés.txt
# Final cleaned file saved: district_courthouse_(aguadilla,_puerto_rico).txt
# Final cleaned file saved: domes_beach.txt
# Final cleaned file saved: dorado_barrio-pueblo.txt
# Final cleaned file saved: dos_bocas_lake.txt
# Final cleaned file saved: dos_hermanos_bridge.txt
# Final cleaned file saved: dr._juan_a._rivero_zoo.txt
# Final cleaned file saved: edificio_aboy.txt
# Final cleaned file saved: edificio_comunidad_de_orgullo_gay_de_puerto_rico.txt
# Final cleaned file saved: edificio_del_valle.txt
# Final cleaned file saved: edificio_josé_de_diego.txt
# Final cleaned file saved: edificio_oliver.txt
# Final cleaned file saved: edificio_patio_español.txt
# Final cleaned file saved: edificio_victory_garden.txt
# Final cleaned file saved: el_falansterio_de_puerta_de_tierra.txt
# Final cleaned file saved: el_gigante_dormido.txt
# Final cleaned file saved: el_monumento_de_la_recordación.txt
# Final cleaned file saved: el_parterre.txt
# Final cleaned file saved: el_toro_wilderness.txt
# Final cleaned file saved: el_tuque.txt
# Final cleaned file saved: el_yunque_national_forest.txt
# Final cleaned file saved: enrique_laguerre.txt
# Final cleaned file saved: ensenada_honda_(culebra,_puerto_rico).txt
# Final cleaned file saved: episcopal_cathedral_of_st._john_the_baptist_(san_juan,_puerto_rico).txt
# Final cleaned file saved: ermita_nuestra_señora_de_la_valvanera.txt
# Final cleaned file saved: escuela_brambaugh.txt
# Final cleaned file saved: escuela_de_artes_plásticas_y_diseño_de_puerto_rico.txt
# Final cleaned file saved: esperanza_beach.txt
# Final cleaned file saved: estadio_country_club.txt
# Final cleaned file saved: estadio_francisco_montaner.txt
# Final cleaned file saved: estadio_sixto_escobar.txt
# Final cleaned file saved: fajardo_barrio-pueblo.txt
# Final cleaned file saved: farmers'_market.txt
# Final cleaned file saved: faro_del_puerto_de_ponce.txt
# Final cleaned file saved: faro_de_la_isla_de_caja_de_muertos.txt
# Final cleaned file saved: filardi_house.txt
# Final cleaned file saved: flamenco_beach.txt
# Final cleaned file saved: florida,_puerto_rico.txt
# Final cleaned file saved: fort_buchanan,_puerto_rico.txt
# Final cleaned file saved: fortín_de_san_gerónimo.txt
# Final cleaned file saved: fortín_san_antonio.txt
# Final cleaned file saved: fortín_san_juan_de_la_cruz.txt
# Final cleaned file saved: francisco_oller.txt
# Final cleaned file saved: fuerte_de_la_concepción.txt
# Final cleaned file saved: fuerte_de_vieques.txt
# Final cleaned file saved: galería_nacional.txt
# Final cleaned file saved: gatas_(ponce).txt
# Final cleaned file saved: general_norzagaray_bridge.txt
# Final cleaned file saved: general_store.txt
# Final cleaned file saved: guajataca_lake.txt
# Final cleaned file saved: guajataca_state_forest.txt
# Final cleaned file saved: guajataca_tunnel.txt
# Final cleaned file saved: guavate,_cayey,_puerto_rico.txt
# Final cleaned file saved: guayama_barrio-pueblo.txt
# Final cleaned file saved: guayanilla_barrio-pueblo.txt
# Final cleaned file saved: guaynabo_barrio-pueblo.txt
# Final cleaned file saved: guilarte_state_forest.txt
# Final cleaned file saved: gurabo_barrio-pueblo.txt
# Final cleaned file saved: guánica_barrio-pueblo.txt
# Final cleaned file saved: guánica_light.txt
# Final cleaned file saved: guánica_state_forest.txt
# Final cleaned file saved: gómez_residence.txt
# Final cleaned file saved: hacienda_azucarera_la_esperanza.txt
# Final cleaned file saved: hacienda_buena_vista.txt
# Final cleaned file saved: hacienda_el_jibarito.txt
# Final cleaned file saved: hacienda_juanita.txt
# Final cleaned file saved: hacienda_lealtad.txt
# Final cleaned file saved: hacienda_santa_rita.txt
# Final cleaned file saved: hacienda_san_francisco.txt
# Final cleaned file saved: hatillo_barrio-pueblo.txt
# Final cleaned file saved: henry_klumb_house.txt
# Final cleaned file saved: hermitage_of_san_antonio_de_padua_de_la_tuna.txt
# Final cleaned file saved: hipódromo_camarero.txt
# Final cleaned file saved: hiram_bithorn_stadium.txt
# Final cleaned file saved: hormigueros_barrio-pueblo.txt
# Final cleaned file saved: horse_racing.txt
# Final cleaned file saved: hotel_el_convento.txt
# Final cleaned file saved: hotel_melia.txt
# Final cleaned file saved: hotel_ponce_intercontinental.txt
# Final cleaned file saved: hotel_ponce_ramada.txt
# Final cleaned file saved: house_at_659_concordia_street.txt
# Final cleaned file saved: house_at_659_la_paz_street.txt
# Final cleaned file saved: house_at_663_la_paz_street.txt
# Final cleaned file saved: house_at_665_mckinley_street.txt
# Final cleaned file saved: humacao_barrio-pueblo.txt
# Final cleaned file saved: humacao_nature_reserve.txt
# Final cleaned file saved: húcares.txt
# Final cleaned file saved: iglesia_de_la_santísima_trinidad.txt
# Final cleaned file saved: iglesia_de_nuestra_señora_del_carmen.txt
# Final cleaned file saved: iglesia_de_san_antonio_de_padua.txt
# Final cleaned file saved: iglesia_san_germán_de_auxerre.txt
# Final cleaned file saved: iglesia_san_sebastián_mártir.txt
# Final cleaned file saved: industrias_vassallo.txt
# Final cleaned file saved: institute_of_puerto_rican_culture.txt
# Final cleaned file saved: interamerican_university_of_puerto_rico.txt
# Final cleaned file saved: interamerican_university_of_puerto_rico_at_ponce.txt
# Final cleaned file saved: isabela_barrio-pueblo.txt
# Final cleaned file saved: isabel_ii_barrio-pueblo.txt
# Final cleaned file saved: isla_del_frío.txt
# Final cleaned file saved: isla_de_cabras.txt
# Final cleaned file saved: isla_de_jueyes.txt
# Final cleaned file saved: isla_de_mona.txt
# Final cleaned file saved: isla_de_ratones_(cabo_rojo,_puerto_rico).txt
# Final cleaned file saved: isla_de_ratones_(ponce,_puerto_rico).txt
# Final cleaned file saved: isla_magueyes.txt
# Final cleaned file saved: isla_mata_la_gata.txt
# Final cleaned file saved: isla_palomino.txt
# Final cleaned file saved: isla_verde,_puerto_rico.txt
# Final cleaned file saved: jayuya_barrio-pueblo.txt
# Final cleaned file saved: jesús_izcoa_moure_bridge.txt
# Final cleaned file saved: jesús_t._piñero_house.txt
# Final cleaned file saved: jobos_beach.txt
# Final cleaned file saved: jose_v._toledo_federal_building_and_united_states_courthouse.txt
# Final cleaned file saved: josé_celso_barbosa.txt
# Final cleaned file saved: josé_miguel_agrelot_coliseum.txt
# Final cleaned file saved: joyuda,_puerto_rico.txt
# Final cleaned file saved: joyuda_lagoon.txt
# Final cleaned file saved: juana_díaz_barrio-pueblo.txt
# Final cleaned file saved: juan_boria.txt
# Final cleaned file saved: juan_ramón_loubriel_stadium.txt
# Final cleaned file saved: julia_de_burgos.txt
# Final cleaned file saved: julio_enrique_monagas_park.txt
# Final cleaned file saved: juncos_barrio-pueblo.txt
# Final cleaned file saved: lago_dos_bocas.txt
# Final cleaned file saved: laguna_cartagena_national_wildlife_refuge.txt
# Final cleaned file saved: lajas_barrio-pueblo.txt
# Final cleaned file saved: lake_luchetti.txt
# Final cleaned file saved: lares_barrio-pueblo.txt
# Final cleaned file saved: lares_ice_cream_parlor.txt
# Final cleaned file saved: las_cabañas_bridge.txt
# Final cleaned file saved: las_cascadas_water_park.txt
# Final cleaned file saved: las_catalinas_mall.txt
# Final cleaned file saved: las_marías_barrio-pueblo.txt
# Final cleaned file saved: las_piedras_barrio-pueblo.txt
# Final cleaned file saved: la_bombonera_(san_juan).txt
# Final cleaned file saved: la_concha_renaissance_san_juan_resort.txt
# Final cleaned file saved: la_cordillera_reef_nature_reserve.txt
# Final cleaned file saved: la_fortaleza.txt
# Final cleaned file saved: la_giralda_(san_juan,_puerto_rico).txt
# Final cleaned file saved: la_guancha_(ponce,_puerto_rico).txt
# Final cleaned file saved: la_liendre_bridge.txt
# Final cleaned file saved: la_mallorquina.txt
# Final cleaned file saved: la_parguera.txt
# Final cleaned file saved: la_perla,_san_juan,_puerto_rico.txt
# Final cleaned file saved: la_placita_de_santurce.txt
# Final cleaned file saved: la_plata_lake.txt
# Final cleaned file saved: la_pocita_de_las_golondrinas_beach.txt
# Final cleaned file saved: la_ventana_al_mar.txt
# Final cleaned file saved: lechon.txt
# Final cleaned file saved: legend_of_diego_salcedo.txt
# Final cleaned file saved: letras_de_ponce.txt
# Final cleaned file saved: lin-manuel_miranda.txt
# Final cleaned file saved: logia_masónica_hijos_de_la_luz.txt
# Final cleaned file saved: los_chinos_de_ponce.txt
# Final cleaned file saved: los_morrillos_lighthouse.txt
# Final cleaned file saved: los_tres_picachos.txt
# Final cleaned file saved: los_tres_picachos_state_forest.txt
# Final cleaned file saved: los_túneles_subterráneos_de_san_germán.txt
# Final cleaned file saved: loverbar.txt
# Final cleaned file saved: loíza_barrio-pueblo.txt
# Final cleaned file saved: loíza_lake.txt
# Final cleaned file saved: luis_a._ferré_performing_arts_center.txt
# Final cleaned file saved: luis_a._ferré_united_states_courthouse_and_post_office_building.txt
# Final cleaned file saved: luis_muñoz_marín_international_airport.txt
# Final cleaned file saved: luis_muñoz_marín_park.txt
# Final cleaned file saved: luis_muñoz_rivera_park.txt
# Final cleaned file saved: luquillo_barrio-pueblo.txt
# Final cleaned file saved: luquillo_beach.txt
# Final cleaned file saved: línea_avanzada.txt
# Final cleaned file saved: lópez_residence.txt
# Final cleaned file saved: manatí_barrio-pueblo.txt
# Final cleaned file saved: manatí_bridge_at_mata_de_plátano.txt
# Final cleaned file saved: maricao_barrio-pueblo.txt
# Final cleaned file saved: maricao_fish_hatchery.txt
# Final cleaned file saved: maricao_state_forest.txt
# Final cleaned file saved: mario_morales_coliseum.txt
# Final cleaned file saved: martín_peña_bridge.txt
# Final cleaned file saved: mar_bella_beach.txt
# Final cleaned file saved: maunabo_barrio-pueblo.txt
# Final cleaned file saved: mavilla_bridge.txt
# Final cleaned file saved: mayagüez_barrio-pueblo.txt
# Final cleaned file saved: mayagüez_city_hall.txt
# Final cleaned file saved: mayagüez_resort_&_casino.txt
# Final cleaned file saved: mccabe_memorial_church.txt
# Final cleaned file saved: miramar_(santurce).txt
# Final cleaned file saved: mizpa_pentecostal_university.txt
# Final cleaned file saved: moca_barrio-pueblo.txt
# Final cleaned file saved: mona_ground_iguana.txt
# Final cleaned file saved: monte_jayuya.txt
# Final cleaned file saved: monumento_al_jíbaro_puertorriqueño.txt
# Final cleaned file saved: monumento_a_la_abolición_de_la_exclavitud.txt
# Final cleaned file saved: monumento_a_los_heroes_de_el_polvorín_(obelisk).txt
# Final cleaned file saved: monumento_a_los_heroes_de_el_polvorín_(tomb).txt
# Final cleaned file saved: morovis_barrio-pueblo.txt
# Final cleaned file saved: morovis_national_cemetery.txt
# Final cleaned file saved: morrillito.txt
# Final cleaned file saved: museo_castillo_serrallés.txt
# Final cleaned file saved: museo_del_autonomismo_puertorriqueño.txt
# Final cleaned file saved: museo_de_arte_de_ponce.txt
# Final cleaned file saved: museo_de_la_arquitectura_ponceña.txt
# Final cleaned file saved: museo_de_la_historia_de_ponce.txt
# Final cleaned file saved: museo_de_la_masacre_de_ponce.txt
# Final cleaned file saved: museo_de_la_música_puertorriqueña.txt
# Final cleaned file saved: museo_de_vida_silvestre.txt
# Final cleaned file saved: museum_of_art_of_puerto_rico.txt
# Final cleaned file saved: museum_of_transportation_of_puerto_rico.txt
# Final cleaned file saved: naguabo_barrio-pueblo.txt
# Final cleaned file saved: naranjito_barrio-pueblo.txt
# Final cleaned file saved: normandie_hotel.txt
# Final cleaned file saved: nuestra_señora_de_lourdes_chapel.txt
# Final cleaned file saved: nuevo_milenio_state_forest.txt
# Final cleaned file saved: ocean_park_(santurce).txt
# Final cleaned file saved: old_piedras_river_aqueduct.txt
# Final cleaned file saved: old_san_juan.txt
# Final cleaned file saved: orocovis.txt
# Final cleaned file saved: orocovis_barrio-pueblo.txt
# Final cleaned file saved: orthodox_judaism.txt
# Final cleaned file saved: our_lady_of_lourdes.txt
# Final cleaned file saved: pablo_casals_museum.txt
# Final cleaned file saved: palacete_los_moreau.txt
# Final cleaned file saved: palmas_del_mar.txt
# Final cleaned file saved: panteón_nacional_román_baldorioty_de_castro.txt
# Final cleaned file saved: parque_del_litoral.txt
# Final cleaned file saved: parque_del_retiro.txt
# Final cleaned file saved: parque_del_tricentenario_(ponce,_puerto_rico).txt
# Final cleaned file saved: parque_de_bombas.txt
# Final cleaned file saved: parque_de_bombas_maximiliano_merced.txt
# Final cleaned file saved: parque_de_las_ciencias.txt
# Final cleaned file saved: parque_de_la_abolición.txt
# Final cleaned file saved: parque_de_la_ceiba.txt
# Final cleaned file saved: parque_ecológico_urbano.txt
# Final cleaned file saved: parque_familiar_julio_enrique_monagas.txt
# Final cleaned file saved: parque_lineal_veredas_del_labrador.txt
# Final cleaned file saved: parque_luis_a._wito_morales.txt
# Final cleaned file saved: parque_nacional_de_las_cavernas_del_río_camuy.txt
# Final cleaned file saved: parque_pedro_albizu_campos.txt
# Final cleaned file saved: parque_urbano_dora_colón_clavell.txt
# Final cleaned file saved: parroquia_del_espíritu_santo_y_san_patricio.txt
# Final cleaned file saved: paseo_atocha.txt
# Final cleaned file saved: paseo_de_la_princesa.txt
# Final cleaned file saved: paseo_tablado_la_guancha.txt
# Final cleaned file saved: paseo_víctor_rojas.txt
# Final cleaned file saved: patillas_barrio-pueblo.txt
# Final cleaned file saved: peñuelas_barrio-pueblo.txt
# Final cleaned file saved: pico_piedra.txt
# Final cleaned file saved: pico_rodadero.txt
# Final cleaned file saved: picó_pomar_residence.txt
# Final cleaned file saved: piñones_state_forest.txt
# Final cleaned file saved: playa_espinar.txt
# Final cleaned file saved: playita_del_condado.txt
# Final cleaned file saved: plaza_carolina.txt
# Final cleaned file saved: plaza_colón.txt
# Final cleaned file saved: plaza_colón_(san_juan).txt
# Final cleaned file saved: plaza_degetau.txt
# Final cleaned file saved: plaza_del_caribe.txt
# Final cleaned file saved: plaza_del_mercado_de_ponce.txt
# Final cleaned file saved: plaza_del_norte.txt
# Final cleaned file saved: plaza_del_quinto_centenario.txt
# Final cleaned file saved: plaza_del_sol_(puerto_rico).txt
# Final cleaned file saved: plaza_de_armas,_san_juan.txt
# Final cleaned file saved: plaza_de_la_catedral_(san_juan).txt
# Final cleaned file saved: plaza_de_san_josé.txt
# Final cleaned file saved: plaza_juan_ponce_de_león.txt
# Final cleaned file saved: plaza_las_américas_(puerto_rico).txt
# Final cleaned file saved: plaza_las_delicias.txt
# Final cleaned file saved: plaza_muñoz_rivera.txt
# Final cleaned file saved: plaza_rio_hondo.txt
# Final cleaned file saved: polvorín_de_miraflores.txt
# Final cleaned file saved: polytechnic_university_of_puerto_rico.txt
# Final cleaned file saved: ponce_cement,_inc..txt
# Final cleaned file saved: ponce_city_hall.txt
# Final cleaned file saved: ponce_high_school.txt
# Final cleaned file saved: ponce_historic_zone.txt
# Final cleaned file saved: ponce_school_of_medicine.txt
# Final cleaned file saved: ponce_ymca_building.txt
# Final cleaned file saved: pontificia_universidad_católica_de_puerto_rico.txt
# Final cleaned file saved: porta_coeli_(puerto_rico).txt
# Final cleaned file saved: pozo_de_jacinto.txt
# Final cleaned file saved: primera_iglesia_bautista_de_caguas.txt
# Final cleaned file saved: primera_iglesia_metodista_unida_de_ponce.txt
# Final cleaned file saved: pueblo,_san_juan,_puerto_rico.txt
# Final cleaned file saved: puente_blanco.txt
# Final cleaned file saved: puente_de_coloso.txt
# Final cleaned file saved: puente_de_las_calabazas.txt
# Final cleaned file saved: puente_no._6.txt
# Final cleaned file saved: puerta_de_tierra,_san_juan.txt
# Final cleaned file saved: puerto_del_rey_marina.txt
# Final cleaned file saved: puerto_rico.txt
# Final cleaned file saved: puerto_rico_convention_center.txt
# Final cleaned file saved: puerto_rico_iron_works.txt
# Final cleaned file saved: puerto_rico_museum_of_contemporary_art.txt
# Final cleaned file saved: puerto_rico_national_library.txt
# Final cleaned file saved: punta_borinquen_light.txt
# Final cleaned file saved: punta_de_las_figuras_light.txt
# Final cleaned file saved: punta_higuero_light.txt
# Final cleaned file saved: punta_mulas_light.txt
# Final cleaned file saved: punta_santiago,_humacao,_puerto_rico.txt
# Final cleaned file saved: punta_tuna_light.txt
# Final cleaned file saved: quebradillas_barrio-pueblo.txt
# Final cleaned file saved: rafael_hernández_marín.txt
# Final cleaned file saved: ramón_rivero_(diplo).txt
# Final cleaned file saved: residencia_aboy-lompré.txt
# Final cleaned file saved: residencia_armstrong-poventud.txt
# Final cleaned file saved: residencia_rosaly-batiz.txt
# Final cleaned file saved: residencia_subirá.txt
# Final cleaned file saved: rincón_barrio-pueblo.txt
# Final cleaned file saved: roberto_clemente_coliseum.txt
# Final cleaned file saved: roberto_clemente_stadium.txt
# Final cleaned file saved: roosevelt_roads_naval_station.txt
# Final cleaned file saved: rovira_biscuits_corporation.txt
# Final cleaned file saved: rum.txt
# Final cleaned file saved: rum_planetarium.txt
# Final cleaned file saved: río_abajo_state_forest.txt
# Final cleaned file saved: río_grande_barrio-pueblo.txt
# Final cleaned file saved: río_grande_de_loíza.txt
# Final cleaned file saved: río_matón_bridge.txt
# Final cleaned file saved: río_piedras_bridge.txt
# Final cleaned file saved: sabana_grande_barrio-pueblo.txt
# Final cleaned file saved: sabana_grande_masonic_cemetery.txt
# Final cleaned file saved: saint_john's_school_(san_juan).txt
# Final cleaned file saved: saliente_river.txt
# Final cleaned file saved: salinas_barrio-pueblo.txt
# Final cleaned file saved: samuel_morse.txt
# Final cleaned file saved: santa_ana_church_(san_juan).txt
# Final cleaned file saved: santa_isabel_barrio-pueblo.txt
# Final cleaned file saved: santa_maría_magdalena_de_pazzis_cemetery.txt
# Final cleaned file saved: santurce,_san_juan,_puerto_rico.txt
# Final cleaned file saved: san_cristóbal_canyon.txt
# Final cleaned file saved: san_germán_historic_district.txt
# Final cleaned file saved: san_josé_church.txt
# Final cleaned file saved: san_juan_botanical_garden.txt
# Final cleaned file saved: san_juan_city_hall.txt
# Final cleaned file saved: san_juan_marriott_resort_&_stellaris_casino.txt
# Final cleaned file saved: san_juan_natatorium.txt
# Final cleaned file saved: san_juan_puerto_rico_temple.txt
# Final cleaned file saved: san_lorenzo_barrio-pueblo.txt
# Final cleaned file saved: san_miguel_arcángel_church_(cabo_rojo).txt
# Final cleaned file saved: san_patricio_plaza.txt
# Final cleaned file saved: san_patricio_state_forest.txt
# Final cleaned file saved: san_sebastián_barrio-pueblo.txt
# Final cleaned file saved: school_of_tropical_medicine_(puerto_rico).txt
# Final cleaned file saved: sixto_escobar.txt
# Final cleaned file saved: stud_farm.txt
# Final cleaned file saved: supreme_court_building_(puerto_rico).txt
# Final cleaned file saved: susúa_state_forest.txt
# Final cleaned file saved: t-mobile_district.txt
# Final cleaned file saved: teatro_fox_delicias.txt
# Final cleaned file saved: teatro_la_perla.txt
# Final cleaned file saved: teatro_tapia.txt
# Final cleaned file saved: teatro_yagüez.txt
# Final cleaned file saved: teodoro_moscoso_bridge.txt
# Final cleaned file saved: the_mall_of_san_juan.txt
# Final cleaned file saved: tito_puente_amphitheatre.txt
# Final cleaned file saved: toa_alta_barrio-pueblo.txt
# Final cleaned file saved: toa_baja_barrio-pueblo.txt
# Final cleaned file saved: toro_negro_state_forest.txt
# Final cleaned file saved: tortuguero_lagoon.txt
# Final cleaned file saved: train_of_the_south.txt
# Final cleaned file saved: trujillo_alto_barrio-pueblo.txt
# Final cleaned file saved: u.s._custom_house_(san_juan,_puerto_rico).txt
# Final cleaned file saved: u.s._post_office_and_courthouse_(mayagüez,_puerto_rico).txt
# Final cleaned file saved: united_states_customs_house_(fajardo,_puerto_rico).txt
# Final cleaned file saved: united_states_customs_house_(ponce,_puerto_rico).txt
# Final cleaned file saved: united_states_district_court_for_the_district_of_puerto_rico.txt
# Final cleaned file saved: universidad_del_sagrado_corazón.txt
# Final cleaned file saved: university_gardens_high_school.txt
# Final cleaned file saved: university_high_school_(san_juan).txt
# Final cleaned file saved: university_of_puerto_rico,_medical_sciences_campus.txt
# Final cleaned file saved: university_of_puerto_rico,_río_piedras_campus.txt
# Final cleaned file saved: university_of_puerto_rico_at_cayey.txt
# Final cleaned file saved: university_of_puerto_rico_at_humacao.txt
# Final cleaned file saved: university_of_puerto_rico_at_mayagüez.txt
# Final cleaned file saved: university_of_puerto_rico_at_ponce.txt
# Final cleaned file saved: university_of_puerto_rico_school_of_medicine.txt
# Final cleaned file saved: uss_killen_(dd-593).txt
# Final cleaned file saved: utuado_barrio-pueblo.txt
# Final cleaned file saved: vega_alta_barrio-pueblo.txt
# Final cleaned file saved: vega_baja_barrio-pueblo.txt
# Final cleaned file saved: vega_state_forest.txt
# Final cleaned file saved: vieques_national_wildlife_refuge.txt
# Final cleaned file saved: villalba,_puerto_rico.txt
# Final cleaned file saved: villalba_barrio-pueblo.txt
# Final cleaned file saved: villa_pesquera.txt
# Final cleaned file saved: west_indian_manatee.txt
# Final cleaned file saved: whale_watching.txt
# Final cleaned file saved: william_miranda_marín_botanical_and_cultural_garden.txt
# Final cleaned file saved: world_war_ii.txt
# Final cleaned file saved: yabucoa_barrio-pueblo.txt
# Final cleaned file saved: yauco_barrio-pueblo.txt
# Final cleaned file saved: zona_historica_de_ponce.txt

# %% [markdown]
# import os
# import json
# import re
#
# # Define paths
# raw_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\test"
# cleaned_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleanng\final_step_cleaned_data"
# output_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleanng\10Feb25_step01_title_cat_geo_clean"
#
# # Create output directory if it doesn't exist
# if not os.path.exists(output_path):
#     os.makedirs(output_path)
#
# # Keyword-based category mapping
# category_keywords = {
#     "Extreme Adventure": ["zipline", "canopy", "extreme sports", "rock climbing", "caving", "spelunking", "skydiving", "bungee jumping", "off-road", "ATV"],
#     "Soft Adventure": ["hiking", "kayaking", "snorkeling", "paddleboarding", "scuba diving", "tubing", "water sports"],
#     "Outdoor": ["nature", "park", "trail", "scenic", "river", "camping", "wildlife", "birdwatching", "cave", "natural reserve"],
#     "Beach": ["beach", "sand", "ocean", "coast", "surfing", "snorkeling", "seaside"],
#     "Culture": ["museum", "history", "heritage", "colonial", "art", "landmark", "architecture"],
#     "Food": ["food", "cuisine", "restaurant", "culinary", "gastronomy", "local dishes"],
#     "Nightlife": ["nightlife", "bar", "party", "music", "club", "cocktail", "dance"],
#     "Shopping": ["shopping", "mall", "store", "boutique", "souvenirs", "market"],
#     "Wildlife": ["animals", "zoo", "wildlife", "birdwatching", "conservation"],
#     "Family-Friendly": ["family", "kids", "playground", "amusement", "theme park", "activities"],
#     "Religion": ["church", "cathedral", "parish", "temple", "sanctuary", "basilica", "shrine", "holy", "worship"],
#     "Wellness & Relaxation": ["spa", "wellness", "yoga", "retreat", "meditation", "hot springs", "thermal baths", "relaxation", "peaceful"],
#     "Luxury & Resorts": ["resort", "luxury", "boutique hotel", "exclusive", "private beach", "high-end"],
#     "Festivals & Events": ["festival", "event", "parade", "local traditions", "carnival", "concert", "Puerto Rican festival"]
# }
#
# # Function to extract coordinates
# def extract_coordinates(text):
#     coordinate_pattern = re.compile(r'(-?\d+\.\d+);\s*(-?\d+\.\d+)')
#     matches = coordinate_pattern.findall(text)
#     if matches:
#         lat, lon = float(matches[0][0]), float(matches[0][1])
#         return [lat, lon]
#     return None
#
# # Function to remove pronunciation sections (generic patterns within parentheses)
# def remove_pronunciation(text):
#     # Define the regex pattern to match different pronunciation formats
#     pronunciation_pattern = re.compile(
#         r"\(\s*(US:.*?|UK:.*?|Spanish:.*?|US :.*?|UK :.*?|Spanish :.*?|.*?pronunciation:.*?|/.*?/.*?)\s*\)",  # Include "pronunciation:" explicitly
#         flags=re.DOTALL
#     )
#     # Remove all matching patterns
#     return re.sub(pronunciation_pattern, "", text)
#
# # Function to assign categories based on keywords
# def assign_categories(text):
#     assigned_categories = []
#     text_lower = text.lower()
#     for category, keywords in category_keywords.items():
#         if any(keyword in text_lower for keyword in keywords):
#             assigned_categories.append(category)
#     return list(set(assigned_categories))  # Ensure unique categories
#
# # Process all files
# for file_name in os.listdir(cleaned_data_path):
#     raw_file_path = os.path.join(raw_data_path, file_name)
#     cleaned_file_path = os.path.join(cleaned_data_path, file_name)
#
#     if not os.path.exists(raw_file_path):
#         print(f"Skipping {file_name}: Raw file not found.")
#         continue
#
#     # Load raw and cleaned data
#     with open(raw_file_path, "r", encoding="utf-8") as raw_file:
#         raw_content = raw_file.read()
#
#     with open(cleaned_file_path, "r", encoding="utf-8") as cleaned_file:
#         cleaned_data = json.load(cleaned_file)
#
#     # Extract title (use file name as fallback)
#     title_match = re.search(r"<h1>(.*?)</h1>", raw_content)
#     title = title_match.group(1).strip() if title_match else file_name.replace(".txt", "")
#
#     # Extract coordinates
#     coordinates = extract_coordinates(raw_content)
#
#     # Assign categories
#     categories = assign_categories(cleaned_data["main_content"])
#
#     # Remove pronunciation details
#     cleaned_data["main_content"] = remove_pronunciation(cleaned_data["main_content"])
#
#     # Update geo_metadata
#     cleaned_data["geo_metadata"] = {
#         "coordinates": coordinates if coordinates else cleaned_data["geo_metadata"].get("coordinates", "Not Found"),
#         "title": title,
#         "type": "Point"
#     }
#
#     # Add categories
#     cleaned_data["categories"] = categories
#
#     # Save updated JSON
#     output_file_path = os.path.join(output_path, file_name)
#     with open(output_file_path, "w", encoding="utf-8") as out_file:
#         json.dump(cleaned_data, out_file, indent=4, ensure_ascii=False)
#
#     print(f"Updated and saved: {file_name}")

# %% [markdown]
# Sure, I can help you integrate the provided code into your existing code. Here is the updated code with the new functions and logic included:

# %% [markdown]
# import os
# import json
# import re
#
# # Define paths
# raw_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\test"
# cleaned_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleanng\final_step_cleaned_data"
# output_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleanng\10Feb25_step01_title_cat_geo_clean"
#
# # Create output directory if it doesn't exist
# if not os.path.exists(output_path):
#     os.makedirs(output_path)
#
# # Keyword-based category mapping
# category_keywords = {
#     "Extreme Adventure": ["zipline", "canopy", "extreme sports", "rock climbing", "caving", "spelunking", "skydiving", "bungee jumping", "off-road", "ATV"],
#     "Soft Adventure": ["hiking", "kayaking", "snorkeling", "paddleboarding", "scuba diving", "tubing", "water sports"],
#     "Outdoor": ["nature", "park", "trail", "scenic", "river", "camping", "wildlife", "birdwatching", "cave", "natural reserve"],
#     "Beach": ["beach", "sand", "ocean", "coast", "surfing", "snorkeling", "seaside"],
#     "Culture": ["museum", "history", "heritage", "colonial", "art", "landmark", "architecture"],
#     "Food": ["food", "cuisine", "restaurant", "culinary", "gastronomy", "local dishes"],
#     "Nightlife": ["nightlife", "bar", "party", "music", "club", "cocktail", "dance"],
#     "Shopping": ["shopping", "mall", "store", "boutique", "souvenirs", "market"],
#     "Wildlife": ["animals", "zoo", "wildlife", "birdwatching", "conservation"],
#     "Family-Friendly": ["family", "kids", "playground", "amusement", "theme park", "activities"],
#     "Religion": ["church", "cathedral", "parish", "temple", "sanctuary", "basilica", "shrine", "holy", "worship"],
#     "Wellness & Relaxation": ["spa", "wellness", "yoga", "retreat", "meditation", "hot springs", "thermal baths", "relaxation", "peaceful"],
#     "Luxury & Resorts": ["resort", "luxury", "boutique hotel", "exclusive", "private beach", "high-end"],
#     "Festivals & Events": ["festival", "event", "parade", "local traditions", "carnival", "concert", "Puerto Rican festival"]
# }
#
# # Function to extract coordinates
# def extract_coordinates(text):
#     coordinate_pattern = re.compile(r'(-?\d+\.\d+);\s*(-?\d+\.\d+)')
#     matches = coordinate_pattern.findall(text)
#     if matches:
#         lat, lon = float(matches[0][0]), float(matches[0][1])
#         return [lat, lon]
#     return None
#
# # Function to remove pronunciation sections (generic patterns within parentheses)
# def remove_pronunciation(text):
#     # Define the regex pattern to match different pronunciation formats
#     pronunciation_pattern = re.compile(
#         r"\(\s*(US:.*?|UK:.*?|Spanish:.*?|US :.*?|UK :.*?|Spanish :.*?|.*?pronunciation:.*?|/.*?/.*?)\s*\)",  # Include "pronunciation:" explicitly
#         flags=re.DOTALL
#     )
#     # Remove all matching patterns
#     return re.sub(pronunciation_pattern, "", text)
#
# # Function to assign categories based on keywords
# def assign_categories(text):
#     assigned_categories = []
#     text_lower = text.lower()
#     for category, keywords in category_keywords.items():
#         if any(keyword in text_lower for keyword in keywords):
#             assigned_categories.append(category)
#     return list(set(assigned_categories))  # Ensure unique categories
#
# # Function to update geo_metadata and categories in cleaned files
# def update_cleaned_file(cleaned_data, title, coordinates, categories):
#     # Validate and update geo_metadata
#     cleaned_data["geo_metadata"] = {
#         "coordinates": coordinates,
#         "title": cleaned_data["geo_metadata"].get("title", title) if "geo_metadata" in cleaned_data else title,
#         "type": "Point"
#     }
#
#     # Add categories
#     cleaned_data["categories"] = categories
#
#     return cleaned_data
#
# # Function to clean and update main content
# def update_main_content(cleaned_data):
#     # Remove pronunciation sections if available
#     if "main_content" in cleaned_data:
#         cleaned_data["main_content"] = remove_pronunciation(cleaned_data["main_content"])
#     return cleaned_data
#
# # Process files and handle exceptions
# for file in os.listdir(cleaned_data_path):
#     try:
#         cleaned_file_path = os.path.join(cleaned_data_path, file)
#         raw_file_path = os.path.join(raw_data_path, file)
#
#         # Load cleaned data
#         with open(cleaned_file_path, "r", encoding="utf-8") as f:
#             cleaned_data = json.load(f)
#
#         # Extract title, coordinates, and categories from raw data
#         with open(raw_file_path, "r", encoding="utf-8") as f:
#             raw_content = f.read()
#         title = re.search(r"<h1>(.*?)</h1>", raw_content).group(1).strip() if re.search(r"<h1>(.*?)</h1>", raw_content) else file.replace(".txt", "")
#         coordinates = extract_coordinates(raw_content)
#         categories = assign_categories(raw_content)
#
#         # Update cleaned data
#         cleaned_data = update_cleaned_file(cleaned_data, title, coordinates, categories)
#         cleaned_data = update_main_content(cleaned_data)
#
#         # Save updated cleaned data
#         output_file_path = os.path.join(output_path, file)
#         with open(output_file_path, "w", encoding="utf-8") as f:
#             json.dump(cleaned_data, f, indent=4, ensure_ascii=False)
#
#         print(f"Updated and saved: {file}")
#
#     except Exception as e:
#         print(f"Error processing file {file}: {e}")

# %% [markdown]
# This code integrates the new functions `update_cleaned_file` and `update_main_content` into the existing processing loop. It ensures that the cleaned data is updated with the title, coordinates, and categories, and that the main content is cleaned by removing pronunciation sections. The updated cleaned data is then saved to the specified output path.

# %% [markdown]
# import os
# import json
# import re
#
# # Define paths
# raw_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\test"
# cleaned_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleanng\final_step_cleaned_data"
# output_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleanng\10Feb25a_step01_title_cat_geo_clean"
# municipality_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\municipalities_cleaning\step3_final_cleaned_data"
#
# # Create output directory if it doesn't exist
# if not os.path.exists(output_path):
#     os.makedirs(output_path)
#
# # Keyword-based category mapping
# category_keywords = {
#     "Extreme Adventure": ["zipline", "canopy", "bike", "rappelling", "mountain bike", "paragliding", "skate", "skating", "extreme sports", "rock climbing", "caving", "spelunking", "skydiving", "bungee jumping", "off-road", "ATV"],
#     "Soft Adventure": ["hiking", "kayaking", "snorkeling", "paddleboarding", "scuba diving", "tubing", "water sports"],
#     "Outdoor": ["nature", "park", "trail", "scenic", "river", "camping", "wildlife", "birdwatching", "cave", "natural reserve"],
#     "Beach": ["beach", "sand", "ocean", "coast", "surfing", "snorkeling", "seaside"],
#     "Culture": ["museum", "history", "heritage", "colonial", "art", "landmark", "architecture"],
#     "Food": ["food", "cuisine", "restaurant", "culinary", "gastronomy", "local dishes"],
#     "Nightlife": ["nightlife", "bar", "party", "music", "club", "cocktail", "dance"],
#     "Shopping": ["shopping", "mall", "store", "boutique", "souvenirs", "market"],
#     "Wildlife": ["animals", "zoo", "wildlife", "birdwatching", "conservation"],
#     "Family-Friendly": ["family", "kids", "playground", "amusement", "theme park", "activities"],
#     "Religion": ["church", "cathedral", "parish", "temple", "sanctuary", "basilica", "shrine", "holy", "worship"],
#     "Wellness & Relaxation": ["spa", "wellness", "yoga", "retreat", "meditation", "hot springs", "thermal baths", "relaxation", "peaceful"],
#     "Luxury & Resorts": ["resort", "luxury", "boutique hotel", "exclusive", "private beach", "high-end"],
#     "Festivals & Events": ["festival", "event", "parade", "local traditions", "carnival", "concert", "Puerto Rican festival"]
# }
#
# # Function to extract coordinates
# def extract_coordinates(text):
#     coordinate_pattern = re.compile(r'(-?\d+\.\d+);\s*(-?\d+\.\d+)')
#     matches = coordinate_pattern.findall(text)
#     if matches:
#         lat, lon = float(matches[0][0]), float(matches[0][1])
#         return [lat, lon]
#     return None
#
# # Function to remove pronunciation sections (generic patterns within parentheses)
# def remove_pronunciation(text):
#     # Define the regex pattern to match different pronunciation formats
#     pronunciation_pattern = re.compile(
#         r"\(\s*(US:.*?|UK:.*?|Spanish:.*?|US :.*?|UK :.*?|Spanish :.*?|.*?pronunciation:.*?|/.*?/.*?)\s*\)",  # Include "pronunciation:" explicitly
#         flags=re.DOTALL
#     )
#     # Remove all matching patterns
#     return re.sub(pronunciation_pattern, "", text)
#
# # Function to assign categories based on keywords
# def assign_categories(text):
#     assigned_categories = []
#     text_lower = text.lower()
#     for category, keywords in category_keywords.items():
#         if any(keyword in text_lower for keyword in keywords):
#             assigned_categories.append(category)
#     return list(set(assigned_categories))  # Ensure unique categories
#
# # Function to update geo_metadata and categories in cleaned files
# def update_cleaned_file(cleaned_data, title, coordinates, categories):
#     # Validate and update geo_metadata
#     cleaned_data["geo_metadata"] = {
#         "coordinates": coordinates if coordinates else cleaned_data["geo_metadata"].get("coordinates", "Not Found"),
#         "title": cleaned_data["geo_metadata"].get("title", title) if "geo_metadata" in cleaned_data else title,
#         "type": "Point"
#     }
#
#     # Add categories
#     cleaned_data["categories"] = categories
#
#     return cleaned_data
#
# # Function to clean and update main content
# def update_main_content(cleaned_data):
#     # Remove pronunciation sections if available
#     if "main_content" in cleaned_data:
#         cleaned_data["main_content"] = remove_pronunciation(cleaned_data["main_content"])
#     return cleaned_data
#
# # Process files and handle exceptions
# files_without_coordinates = []
# for file in os.listdir(cleaned_data_path):
#     try:
#         cleaned_file_path = os.path.join(cleaned_data_path, file)
#         raw_file_path = os.path.join(raw_data_path, file)
#
#         # Load cleaned data
#         with open(cleaned_file_path, "r", encoding="utf-8") as f:
#             cleaned_data = json.load(f)
#
#         # Extract title, coordinates, and categories from raw data
#         with open(raw_file_path, "r", encoding="utf-8") as f:
#             raw_content = f.read()
#         title = re.search(r"<h1>(.*?)</h1>", raw_content).group(1).strip() if re.search(r"<h1>(.*?)</h1>", raw_content) else file.replace(".txt", "")
#         coordinates = extract_coordinates(raw_content)
#         categories = assign_categories(cleaned_data["main_content"])
#
#         # Update cleaned data
#         cleaned_data = update_cleaned_file(cleaned_data, title, coordinates, categories)
#         cleaned_data = update_main_content(cleaned_data)
#
#         # Save updated cleaned data
#         output_file_path = os.path.join(output_path, file)
#         with open(output_file_path, "w", encoding="utf-8") as f:
#             json.dump(cleaned_data, f, indent=4, ensure_ascii=False)
#
#         print(f"Updated and saved: {file}")
#
#         if not coordinates:
#             files_without_coordinates.append(file)
#
#     except Exception as e:
#         print(f"Error processing file {file}: {e}")
#
# # List files without coordinates
# print("Files without coordinates:")
# for file in files_without_coordinates:
#     print(file)
#
# # Assign coordinates based on municipality location
# for file in files_without_coordinates:
#     try:
#         cleaned_file_path = os.path.join(output_path, file)
#         with open(cleaned_file_path, "r", encoding="utf-8") as f:
#             cleaned_data = json.load(f)
#
#         # Assign coordinates based on municipality
#         for municipality_file in os.listdir(municipality_data_path):
#             municipality_name = municipality_file.replace(".json", "")
#             if municipality_name.lower() in cleaned_data["geo_metadata"]["title"].lower():
#                 municipality_file_path = os.path.join(municipality_data_path, municipality_file)
#                 with open(municipality_file_path, "r", encoding="utf-8") as mf:
#                     municipality_data = json.load(mf)
#                 cleaned_data["geo_metadata"]["coordinates"] = municipality_data["geo_metadata"]["coordinates"]
#                 break
#
#         # Save updated cleaned data with municipality coordinates
#         with open(cleaned_file_path, "w", encoding="utf-8") as f:
#             json.dump(cleaned_data, f, indent=4, ensure_ascii=False)
#
#         print(f"Assigned coordinates to: {file}")
#
#     except Exception as e:
#         print(f"Error assigning coordinates to file {file}: {e}")

# %% [markdown]
# Entiendo, vamos a realizar las siguientes modificaciones para solucionar los problemas:
#
# 1. Asegurarnos de que la verificación de `geo_metadata` maneje correctamente los casos en los que no existe.
# 2. Ajustar la asignación de categorías para que haga una coincidencia exacta de las palabras clave.
# 3. Asegurarnos de que el sistema intente aplicar la información de los municipios cuando no se encuentren coordenadas.
#
# Aquí está el código actualizado:

# %% [markdown]
# import os
# import json
# import re
#
# # Define paths
# raw_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks\test"
# cleaned_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleanng\final_step_cleaned_data"
# output_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleanng\10Feb25b_step01_title_cat_geo_clean"
# municipality_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\municipalities_cleaning\step3_final_cleaned_data"
#
# # Create output directory if it doesn't exist
# if not os.path.exists(output_path):
#     os.makedirs(output_path)
#
# # Keyword-based category mapping
# category_keywords = {
#     "Extreme Adventure": ["zipline", "canopy", "rappelling", "mountain bike", "paragliding", "skate", "skating", "extreme sports", "rock climbing", "caving", "spelunking", "skydiving", "bungee jumping", "off-road", "ATV"],
#     "Soft Adventure": ["hiking", "kayaking", "bike", "snorkeling", "paddleboarding", "scuba diving", "tubing", "water sports"],
#     "Outdoor": ["nature", "park", "trail", "scenic", "river", "trails", "camping", "picnic", "wildlife", "birdwatching", "cave", "natural reserve", "outdoor", "forrest"],
#     "Beach": ["beach", "sand", "ocean", "coast", "surfing", "snorkeling", "seaside"],
#     "Culture": ["museum", "history", "heritage", "colonial", "art", "architecture"],
#     "Food": ["food", "cuisine", "restaurant", "culinary", "gastronomy", "local dishes"],
#     "Nightlife": ["nightlife", "bar", "party", "dance music", "night club", "cocktail", "dancing stage", "pub", "sport bar"],
#     "Shopping": ["shopping", "shop", "mall", "store", "boutique", "souvenirs", "market"],
#     "Wildlife": ["animals", "zoo", "wildlife", "birdwatching", "feeding"],
#     "Family-Friendly": ["family", "kids", "playground", "camping", "park", "amusement", "theme park", "picnic", "kite flying", "kites"],
#     "Religion": ["church", "cathedral", "parish", "temple", "sanctuary", "basilica", "shrine", "holy", "worship"],
#     "Wellness & Relaxation": ["spa", "wellness", "yoga", "retreat", "meditation", "hot springs", "thermal baths", "relaxation", "peaceful"],
#     "Luxury & Resorts": ["resort", "luxury", "boutique hotel", "exclusive", "private beach", "high-end", "hotel", "inn", "lodging"],
#     "Festivals & Events": ["festival", "event", "parade", "local traditions", "carnival", "concert", "Puerto Rican festival"]
# }
#
# # Function to extract coordinates
# def extract_coordinates(text):
#     coordinate_pattern = re.compile(r'(-?\d+\.\d+);\s*(-?\d+\.\d+)')
#     matches = coordinate_pattern.findall(text)
#     if matches:
#         lat, lon = float(matches[0][0]), float(matches[0][1])
#         return [lat, lon]
#     return None
#
# # Function to remove pronunciation sections (generic patterns within parentheses)
# def remove_pronunciation(text):
#     # Define the regex pattern to match different pronunciation formats
#     pronunciation_pattern = re.compile(
#         r"\(\s*(US:.*?|UK:.*?|Spanish:.*?|US :.*?|UK :.*?|Spanish :.*?|.*?pronunciation:.*?|/.*?/.*?)\s*\)",  # Include "pronunciation:" explicitly
#         flags=re.DOTALL
#     )
#     # Remove all matching patterns
#     return re.sub(pronunciation_pattern, "", text)
#
# # Function to assign categories based on keywords
# def assign_categories(text):
#     assigned_categories = []
#     text_lower = text.lower()
#     words = re.findall(r'\b\w+\b', text_lower)  # Extract words for exact match
#     for category, keywords in category_keywords.items():
#         if any(keyword in words for keyword in keywords):
#             assigned_categories.append(category)
#     return list(set(assigned_categories))  # Ensure unique categories
#
# # Function to update geo_metadata and categories in cleaned files
# def update_cleaned_file(cleaned_data, title, coordinates, categories):
#     # Validate and update geo_metadata
#     if "geo_metadata" not in cleaned_data or cleaned_data["geo_metadata"] is None:
#         cleaned_data["geo_metadata"] = {}
#     cleaned_data["geo_metadata"]["coordinates"] = coordinates if coordinates else cleaned_data["geo_metadata"].get("coordinates", "Not Found")
#     cleaned_data["geo_metadata"]["title"] = cleaned_data["geo_metadata"].get("title", title)
#     cleaned_data["geo_metadata"]["type"] = "Point"
#
#     # Add categories
#     cleaned_data["categories"] = categories
#
#     return cleaned_data
#
# # Function to clean and update main content
# def update_main_content(cleaned_data):
#     # Remove pronunciation sections if available
#     if "main_content" in cleaned_data:
#         cleaned_data["main_content"] = remove_pronunciation(cleaned_data["main_content"])
#     return cleaned_data
#
# # Process files and handle exceptions
# files_without_coordinates = []
# for file in os.listdir(cleaned_data_path):
#     try:
#         cleaned_file_path = os.path.join(cleaned_data_path, file)
#         raw_file_path = os.path.join(raw_data_path, file)
#
#         # Load cleaned data
#         with open(cleaned_file_path, "r", encoding="utf-8") as f:
#             cleaned_data = json.load(f)
#
#         # Extract title, coordinates, and categories from raw data
#         with open(raw_file_path, "r", encoding="utf-8") as f:
#             raw_content = f.read()
#         title = re.search(r"<h1>(.*?)</h1>", raw_content).group(1).strip() if re.search(r"<h1>(.*?)</h1>", raw_content) else file.replace(".txt", "")
#         coordinates = extract_coordinates(raw_content)
#         categories = assign_categories(cleaned_data["main_content"])
#
#         # Update cleaned data
#         cleaned_data = update_cleaned_file(cleaned_data, title, coordinates, categories)
#         cleaned_data = update_main_content(cleaned_data)
#
#         # Save updated cleaned data
#         output_file_path = os.path.join(output_path, file)
#         with open(output_file_path, "w", encoding="utf-8") as f:
#             json.dump(cleaned_data, f, indent=4, ensure_ascii=False)
#
#         print(f"Updated and saved: {file}")
#
#         if not coordinates:
#             files_without_coordinates.append(file)
#
#     except Exception as e:
#         print(f"Error processing file {file}: {e}")
#
# # List files without coordinates
# print("Files without coordinates:")
# for file in files_without_coordinates:
#     print(file)
#
# # Assign coordinates based on municipality location
# for file in files_without_coordinates:
#     try:
#         cleaned_file_path = os.path.join(output_path, file)
#         with open(cleaned_file_path, "r", encoding="utf-8") as f:
#             cleaned_data = json.load(f)
#
#         # Assign coordinates based on municipality
#         for municipality_file in os.listdir(municipality_data_path):
#             municipality_name = municipality_file.replace(".json", "")
#             if municipality_name.lower() in cleaned_data["geo_metadata"]["title"].lower():
#                 municipality_file_path = os.path.join(municipality_data_path, municipality_file)
#                 with open(municipality_file_path, "r", encoding="utf-8") as mf:
#                     municipality_data = json.load(mf)
#                 cleaned_data["geo_metadata"]["coordinates"] = municipality_data["geo_metadata"]["coordinates"]
#                 break
#
#         # Save updated cleaned data with municipality coordinates
#         with open(cleaned_file_path, "w", encoding="utf-8") as f:
#             json.dump(cleaned_data, f, indent=4, ensure_ascii=False)
#
#         print(f"Assigned coordinates to: {file}")
#
#     except Exception as e:
#         print(f"Error assigning coordinates to file {file}: {e}")

# %% [markdown]
# Este código realiza las siguientes modificaciones:
# 1. Asegura que la verificación de `geo_metadata` maneje correctamente los casos en los que no existe.
# 2. Ajusta la asignación de categorías para que haga una coincidencia exacta de las palabras clave.
# 3. Asegura que el sistema intente aplicar la información de los municipios cuando no se encuentren coordenadas.
#
# Asegúrate de que los archivos de municipios en la carpeta `municipality_data_path` tengan la estructura correcta y contengan las coordenadas necesarias.

# %% [markdown]
# # **Final Cleaning Step No. 1: Adding Title, geo info and Categories & removal of pronunciation section**

# %%
import os
import json
import re

# Define paths
raw_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks"
cleaned_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleaning\final_step_cleaned_data"                     
output_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleaning\10Feb25_final_step01_title_cat_geo_clean"
municipality_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\municipalities_cleaning\step3_final_cleaned_data"
no_coordinates_output_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleaning\no_coordinates_records.json"

# Create output directory if it doesn't exist
if not os.path.exists(output_path):
    os.makedirs(output_path)

# Keyword-based category mapping
category_keywords = {
    "Extreme Adventure": ["zipline", "canopy", "rappelling", "mountain bike", "paragliding", "skate", "skating", "extreme sports", "rock climbing", "caving", "spelunking", "skydiving", "bungee jumping", "off-road", "ATV"],
    "Soft Adventure": ["hiking", "kayaking", "bike", "snorkeling", "paddleboarding", "scuba diving", "tubing", "water sports"],
    "Outdoor": ["nature", "park", "trail", "scenic", "river", "trails", "camping", "picnic", "wildlife", "birdwatching", "cave", "natural reserve", "outdoor", "forrest"],
    "Beach": ["beach", "sand", "ocean", "coast", "surfing", "snorkeling", "seaside"],
    "Culture": ["museum", "history", "heritage", "colonial", "art", "architecture"],
    "Food": ["food", "cuisine", "restaurant", "culinary", "gastronomy", "local dishes"],
    "Nightlife": ["nightlife", "bar", "party", "dance music", "night club", "cocktail", "dancing stage", "pub", "sport bar"],
    "Shopping": ["shopping", "shop", "mall", "store", "boutique", "souvenirs", "market"],
    "Wildlife": ["animals", "zoo", "wildlife", "birdwatching", "feeding"],
    "Family-Friendly": ["family", "kids", "playground", "camping", "park", "amusement", "theme park", "picnic", "kite flying", "kites"],
    "Religion": ["church", "cathedral", "parish", "temple", "sanctuary", "basilica", "shrine", "holy", "worship"],
    "Wellness & Relaxation": ["spa", "wellness", "yoga", "retreat", "meditation", "hot springs", "thermal baths", "relaxation", "peaceful"],
    "Luxury & Resorts": ["resort", "luxury", "boutique hotel", "exclusive", "private beach", "high-end", "hotel", "inn", "lodging"],
    "Festivals & Events": ["festival", "event", "parade", "local traditions", "carnival", "concert", "Puerto Rican festival"]
}

# Function to extract coordinates
def extract_coordinates(text):
    coordinate_pattern = re.compile(r'(-?\d+\.\d+);\s*(-?\d+\.\d+)')
    matches = coordinate_pattern.findall(text)
    if matches:
        lat, lon = float(matches[0][0]), float(matches[0][1])
        return [lat, lon]
    return None

# Function to remove pronunciation sections (generic patterns within parentheses)
def remove_pronunciation(text):
    # Define the regex pattern to match different pronunciation formats
    pronunciation_pattern = re.compile(
        r"\(\s*(US:.*?|UK:.*?|Spanish:.*?|US :.*?|UK :.*?|Spanish :.*?|.*?pronunciation:.*?|/.*?/.*?)\s*\)",  # Include "pronunciation:" explicitly
        flags=re.DOTALL
    )
    # Remove all matching patterns
    return re.sub(pronunciation_pattern, "", text)

# Function to assign categories based on keywords
def assign_categories(text):
    assigned_categories = []
    text_lower = text.lower()
    words = re.findall(r'\b\w+\b', text_lower)  # Extract words for exact match
    for category, keywords in category_keywords.items():
        if any(keyword in words for keyword in keywords):
            assigned_categories.append(category)
    return list(set(assigned_categories))  # Ensure unique categories

# Function to format title from filename
def format_title(filename):
    return ' '.join(word.capitalize() for word in filename.replace(".txt", "").replace("_", " ").split())

# Function to update geo_metadata and categories in cleaned files
def update_cleaned_file(cleaned_data, title, coordinates, categories):
    # Validate and update geo_metadata
    if "geo_metadata" not in cleaned_data or cleaned_data["geo_metadata"] is None:
        cleaned_data["geo_metadata"] = {}
    cleaned_data["geo_metadata"]["coordinates"] = coordinates if coordinates else cleaned_data["geo_metadata"].get("coordinates", "Not Found")
    cleaned_data["geo_metadata"]["title"] = cleaned_data["geo_metadata"].get("title", title)
    cleaned_data["geo_metadata"]["type"] = "Point"

    # Add categories
    cleaned_data["categories"] = categories

    return cleaned_data

# Function to clean and update main content
def update_main_content(cleaned_data):
    # Remove pronunciation sections if available
    if "main_content" in cleaned_data:
        cleaned_data["main_content"] = remove_pronunciation(cleaned_data["main_content"])
    return cleaned_data

# Process files and handle exceptions
files_without_coordinates = []
for file in os.listdir(cleaned_data_path):
    try:
        cleaned_file_path = os.path.join(cleaned_data_path, file)
        raw_file_path = os.path.join(raw_data_path, file)

        # Load cleaned data
        with open(cleaned_file_path, "r", encoding="utf-8") as f:
            cleaned_data = json.load(f)

        # Extract title, coordinates, and categories from raw data
        with open(raw_file_path, "r", encoding="utf-8") as f:
            raw_content = f.read()
        title = re.search(r"<h1>(.*?)</h1>", raw_content).group(1).strip() if re.search(r"<h1>(.*?)</h1>", raw_content) else format_title(file)
        coordinates = extract_coordinates(raw_content)
        categories = assign_categories(cleaned_data["main_content"])

        # Update cleaned data
        cleaned_data = update_cleaned_file(cleaned_data, title, coordinates, categories)
        cleaned_data = update_main_content(cleaned_data)

        # Save updated cleaned data
        output_file_path = os.path.join(output_path, file)
        with open(output_file_path, "w", encoding="utf-8") as f:
            json.dump(cleaned_data, f, indent=4, ensure_ascii=False)
        
        print(f"Updated and saved: {file}")

        if not coordinates:
            files_without_coordinates.append(file)

    except Exception as e:
        print(f"Error processing file {file}: {e}")

# List files without coordinates
print("Files without coordinates:")
for file in files_without_coordinates:
    print(file)

# Assign coordinates based on municipality location
for file in files_without_coordinates:
    try:
        cleaned_file_path = os.path.join(output_path, file)
        with open(cleaned_file_path, "r", encoding="utf-8") as f:
            cleaned_data = json.load(f)

        # Assign coordinates based on municipality
        for municipality_file in os.listdir(municipality_data_path):
            municipality_name = municipality_file.replace(".json", "")
            if municipality_name.lower() in cleaned_data["geo_metadata"]["title"].lower():
                municipality_file_path = os.path.join(municipality_data_path, municipality_file)
                with open(municipality_file_path, "r", encoding="utf-8") as mf:
                    municipality_data = json.load(mf)
                cleaned_data["geo_metadata"]["coordinates"] = municipality_data["geo_metadata"]["coordinates"]
                break

        # Save updated cleaned data with municipality coordinates
        with open(cleaned_file_path, "w", encoding="utf-8") as f:
            json.dump(cleaned_data, f, indent=4, ensure_ascii=False)
        
        print(f"Assigned coordinates to: {file}")

    except Exception as e:
        print(f"Error assigning coordinates to file {file}: {e}")

# Save list of files without coordinates to a JSON file
with open(no_coordinates_output_path, "w", encoding="utf-8") as f:
    json.dump(files_without_coordinates, f, indent=4, ensure_ascii=False)

print(f"List of files without coordinates saved to {no_coordinates_output_path}")
# Out:
# Updated and saved: academia_del_perpetuo_socorro.txt
# Updated and saved: academia_interamericana_metro.txt
# Updated and saved: academia_maria_reina.txt
# Updated and saved: academia_san_jorge.txt
# Updated and saved: adjuntas_barrio-pueblo.txt
# Updated and saved: aguada_barrio-pueblo.txt
# Updated and saved: aguada_transmission_station.txt
# Updated and saved: aguadilla_barrio-pueblo.txt
# Updated and saved: aguadilla_ice_skating_arena.txt
# Updated and saved: aguas_buenas_barrio-pueblo.txt
# Updated and saved: aguas_buenas_cave_system.txt
# Updated and saved: aguirre_state_forest.txt
# Updated and saved: aibonito_barrio-pueblo.txt
# Updated and saved: aibonito_festival_of_flowers.txt
# Updated and saved: albergue_olímpico.txt
# Updated and saved: albizu_university.txt
# Updated and saved: ana_g._méndez_university.txt
# Updated and saved: antiguo_casino_de_ponce.txt
# Updated and saved: antiguo_cuartel_militar_español_de_ponce.txt
# Updated and saved: antiguo_hospital_militar_español_de_ponce.txt
# Updated and saved: archivo_general_de_puerto_rico.txt
# Updated and saved: arecibo_barrio-pueblo.txt
# Updated and saved: arecibo_light.txt
# Updated and saved: arecibo_observatory.txt
# Updated and saved: arecibo_telescope.txt
# Updated and saved: arenas_bridge.txt
# Updated and saved: arroyo_barrio-pueblo.txt
# Updated and saved: asilo_de_pobres.txt
# Updated and saved: ateneo_puertorriqueño.txt
# Updated and saved: auditorio_juan_pachín_vicéns.txt
# Updated and saved: añasco_barrio-pueblo.txt
# Updated and saved: bacardi.txt
# Updated and saved: bahía_de_jobos.txt
# Updated and saved: ballajá_barracks.txt
# Updated and saved: balneario_de_rincón.txt
# Updated and saved: banco_crédito_y_ahorro_ponceño_(building).txt
# Updated and saved: banco_de_ponce_(building).txt
# Updated and saved: barceloneta_barrio-pueblo.txt
# Updated and saved: barranquitas_barrio-pueblo.txt
# Updated and saved: basílica_menor_de_la_virgen_de_monserrate.txt
# Updated and saved: bayamón_barrio-pueblo.txt
# Updated and saved: bayamón_city_hall.txt
# Updated and saved: bayamón_river.txt
# Updated and saved: baños_de_coamo.txt
# Updated and saved: biblical_magi.txt
# Updated and saved: biblioteca_carnegie.txt
# Updated and saved: biblioteca_municipal_de_ponce.txt
# Updated and saved: birth_of_the_new_world.txt
# Updated and saved: black_sand.txt
# Updated and saved: blue_beach_(vieques).txt
# Updated and saved: bobbin_lace.txt
# Updated and saved: bolera_caribe.txt
# Updated and saved: boquerón,_cabo_rojo,_puerto_rico.txt
# Updated and saved: boquerón_state_forest.txt
# Updated and saved: braulio_castillo.txt
# Updated and saved: buyé_beach.txt
# Updated and saved: cabo_rojo_barrio-pueblo.txt
# Updated and saved: cabo_rojo_national_wildlife_refuge.txt
# Updated and saved: café_rico.txt
# Updated and saved: caguana_ceremonial_ball_courts_site.txt
# Updated and saved: caguas_barrio-pueblo.txt
# Updated and saved: caguas_city_hall.txt
# Updated and saved: caguas_museum_of_art.txt
# Updated and saved: caguas_museum_of_folk_arts.txt
# Updated and saved: caguas_museum_of_tobacco.txt
# Updated and saved: caguas_valley.txt
# Updated and saved: caja_de_muertos.txt
# Updated and saved: calle_25_de_enero.txt
# Updated and saved: cambalache_forest_reserve.txt
# Updated and saved: campamento_santiago.txt
# Updated and saved: campo_atlético_charles_h._terry.txt
# Updated and saved: camuy_barrio-pueblo.txt
# Updated and saved: camuy_river.txt
# Updated and saved: canóvanas_barrio-pueblo.txt
# Updated and saved: caparra_archaeological_site.txt
# Updated and saved: cape_san_juan_light.txt
# Updated and saved: capilla_del_cristo.txt
# Updated and saved: capitol_of_puerto_rico.txt
# Updated and saved: caracas_beach_(vieques).txt
# Updated and saved: cardona_(ponce).txt
# Updated and saved: cardona_residence.txt
# Updated and saved: caribe_hilton_hotel.txt
# Updated and saved: carite_lake.txt
# Updated and saved: carite_state_forest.txt
# Updated and saved: carolina_barrio-pueblo.txt
# Updated and saved: carraízo_dam.txt
# Updated and saved: casa_alonso.txt
# Updated and saved: casa_blanca_(san_juan).txt
# Updated and saved: casa_cautiño.txt
# Updated and saved: casa_del_rey.txt
# Updated and saved: casa_de_españa.txt
# Updated and saved: casa_dra._concha_melendez_ramirez.txt
# Updated and saved: casa_fernando_luis_toro.txt
# Updated and saved: casa_font-ubides.txt
# Updated and saved: casa_franceschi_antongiorgi.txt
# Updated and saved: casa_natal_de_luis_muñoz_rivera.txt
# Updated and saved: casa_nemesio_canales.txt
# Updated and saved: casa_oppenheimer.txt
# Updated and saved: casa_paoli.txt
# Updated and saved: casa_pueblo_puerto_rico.txt
# Updated and saved: casa_roig_museum.txt
# Updated and saved: casa_rosa.txt
# Updated and saved: casa_rosita_serrallés.txt
# Updated and saved: casa_salazar-candal.txt
# Updated and saved: casa_serralles.txt
# Updated and saved: casa_wiechers-villaronga.txt
# Updated and saved: casona_césari.txt
# Updated and saved: castillo_san_cristóbal_(san_juan).txt
# Updated and saved: castillo_san_felipe_del_morro.txt
# Updated and saved: castillo_san_felipe_del_morro_lighthouse.txt
# Updated and saved: castillo_serrallés.txt
# Updated and saved: cataño_barrio-pueblo.txt
# Updated and saved: catedral_de_nuestra_señora_de_guadalupe.txt
# Updated and saved: catedral_de_san_felipe_apóstol_(arecibo,_puerto_rico).txt
# Updated and saved: catedral_dulce_nombre_de_jesús_(caguas,_puerto_rico).txt
# Updated and saved: catedral_metropolitana_basílica_de_san_juan_bautista_(san_juan,_puerto_rico).txt
# Updated and saved: cathedral_of_rum.txt
# Updated and saved: cayey_barrio-pueblo.txt
# Updated and saved: cayos_de_caña_gorda.txt
# Updated and saved: cayo_icacos.txt
# Updated and saved: cayo_luis_peña.txt
# Updated and saved: caño_tiburones.txt
# Updated and saved: ceiba_barrio-pueblo.txt
# Updated and saved: cementerio_católico_san_vicente_de_paul.txt
# Updated and saved: cementerio_civil_de_ponce.txt
# Updated and saved: center_for_advanced_studies_on_puerto_rico_and_the_caribbean.txt
# Updated and saved: central_aguirre_historic_district.txt
# Updated and saved: central_cortada.txt
# Updated and saved: central_guánica.txt
# Updated and saved: central_high_school_(san_juan,_puerto_rico).txt
# Updated and saved: centro_ceremonial_indígena_de_tibes.txt
# Updated and saved: centro_cultural_baudilio_vega_berríos.txt
# Updated and saved: centro_cultural_de_ponce_carmen_solá_de_pereira.txt
# Updated and saved: centro_del_sur_mall.txt
# Updated and saved: centro_de_convenciones_de_ponce.txt
# Updated and saved: cerrillos_state_forest.txt
# Updated and saved: cerro_de_punta.txt
# Updated and saved: cerro_las_tetas.txt
# Updated and saved: cerro_maravilla.txt
# Updated and saved: cerro_morales_(utuado,_puerto_rico).txt
# Updated and saved: cerro_rosa.txt
# Updated and saved: cervecería_india.txt
# Updated and saved: chalet_amill.txt
# Updated and saved: christopher_columbus.txt
# Updated and saved: church_of_saint_francis_of_assisi,_san_juan.txt
# Updated and saved: church_of_san_francisco_de_asís.txt
# Updated and saved: church_of_san_mateo_de_cangrejos_of_santurce.txt
# Updated and saved: church_san_blas_de_illescas_of_coamo.txt
# Updated and saved: church_san_josé_of_aibonito.txt
# Updated and saved: church_san_miguel_arcángel_of_utuado.txt
# Updated and saved: ciales_barrio-pueblo.txt
# Updated and saved: cidra_barrio-pueblo.txt
# Updated and saved: ciudad_deportiva_millito_navarro.txt
# Updated and saved: club_deportivo_del_oeste.txt
# Updated and saved: club_nautico_de_ponce.txt
# Updated and saved: club_náutico_de_ponce.txt
# Updated and saved: coamo_barrio-pueblo.txt
# Updated and saved: coca-cola_music_hall.txt
# Updated and saved: colegio_ponceño.txt
# Updated and saved: colegio_san_conrado.txt
# Updated and saved: coliseo_manuel_iguina.txt
# Updated and saved: coliseo_rubén_rodríguez.txt
# Updated and saved: coloso_sugar_cane_refinery.txt
# Updated and saved: comerío_barrio-pueblo.txt
# Updated and saved: complejo_recreativo_y_cultural_la_guancha.txt
# Updated and saved: concatedral_dulce_nombre_de_jesús_(humacao,_puerto_rico).txt
# Updated and saved: condado_(santurce).txt
# Updated and saved: condado_lagoon.txt
# Updated and saved: condado_vanderbilt_hotel.txt
# Updated and saved: conservatory_of_music_of_puerto_rico.txt
# Updated and saved: corozal_barrio-pueblo.txt
# Updated and saved: couroupita_nicaraguarensis.txt
# Updated and saved: crash_boat_beach.txt
# Updated and saved: cruceta_del_vigía.txt
# Updated and saved: cuevas_las_cabachuelas.txt
# Updated and saved: cueva_del_indio_(arecibo).txt
# Updated and saved: cueva_del_indio_(las_piedras).txt
# Updated and saved: cueva_lucero.txt
# Updated and saved: cueva_ventana.txt
# Updated and saved: culebra_barrio-pueblo.txt
# Updated and saved: culebra_national_wildlife_refuge.txt
# Updated and saved: culebrita.txt
# Updated and saved: dead_dog_beach.txt
# Updated and saved: desecheo_national_wildlife_refuge.txt
# Updated and saved: destilería_serrallés.txt
# Updated and saved: district_courthouse_(aguadilla,_puerto_rico).txt
# Updated and saved: domes_beach.txt
# Updated and saved: dorado_barrio-pueblo.txt
# Updated and saved: dos_bocas_lake.txt
# Updated and saved: dos_hermanos_bridge.txt
# Updated and saved: dr._juan_a._rivero_zoo.txt
# Updated and saved: edificio_aboy.txt
# Updated and saved: edificio_comunidad_de_orgullo_gay_de_puerto_rico.txt
# Updated and saved: edificio_del_valle.txt
# Updated and saved: edificio_josé_de_diego.txt
# Updated and saved: edificio_oliver.txt
# Updated and saved: edificio_patio_español.txt
# Updated and saved: edificio_victory_garden.txt
# Updated and saved: el_falansterio_de_puerta_de_tierra.txt
# Updated and saved: el_gigante_dormido.txt
# Updated and saved: el_monumento_de_la_recordación.txt
# Updated and saved: el_parterre.txt
# Updated and saved: el_toro_wilderness.txt
# Updated and saved: el_tuque.txt
# Updated and saved: el_yunque_national_forest.txt
# Updated and saved: enrique_laguerre.txt
# Updated and saved: ensenada_honda_(culebra,_puerto_rico).txt
# Updated and saved: episcopal_cathedral_of_st._john_the_baptist_(san_juan,_puerto_rico).txt
# Updated and saved: ermita_nuestra_señora_de_la_valvanera.txt
# Updated and saved: escuela_brambaugh.txt
# Updated and saved: escuela_de_artes_plásticas_y_diseño_de_puerto_rico.txt
# Updated and saved: esperanza_beach.txt
# Updated and saved: estadio_country_club.txt
# Updated and saved: estadio_francisco_montaner.txt
# Updated and saved: estadio_sixto_escobar.txt
# Updated and saved: fajardo_barrio-pueblo.txt
# Updated and saved: farmers'_market.txt
# Updated and saved: faro_del_puerto_de_ponce.txt
# Updated and saved: faro_de_la_isla_de_caja_de_muertos.txt
# Updated and saved: filardi_house.txt
# Updated and saved: flamenco_beach.txt
# Updated and saved: florida,_puerto_rico.txt
# Updated and saved: fort_buchanan,_puerto_rico.txt
# Updated and saved: fortín_de_san_gerónimo.txt
# Updated and saved: fortín_san_antonio.txt
# Updated and saved: fortín_san_juan_de_la_cruz.txt
# Updated and saved: francisco_oller.txt
# Updated and saved: fuerte_de_la_concepción.txt
# Updated and saved: fuerte_de_vieques.txt
# Updated and saved: galería_nacional.txt
# Updated and saved: gatas_(ponce).txt
# Updated and saved: general_norzagaray_bridge.txt
# Updated and saved: general_store.txt
# Updated and saved: guajataca_lake.txt
# Updated and saved: guajataca_state_forest.txt
# Updated and saved: guajataca_tunnel.txt
# Updated and saved: guavate,_cayey,_puerto_rico.txt
# Updated and saved: guayama_barrio-pueblo.txt
# Updated and saved: guayanilla_barrio-pueblo.txt
# Updated and saved: guaynabo_barrio-pueblo.txt
# Updated and saved: guilarte_state_forest.txt
# Updated and saved: gurabo_barrio-pueblo.txt
# Updated and saved: guánica_barrio-pueblo.txt
# Updated and saved: guánica_light.txt
# Updated and saved: guánica_state_forest.txt
# Updated and saved: gómez_residence.txt
# Updated and saved: hacienda_azucarera_la_esperanza.txt
# Updated and saved: hacienda_buena_vista.txt
# Updated and saved: hacienda_el_jibarito.txt
# Updated and saved: hacienda_juanita.txt
# Updated and saved: hacienda_lealtad.txt
# Updated and saved: hacienda_santa_rita.txt
# Updated and saved: hacienda_san_francisco.txt
# Updated and saved: hatillo_barrio-pueblo.txt
# Updated and saved: henry_klumb_house.txt
# Updated and saved: hermitage_of_san_antonio_de_padua_de_la_tuna.txt
# Updated and saved: hipódromo_camarero.txt
# Updated and saved: hiram_bithorn_stadium.txt
# Updated and saved: hormigueros_barrio-pueblo.txt
# Updated and saved: horse_racing.txt
# Updated and saved: hotel_el_convento.txt
# Updated and saved: hotel_melia.txt
# Updated and saved: hotel_ponce_intercontinental.txt
# Updated and saved: hotel_ponce_ramada.txt
# Updated and saved: house_at_659_concordia_street.txt
# Updated and saved: house_at_659_la_paz_street.txt
# Updated and saved: house_at_663_la_paz_street.txt
# Updated and saved: house_at_665_mckinley_street.txt
# Updated and saved: humacao_barrio-pueblo.txt
# Updated and saved: humacao_nature_reserve.txt
# Updated and saved: húcares.txt
# Updated and saved: iglesia_de_la_santísima_trinidad.txt
# Updated and saved: iglesia_de_nuestra_señora_del_carmen.txt
# Updated and saved: iglesia_de_san_antonio_de_padua.txt
# Updated and saved: iglesia_san_germán_de_auxerre.txt
# Updated and saved: iglesia_san_sebastián_mártir.txt
# Updated and saved: industrias_vassallo.txt
# Updated and saved: institute_of_puerto_rican_culture.txt
# Updated and saved: interamerican_university_of_puerto_rico.txt
# Updated and saved: interamerican_university_of_puerto_rico_at_ponce.txt
# Updated and saved: isabela_barrio-pueblo.txt
# Updated and saved: isabel_ii_barrio-pueblo.txt
# Updated and saved: isla_del_frío.txt
# Updated and saved: isla_de_cabras.txt
# Updated and saved: isla_de_jueyes.txt
# Updated and saved: isla_de_mona.txt
# Updated and saved: isla_de_ratones_(cabo_rojo,_puerto_rico).txt
# Updated and saved: isla_de_ratones_(ponce,_puerto_rico).txt
# Updated and saved: isla_magueyes.txt
# Updated and saved: isla_mata_la_gata.txt
# Updated and saved: isla_palomino.txt
# Updated and saved: isla_verde,_puerto_rico.txt
# Updated and saved: jayuya_barrio-pueblo.txt
# Updated and saved: jesús_izcoa_moure_bridge.txt
# Updated and saved: jesús_t._piñero_house.txt
# Updated and saved: jobos_beach.txt
# Updated and saved: jose_v._toledo_federal_building_and_united_states_courthouse.txt
# Updated and saved: josé_celso_barbosa.txt
# Updated and saved: josé_miguel_agrelot_coliseum.txt
# Updated and saved: joyuda,_puerto_rico.txt
# Updated and saved: joyuda_lagoon.txt
# Updated and saved: juana_díaz_barrio-pueblo.txt
# Updated and saved: juan_boria.txt
# Updated and saved: juan_ramón_loubriel_stadium.txt
# Updated and saved: julia_de_burgos.txt
# Updated and saved: julio_enrique_monagas_park.txt
# Updated and saved: juncos_barrio-pueblo.txt
# Updated and saved: lago_dos_bocas.txt
# Updated and saved: laguna_cartagena_national_wildlife_refuge.txt
# Updated and saved: lajas_barrio-pueblo.txt
# Updated and saved: lake_luchetti.txt
# Updated and saved: lares_barrio-pueblo.txt
# Updated and saved: lares_ice_cream_parlor.txt
# Updated and saved: las_cabañas_bridge.txt
# Updated and saved: las_cascadas_water_park.txt
# Updated and saved: las_catalinas_mall.txt
# Updated and saved: las_marías_barrio-pueblo.txt
# Updated and saved: las_piedras_barrio-pueblo.txt
# Updated and saved: la_bombonera_(san_juan).txt
# Updated and saved: la_concha_renaissance_san_juan_resort.txt
# Updated and saved: la_cordillera_reef_nature_reserve.txt
# Updated and saved: la_fortaleza.txt
# Updated and saved: la_giralda_(san_juan,_puerto_rico).txt
# Updated and saved: la_guancha_(ponce,_puerto_rico).txt
# Updated and saved: la_liendre_bridge.txt
# Updated and saved: la_mallorquina.txt
# Updated and saved: la_parguera.txt
# Updated and saved: la_perla,_san_juan,_puerto_rico.txt
# Updated and saved: la_placita_de_santurce.txt
# Updated and saved: la_plata_lake.txt
# Updated and saved: la_pocita_de_las_golondrinas_beach.txt
# Updated and saved: la_ventana_al_mar.txt
# Updated and saved: lechon.txt
# Updated and saved: legend_of_diego_salcedo.txt
# Updated and saved: letras_de_ponce.txt
# Updated and saved: lin-manuel_miranda.txt
# Updated and saved: logia_masónica_hijos_de_la_luz.txt
# Updated and saved: los_chinos_de_ponce.txt
# Updated and saved: los_morrillos_lighthouse.txt
# Updated and saved: los_tres_picachos.txt
# Updated and saved: los_tres_picachos_state_forest.txt
# Updated and saved: los_túneles_subterráneos_de_san_germán.txt
# Updated and saved: loverbar.txt
# Updated and saved: loíza_barrio-pueblo.txt
# Updated and saved: loíza_lake.txt
# Updated and saved: luis_a._ferré_performing_arts_center.txt
# Updated and saved: luis_a._ferré_united_states_courthouse_and_post_office_building.txt
# Updated and saved: luis_muñoz_marín_international_airport.txt
# Updated and saved: luis_muñoz_marín_park.txt
# Updated and saved: luis_muñoz_rivera_park.txt
# Updated and saved: luquillo_barrio-pueblo.txt
# Updated and saved: luquillo_beach.txt
# Updated and saved: línea_avanzada.txt
# Updated and saved: lópez_residence.txt
# Updated and saved: manatí_barrio-pueblo.txt
# Updated and saved: manatí_bridge_at_mata_de_plátano.txt
# Updated and saved: maricao_barrio-pueblo.txt
# Updated and saved: maricao_fish_hatchery.txt
# Updated and saved: maricao_state_forest.txt
# Updated and saved: mario_morales_coliseum.txt
# Updated and saved: martín_peña_bridge.txt
# Updated and saved: mar_bella_beach.txt
# Updated and saved: maunabo_barrio-pueblo.txt
# Updated and saved: mavilla_bridge.txt
# Updated and saved: mayagüez_barrio-pueblo.txt
# Updated and saved: mayagüez_city_hall.txt
# Updated and saved: mayagüez_resort_&_casino.txt
# Updated and saved: mccabe_memorial_church.txt
# Updated and saved: miramar_(santurce).txt
# Updated and saved: mizpa_pentecostal_university.txt
# Updated and saved: moca_barrio-pueblo.txt
# Updated and saved: mona_ground_iguana.txt
# Updated and saved: monte_jayuya.txt
# Updated and saved: monumento_al_jíbaro_puertorriqueño.txt
# Updated and saved: monumento_a_la_abolición_de_la_exclavitud.txt
# Updated and saved: monumento_a_los_heroes_de_el_polvorín_(obelisk).txt
# Updated and saved: monumento_a_los_heroes_de_el_polvorín_(tomb).txt
# Updated and saved: morovis_barrio-pueblo.txt
# Updated and saved: morovis_national_cemetery.txt
# Updated and saved: morrillito.txt
# Updated and saved: museo_castillo_serrallés.txt
# Updated and saved: museo_del_autonomismo_puertorriqueño.txt
# Updated and saved: museo_de_arte_de_ponce.txt
# Updated and saved: museo_de_la_arquitectura_ponceña.txt
# Updated and saved: museo_de_la_historia_de_ponce.txt
# Updated and saved: museo_de_la_masacre_de_ponce.txt
# Updated and saved: museo_de_la_música_puertorriqueña.txt
# Updated and saved: museo_de_vida_silvestre.txt
# Updated and saved: museum_of_art_of_puerto_rico.txt
# Updated and saved: museum_of_transportation_of_puerto_rico.txt
# Updated and saved: naguabo_barrio-pueblo.txt
# Updated and saved: naranjito_barrio-pueblo.txt
# Updated and saved: normandie_hotel.txt
# Updated and saved: nuestra_señora_de_lourdes_chapel.txt
# Updated and saved: nuevo_milenio_state_forest.txt
# Updated and saved: ocean_park_(santurce).txt
# Updated and saved: old_piedras_river_aqueduct.txt
# Updated and saved: old_san_juan.txt
# Updated and saved: orocovis.txt
# Updated and saved: orocovis_barrio-pueblo.txt
# Updated and saved: orthodox_judaism.txt
# Updated and saved: our_lady_of_lourdes.txt
# Updated and saved: pablo_casals_museum.txt
# Updated and saved: palacete_los_moreau.txt
# Updated and saved: palmas_del_mar.txt
# Updated and saved: panteón_nacional_román_baldorioty_de_castro.txt
# Updated and saved: parque_del_litoral.txt
# Updated and saved: parque_del_retiro.txt
# Updated and saved: parque_del_tricentenario_(ponce,_puerto_rico).txt
# Updated and saved: parque_de_bombas.txt
# Updated and saved: parque_de_bombas_maximiliano_merced.txt
# Updated and saved: parque_de_las_ciencias.txt
# Updated and saved: parque_de_la_abolición.txt
# Updated and saved: parque_de_la_ceiba.txt
# Updated and saved: parque_ecológico_urbano.txt
# Updated and saved: parque_familiar_julio_enrique_monagas.txt
# Updated and saved: parque_lineal_veredas_del_labrador.txt
# Updated and saved: parque_luis_a._wito_morales.txt
# Updated and saved: parque_nacional_de_las_cavernas_del_río_camuy.txt
# Updated and saved: parque_pedro_albizu_campos.txt
# Updated and saved: parque_urbano_dora_colón_clavell.txt
# Updated and saved: parroquia_del_espíritu_santo_y_san_patricio.txt
# Updated and saved: paseo_atocha.txt
# Updated and saved: paseo_de_la_princesa.txt
# Updated and saved: paseo_tablado_la_guancha.txt
# Updated and saved: paseo_víctor_rojas.txt
# Updated and saved: patillas_barrio-pueblo.txt
# Updated and saved: peñuelas_barrio-pueblo.txt
# Updated and saved: pico_piedra.txt
# Updated and saved: pico_rodadero.txt
# Updated and saved: picó_pomar_residence.txt
# Updated and saved: piñones_state_forest.txt
# Updated and saved: playa_espinar.txt
# Updated and saved: playita_del_condado.txt
# Updated and saved: plaza_carolina.txt
# Updated and saved: plaza_colón.txt
# Updated and saved: plaza_colón_(san_juan).txt
# Updated and saved: plaza_degetau.txt
# Updated and saved: plaza_del_caribe.txt
# Updated and saved: plaza_del_mercado_de_ponce.txt
# Updated and saved: plaza_del_norte.txt
# Updated and saved: plaza_del_quinto_centenario.txt
# Updated and saved: plaza_del_sol_(puerto_rico).txt
# Updated and saved: plaza_de_armas,_san_juan.txt
# Updated and saved: plaza_de_la_catedral_(san_juan).txt
# Updated and saved: plaza_de_san_josé.txt
# Updated and saved: plaza_juan_ponce_de_león.txt
# Updated and saved: plaza_las_américas_(puerto_rico).txt
# Updated and saved: plaza_las_delicias.txt
# Updated and saved: plaza_muñoz_rivera.txt
# Updated and saved: plaza_rio_hondo.txt
# Updated and saved: polvorín_de_miraflores.txt
# Updated and saved: polytechnic_university_of_puerto_rico.txt
# Updated and saved: ponce_cement,_inc..txt
# Updated and saved: ponce_city_hall.txt
# Updated and saved: ponce_high_school.txt
# Updated and saved: ponce_historic_zone.txt
# Updated and saved: ponce_school_of_medicine.txt
# Updated and saved: ponce_ymca_building.txt
# Updated and saved: pontificia_universidad_católica_de_puerto_rico.txt
# Updated and saved: porta_coeli_(puerto_rico).txt
# Updated and saved: pozo_de_jacinto.txt
# Updated and saved: primera_iglesia_bautista_de_caguas.txt
# Updated and saved: primera_iglesia_metodista_unida_de_ponce.txt
# Updated and saved: pueblo,_san_juan,_puerto_rico.txt
# Updated and saved: puente_blanco.txt
# Updated and saved: puente_de_coloso.txt
# Updated and saved: puente_de_las_calabazas.txt
# Updated and saved: puente_no._6.txt
# Updated and saved: puerta_de_tierra,_san_juan.txt
# Updated and saved: puerto_del_rey_marina.txt
# Updated and saved: puerto_rico.txt
# Updated and saved: puerto_rico_convention_center.txt
# Updated and saved: puerto_rico_iron_works.txt
# Updated and saved: puerto_rico_museum_of_contemporary_art.txt
# Updated and saved: puerto_rico_national_library.txt
# Updated and saved: punta_borinquen_light.txt
# Updated and saved: punta_de_las_figuras_light.txt
# Updated and saved: punta_higuero_light.txt
# Updated and saved: punta_mulas_light.txt
# Updated and saved: punta_santiago,_humacao,_puerto_rico.txt
# Updated and saved: punta_tuna_light.txt
# Updated and saved: quebradillas_barrio-pueblo.txt
# Updated and saved: rafael_hernández_marín.txt
# Updated and saved: ramón_rivero_(diplo).txt
# Updated and saved: residencia_aboy-lompré.txt
# Updated and saved: residencia_armstrong-poventud.txt
# Updated and saved: residencia_rosaly-batiz.txt
# Updated and saved: residencia_subirá.txt
# Updated and saved: rincón_barrio-pueblo.txt
# Updated and saved: roberto_clemente_coliseum.txt
# Updated and saved: roberto_clemente_stadium.txt
# Updated and saved: roosevelt_roads_naval_station.txt
# Updated and saved: rovira_biscuits_corporation.txt
# Updated and saved: rum.txt
# Updated and saved: rum_planetarium.txt
# Updated and saved: río_abajo_state_forest.txt
# Updated and saved: río_grande_barrio-pueblo.txt
# Updated and saved: río_grande_de_loíza.txt
# Updated and saved: río_matón_bridge.txt
# Updated and saved: río_piedras_bridge.txt
# Updated and saved: sabana_grande_barrio-pueblo.txt
# Updated and saved: sabana_grande_masonic_cemetery.txt
# Updated and saved: saint_john's_school_(san_juan).txt
# Updated and saved: saliente_river.txt
# Updated and saved: salinas_barrio-pueblo.txt
# Updated and saved: samuel_morse.txt
# Updated and saved: santa_ana_church_(san_juan).txt
# Updated and saved: santa_isabel_barrio-pueblo.txt
# Updated and saved: santa_maría_magdalena_de_pazzis_cemetery.txt
# Updated and saved: santurce,_san_juan,_puerto_rico.txt
# Updated and saved: san_cristóbal_canyon.txt
# Updated and saved: san_germán_historic_district.txt
# Updated and saved: san_josé_church.txt
# Updated and saved: san_juan_botanical_garden.txt
# Updated and saved: san_juan_city_hall.txt
# Updated and saved: san_juan_marriott_resort_&_stellaris_casino.txt
# Updated and saved: san_juan_natatorium.txt
# Updated and saved: san_juan_puerto_rico_temple.txt
# Updated and saved: san_lorenzo_barrio-pueblo.txt
# Updated and saved: san_miguel_arcángel_church_(cabo_rojo).txt
# Updated and saved: san_patricio_plaza.txt
# Updated and saved: san_patricio_state_forest.txt
# Updated and saved: san_sebastián_barrio-pueblo.txt
# Updated and saved: school_of_tropical_medicine_(puerto_rico).txt
# Updated and saved: sixto_escobar.txt
# Updated and saved: stud_farm.txt
# Updated and saved: supreme_court_building_(puerto_rico).txt
# Updated and saved: susúa_state_forest.txt
# Updated and saved: t-mobile_district.txt
# Updated and saved: teatro_fox_delicias.txt
# Updated and saved: teatro_la_perla.txt
# Updated and saved: teatro_tapia.txt
# Updated and saved: teatro_yagüez.txt
# Updated and saved: teodoro_moscoso_bridge.txt
# Updated and saved: the_mall_of_san_juan.txt
# Updated and saved: tito_puente_amphitheatre.txt
# Updated and saved: toa_alta_barrio-pueblo.txt
# Updated and saved: toa_baja_barrio-pueblo.txt
# Updated and saved: toro_negro_state_forest.txt
# Updated and saved: tortuguero_lagoon.txt
# Updated and saved: train_of_the_south.txt
# Updated and saved: trujillo_alto_barrio-pueblo.txt
# Updated and saved: u.s._custom_house_(san_juan,_puerto_rico).txt
# Updated and saved: u.s._post_office_and_courthouse_(mayagüez,_puerto_rico).txt
# Updated and saved: united_states_customs_house_(fajardo,_puerto_rico).txt
# Updated and saved: united_states_customs_house_(ponce,_puerto_rico).txt
# Updated and saved: united_states_district_court_for_the_district_of_puerto_rico.txt
# Updated and saved: universidad_del_sagrado_corazón.txt
# Updated and saved: university_gardens_high_school.txt
# Updated and saved: university_high_school_(san_juan).txt
# Updated and saved: university_of_puerto_rico,_medical_sciences_campus.txt
# Updated and saved: university_of_puerto_rico,_río_piedras_campus.txt
# Updated and saved: university_of_puerto_rico_at_cayey.txt
# Updated and saved: university_of_puerto_rico_at_humacao.txt
# Updated and saved: university_of_puerto_rico_at_mayagüez.txt
# Updated and saved: university_of_puerto_rico_at_ponce.txt
# Updated and saved: university_of_puerto_rico_school_of_medicine.txt
# Updated and saved: uss_killen_(dd-593).txt
# Updated and saved: utuado_barrio-pueblo.txt
# Updated and saved: vega_alta_barrio-pueblo.txt
# Updated and saved: vega_baja_barrio-pueblo.txt
# Updated and saved: vega_state_forest.txt
# Updated and saved: vieques_national_wildlife_refuge.txt
# Updated and saved: villalba,_puerto_rico.txt
# Updated and saved: villalba_barrio-pueblo.txt
# Updated and saved: villa_pesquera.txt
# Updated and saved: west_indian_manatee.txt
# Updated and saved: whale_watching.txt
# Updated and saved: william_miranda_marín_botanical_and_cultural_garden.txt
# Updated and saved: world_war_ii.txt
# Updated and saved: yabucoa_barrio-pueblo.txt
# Updated and saved: yauco_barrio-pueblo.txt
# Updated and saved: zona_historica_de_ponce.txt
# Files without coordinates:
# aguas_buenas_cave_system.txt
# aibonito_festival_of_flowers.txt
# archivo_general_de_puerto_rico.txt
# bacardi.txt
# bayamón_river.txt
# biblical_magi.txt
# black_sand.txt
# bobbin_lace.txt
# boquerón_state_forest.txt
# braulio_castillo.txt
# cambalache_forest_reserve.txt
# casa_pueblo_puerto_rico.txt
# central_aguirre_historic_district.txt
# christopher_columbus.txt
# couroupita_nicaraguarensis.txt
# cueva_del_indio_(las_piedras).txt
# cueva_lucero.txt
# enrique_laguerre.txt
# farmers'_market.txt
# francisco_oller.txt
# general_store.txt
# guajataca_state_forest.txt
# guilarte_state_forest.txt
# hacienda_azucarera_la_esperanza.txt
# hacienda_buena_vista.txt
# horse_racing.txt
# interamerican_university_of_puerto_rico.txt
# jesús_t._piñero_house.txt
# josé_celso_barbosa.txt
# juan_boria.txt
# julia_de_burgos.txt
# julio_enrique_monagas_park.txt
# la_mallorquina.txt
# lechon.txt
# legend_of_diego_salcedo.txt
# lin-manuel_miranda.txt
# mona_ground_iguana.txt
# nuevo_milenio_state_forest.txt
# orthodox_judaism.txt
# our_lady_of_lourdes.txt
# rafael_hernández_marín.txt
# ramón_rivero_(diplo).txt
# rum.txt
# saint_john's_school_(san_juan).txt
# samuel_morse.txt
# sixto_escobar.txt
# stud_farm.txt
# united_states_district_court_for_the_district_of_puerto_rico.txt
# university_of_puerto_rico,_medical_sciences_campus.txt
# university_of_puerto_rico_school_of_medicine.txt
# uss_killen_(dd-593).txt
# west_indian_manatee.txt
# whale_watching.txt
# world_war_ii.txt
# Assigned coordinates to: aguas_buenas_cave_system.txt
# Assigned coordinates to: aibonito_festival_of_flowers.txt
# Assigned coordinates to: archivo_general_de_puerto_rico.txt
# Assigned coordinates to: bacardi.txt
# Assigned coordinates to: bayamón_river.txt
# Assigned coordinates to: biblical_magi.txt
# Assigned coordinates to: black_sand.txt
# Assigned coordinates to: bobbin_lace.txt
# Assigned coordinates to: boquerón_state_forest.txt
# Assigned coordinates to: braulio_castillo.txt
# Assigned coordinates to: cambalache_forest_reserve.txt
# Assigned coordinates to: casa_pueblo_puerto_rico.txt
# Assigned coordinates to: central_aguirre_historic_district.txt
# Assigned coordinates to: christopher_columbus.txt
# Assigned coordinates to: couroupita_nicaraguarensis.txt
# Assigned coordinates to: cueva_del_indio_(las_piedras).txt
# Assigned coordinates to: cueva_lucero.txt
# Assigned coordinates to: enrique_laguerre.txt
# Assigned coordinates to: farmers'_market.txt
# Assigned coordinates to: francisco_oller.txt
# Assigned coordinates to: general_store.txt
# Assigned coordinates to: guajataca_state_forest.txt
# Assigned coordinates to: guilarte_state_forest.txt
# Assigned coordinates to: hacienda_azucarera_la_esperanza.txt
# Assigned coordinates to: hacienda_buena_vista.txt
# Assigned coordinates to: horse_racing.txt
# Assigned coordinates to: interamerican_university_of_puerto_rico.txt
# Assigned coordinates to: jesús_t._piñero_house.txt
# Assigned coordinates to: josé_celso_barbosa.txt
# Assigned coordinates to: juan_boria.txt
# Assigned coordinates to: julia_de_burgos.txt
# Assigned coordinates to: julio_enrique_monagas_park.txt
# Assigned coordinates to: la_mallorquina.txt
# Assigned coordinates to: lechon.txt
# Assigned coordinates to: legend_of_diego_salcedo.txt
# Assigned coordinates to: lin-manuel_miranda.txt
# Assigned coordinates to: mona_ground_iguana.txt
# Assigned coordinates to: nuevo_milenio_state_forest.txt
# Assigned coordinates to: orthodox_judaism.txt
# Assigned coordinates to: our_lady_of_lourdes.txt
# Assigned coordinates to: rafael_hernández_marín.txt
# Assigned coordinates to: ramón_rivero_(diplo).txt
# Assigned coordinates to: rum.txt
# Assigned coordinates to: saint_john's_school_(san_juan).txt
# Assigned coordinates to: samuel_morse.txt
# Assigned coordinates to: sixto_escobar.txt
# Assigned coordinates to: stud_farm.txt
# Assigned coordinates to: united_states_district_court_for_the_district_of_puerto_rico.txt
# Assigned coordinates to: university_of_puerto_rico,_medical_sciences_campus.txt
# Assigned coordinates to: university_of_puerto_rico_school_of_medicine.txt
# Assigned coordinates to: uss_killen_(dd-593).txt
# Assigned coordinates to: west_indian_manatee.txt
# Assigned coordinates to: whale_watching.txt
# Assigned coordinates to: world_war_ii.txt
# List of files without coordinates saved to C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleanng\no_coordinates_records.json

# %% [markdown]
# # **Final Cleaning Step No. 2: Update relevant links & Special Characters Removal**

# %%
import os
import json
import re

# Define input and output directories
final_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleaning\10Feb25_final_step01_title_cat_geo_clean"
final_cleaned_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleaning\10Feb25_final_step02_links_clean"

# Create final cleaned output directory if it doesn't exist
if not os.path.exists(final_cleaned_data_path):
    os.makedirs(final_cleaned_data_path)

# Define whitelisted domains for relevant links
WHITELISTED_DOMAINS = ["en.wikipedia.org", 
                       "es.wikipedia.org", 
                       "en.wikivoyage.org",  
                       "es.wikivoyage.org", 
                       "discoverpuertorico.com", 
                       "travel.usnews.com", 
                       "tripadvisor.com", 
                       "skyscanner.com", 
                       "lonelyplanet.com", 
                       "puertorico.com",
                       "geohack.toolforge.org", 
                       "paralanaturaleza.org", 
                       "sanjuanpuertorico.com", 
                       "zeepuertorico.com", 
                       "weather-us.com", 
                       "estuario.org", 
                       "lonelyplanet.com", 
                       "toroverdepr.com", 
                       "distritot-mobile.com", 
                       "prcomiccon.com", 
                       "www.nps.gov", 
                       "prconvention.com", 
                       "nationalgeographic.com", 
                       "areciboweb.50megs.com", 
                       "flickr.com", 
                       "islaculebra.com",
                       ]
# Function to filter relevant links based on whitelist
def filter_relevant_links(links):
    filtered_links = []
    for link in links:
        if any(domain in link for domain in WHITELISTED_DOMAINS) and "web.archive.org" not in link and "www.gotopuertorico.com" not in link and "stats.wikimedia.org" not in link:
            filtered_links.append(link)
    return list(set(filtered_links))  # Remove duplicates

# Define Main Special Characters Mapping
special_chars_mapping = {
    "\\xc3\\xa1": "á",
    "\\xc3\\xa9": "é",
    "\\xc3\\xad": "í",
    "\\xc3\\xb3": "ó",
    "\\xc3\\xba": "ú",
    "\\xc3\\xb1": "ñ",
    "\\xc3\\x9c": "Ü",
    "\\xc3\\xbc": "ü",
    "\\xe2\\x80\\x99": "'",
    "\\xe2\\x80\\x9c": "\"",
    "\\xe2\\x80\\x9d": "\"",
    "\\xca\\x9du\\xca\\x9d": "ü",
    "\\xcb\\x88": "'",
    "\\xa": " ",
    "\\xc2\\xb0F": "°F",
    "\\xc2\\xb0C": "°C",
    "\\xc2\\xb0": "°",
    "\\xe2\\x80\\x93": "-"
}

# Function for Fixing Special Characters
def fix_special_characters(text):
    for wrong, correct in special_chars_mapping.items():
        text = text.replace(wrong, correct)
    return text

# Function to ensure the relevant Wikipedia link is present
def ensure_wikipedia_link(links, landmark_name):
    # Generate the expected Wikipedia link
    wikipedia_link = f"https://en.wikipedia.org/wiki/{landmark_name}"
    
    # Check if the link is already in the list, if not, add it
    if wikipedia_link not in links:
        links.append(wikipedia_link)
    
    return links

# Process each file in the final_data directory
for file_name in os.listdir(final_data_path):
    file_path = os.path.join(final_data_path, file_name)

    with open(file_path, "r", encoding="utf-8") as file:
        data = json.load(file)

    # Clean relevant links
    if "relevant_links" in data:
        data["relevant_links"] = filter_relevant_links(data["relevant_links"])

    # Clean main content from Special Characters
    if "main_content" in data:
        data["main_content"] = fix_special_characters(data["main_content"])

    # Ensure relevant links contain the Wikipedia link for the landmark
    if "relevant_links" in data:
        landmark_name = os.path.splitext(file_name)[0]  # Extract landmark name from the file name
        data["relevant_links"] = ensure_wikipedia_link(data["relevant_links"], landmark_name)

    # Save the cleaned file to final_cleaned_data directory
    output_file_path = os.path.join(final_cleaned_data_path, file_name)
    with open(output_file_path, "w", encoding="utf-8") as output_file:
        json.dump(data, output_file, indent=4, ensure_ascii=False)

    print(f"Final cleaned and saved: {file_name}")
# Out:
# Final cleaned and saved: academia_del_perpetuo_socorro.txt
# Final cleaned and saved: academia_interamericana_metro.txt
# Final cleaned and saved: academia_maria_reina.txt
# Final cleaned and saved: academia_san_jorge.txt
# Final cleaned and saved: adjuntas_barrio-pueblo.txt
# Final cleaned and saved: aguada_barrio-pueblo.txt
# Final cleaned and saved: aguada_transmission_station.txt
# Final cleaned and saved: aguadilla_barrio-pueblo.txt
# Final cleaned and saved: aguadilla_ice_skating_arena.txt
# Final cleaned and saved: aguas_buenas_barrio-pueblo.txt
# Final cleaned and saved: aguas_buenas_cave_system.txt
# Final cleaned and saved: aguirre_state_forest.txt
# Final cleaned and saved: aibonito_barrio-pueblo.txt
# Final cleaned and saved: aibonito_festival_of_flowers.txt
# Final cleaned and saved: albergue_olímpico.txt
# Final cleaned and saved: albizu_university.txt
# Final cleaned and saved: ana_g._méndez_university.txt
# Final cleaned and saved: antiguo_casino_de_ponce.txt
# Final cleaned and saved: antiguo_cuartel_militar_español_de_ponce.txt
# Final cleaned and saved: antiguo_hospital_militar_español_de_ponce.txt
# Final cleaned and saved: archivo_general_de_puerto_rico.txt
# Final cleaned and saved: arecibo_barrio-pueblo.txt
# Final cleaned and saved: arecibo_light.txt
# Final cleaned and saved: arecibo_observatory.txt
# Final cleaned and saved: arecibo_telescope.txt
# Final cleaned and saved: arenas_bridge.txt
# Final cleaned and saved: arroyo_barrio-pueblo.txt
# Final cleaned and saved: asilo_de_pobres.txt
# Final cleaned and saved: ateneo_puertorriqueño.txt
# Final cleaned and saved: auditorio_juan_pachín_vicéns.txt
# Final cleaned and saved: añasco_barrio-pueblo.txt
# Final cleaned and saved: bacardi.txt
# Final cleaned and saved: bahía_de_jobos.txt
# Final cleaned and saved: ballajá_barracks.txt
# Final cleaned and saved: balneario_de_rincón.txt
# Final cleaned and saved: banco_crédito_y_ahorro_ponceño_(building).txt
# Final cleaned and saved: banco_de_ponce_(building).txt
# Final cleaned and saved: barceloneta_barrio-pueblo.txt
# Final cleaned and saved: barranquitas_barrio-pueblo.txt
# Final cleaned and saved: basílica_menor_de_la_virgen_de_monserrate.txt
# Final cleaned and saved: bayamón_barrio-pueblo.txt
# Final cleaned and saved: bayamón_city_hall.txt
# Final cleaned and saved: bayamón_river.txt
# Final cleaned and saved: baños_de_coamo.txt
# Final cleaned and saved: biblical_magi.txt
# Final cleaned and saved: biblioteca_carnegie.txt
# Final cleaned and saved: biblioteca_municipal_de_ponce.txt
# Final cleaned and saved: birth_of_the_new_world.txt
# Final cleaned and saved: black_sand.txt
# Final cleaned and saved: blue_beach_(vieques).txt
# Final cleaned and saved: bobbin_lace.txt
# Final cleaned and saved: bolera_caribe.txt
# Final cleaned and saved: boquerón,_cabo_rojo,_puerto_rico.txt
# Final cleaned and saved: boquerón_state_forest.txt
# Final cleaned and saved: braulio_castillo.txt
# Final cleaned and saved: buyé_beach.txt
# Final cleaned and saved: cabo_rojo_barrio-pueblo.txt
# Final cleaned and saved: cabo_rojo_national_wildlife_refuge.txt
# Final cleaned and saved: café_rico.txt
# Final cleaned and saved: caguana_ceremonial_ball_courts_site.txt
# Final cleaned and saved: caguas_barrio-pueblo.txt
# Final cleaned and saved: caguas_city_hall.txt
# Final cleaned and saved: caguas_museum_of_art.txt
# Final cleaned and saved: caguas_museum_of_folk_arts.txt
# Final cleaned and saved: caguas_museum_of_tobacco.txt
# Final cleaned and saved: caguas_valley.txt
# Final cleaned and saved: caja_de_muertos.txt
# Final cleaned and saved: calle_25_de_enero.txt
# Final cleaned and saved: cambalache_forest_reserve.txt
# Final cleaned and saved: campamento_santiago.txt
# Final cleaned and saved: campo_atlético_charles_h._terry.txt
# Final cleaned and saved: camuy_barrio-pueblo.txt
# Final cleaned and saved: camuy_river.txt
# Final cleaned and saved: canóvanas_barrio-pueblo.txt
# Final cleaned and saved: caparra_archaeological_site.txt
# Final cleaned and saved: cape_san_juan_light.txt
# Final cleaned and saved: capilla_del_cristo.txt
# Final cleaned and saved: capitol_of_puerto_rico.txt
# Final cleaned and saved: caracas_beach_(vieques).txt
# Final cleaned and saved: cardona_(ponce).txt
# Final cleaned and saved: cardona_residence.txt
# Final cleaned and saved: caribe_hilton_hotel.txt
# Final cleaned and saved: carite_lake.txt
# Final cleaned and saved: carite_state_forest.txt
# Final cleaned and saved: carolina_barrio-pueblo.txt
# Final cleaned and saved: carraízo_dam.txt
# Final cleaned and saved: casa_alonso.txt
# Final cleaned and saved: casa_blanca_(san_juan).txt
# Final cleaned and saved: casa_cautiño.txt
# Final cleaned and saved: casa_del_rey.txt
# Final cleaned and saved: casa_de_españa.txt
# Final cleaned and saved: casa_dra._concha_melendez_ramirez.txt
# Final cleaned and saved: casa_fernando_luis_toro.txt
# Final cleaned and saved: casa_font-ubides.txt
# Final cleaned and saved: casa_franceschi_antongiorgi.txt
# Final cleaned and saved: casa_natal_de_luis_muñoz_rivera.txt
# Final cleaned and saved: casa_nemesio_canales.txt
# Final cleaned and saved: casa_oppenheimer.txt
# Final cleaned and saved: casa_paoli.txt
# Final cleaned and saved: casa_pueblo_puerto_rico.txt
# Final cleaned and saved: casa_roig_museum.txt
# Final cleaned and saved: casa_rosa.txt
# Final cleaned and saved: casa_rosita_serrallés.txt
# Final cleaned and saved: casa_salazar-candal.txt
# Final cleaned and saved: casa_serralles.txt
# Final cleaned and saved: casa_wiechers-villaronga.txt
# Final cleaned and saved: casona_césari.txt
# Final cleaned and saved: castillo_san_cristóbal_(san_juan).txt
# Final cleaned and saved: castillo_san_felipe_del_morro.txt
# Final cleaned and saved: castillo_san_felipe_del_morro_lighthouse.txt
# Final cleaned and saved: castillo_serrallés.txt
# Final cleaned and saved: cataño_barrio-pueblo.txt
# Final cleaned and saved: catedral_de_nuestra_señora_de_guadalupe.txt
# Final cleaned and saved: catedral_de_san_felipe_apóstol_(arecibo,_puerto_rico).txt
# Final cleaned and saved: catedral_dulce_nombre_de_jesús_(caguas,_puerto_rico).txt
# Final cleaned and saved: catedral_metropolitana_basílica_de_san_juan_bautista_(san_juan,_puerto_rico).txt
# Final cleaned and saved: cathedral_of_rum.txt
# Final cleaned and saved: cayey_barrio-pueblo.txt
# Final cleaned and saved: cayos_de_caña_gorda.txt
# Final cleaned and saved: cayo_icacos.txt
# Final cleaned and saved: cayo_luis_peña.txt
# Final cleaned and saved: caño_tiburones.txt
# Final cleaned and saved: ceiba_barrio-pueblo.txt
# Final cleaned and saved: cementerio_católico_san_vicente_de_paul.txt
# Final cleaned and saved: cementerio_civil_de_ponce.txt
# Final cleaned and saved: center_for_advanced_studies_on_puerto_rico_and_the_caribbean.txt
# Final cleaned and saved: central_aguirre_historic_district.txt
# Final cleaned and saved: central_cortada.txt
# Final cleaned and saved: central_guánica.txt
# Final cleaned and saved: central_high_school_(san_juan,_puerto_rico).txt
# Final cleaned and saved: centro_ceremonial_indígena_de_tibes.txt
# Final cleaned and saved: centro_cultural_baudilio_vega_berríos.txt
# Final cleaned and saved: centro_cultural_de_ponce_carmen_solá_de_pereira.txt
# Final cleaned and saved: centro_del_sur_mall.txt
# Final cleaned and saved: centro_de_convenciones_de_ponce.txt
# Final cleaned and saved: cerrillos_state_forest.txt
# Final cleaned and saved: cerro_de_punta.txt
# Final cleaned and saved: cerro_las_tetas.txt
# Final cleaned and saved: cerro_maravilla.txt
# Final cleaned and saved: cerro_morales_(utuado,_puerto_rico).txt
# Final cleaned and saved: cerro_rosa.txt
# Final cleaned and saved: cervecería_india.txt
# Final cleaned and saved: chalet_amill.txt
# Final cleaned and saved: christopher_columbus.txt
# Final cleaned and saved: church_of_saint_francis_of_assisi,_san_juan.txt
# Final cleaned and saved: church_of_san_francisco_de_asís.txt
# Final cleaned and saved: church_of_san_mateo_de_cangrejos_of_santurce.txt
# Final cleaned and saved: church_san_blas_de_illescas_of_coamo.txt
# Final cleaned and saved: church_san_josé_of_aibonito.txt
# Final cleaned and saved: church_san_miguel_arcángel_of_utuado.txt
# Final cleaned and saved: ciales_barrio-pueblo.txt
# Final cleaned and saved: cidra_barrio-pueblo.txt
# Final cleaned and saved: ciudad_deportiva_millito_navarro.txt
# Final cleaned and saved: club_deportivo_del_oeste.txt
# Final cleaned and saved: club_nautico_de_ponce.txt
# Final cleaned and saved: club_náutico_de_ponce.txt
# Final cleaned and saved: coamo_barrio-pueblo.txt
# Final cleaned and saved: coca-cola_music_hall.txt
# Final cleaned and saved: colegio_ponceño.txt
# Final cleaned and saved: colegio_san_conrado.txt
# Final cleaned and saved: coliseo_manuel_iguina.txt
# Final cleaned and saved: coliseo_rubén_rodríguez.txt
# Final cleaned and saved: coloso_sugar_cane_refinery.txt
# Final cleaned and saved: comerío_barrio-pueblo.txt
# Final cleaned and saved: complejo_recreativo_y_cultural_la_guancha.txt
# Final cleaned and saved: concatedral_dulce_nombre_de_jesús_(humacao,_puerto_rico).txt
# Final cleaned and saved: condado_(santurce).txt
# Final cleaned and saved: condado_lagoon.txt
# Final cleaned and saved: condado_vanderbilt_hotel.txt
# Final cleaned and saved: conservatory_of_music_of_puerto_rico.txt
# Final cleaned and saved: corozal_barrio-pueblo.txt
# Final cleaned and saved: couroupita_nicaraguarensis.txt
# Final cleaned and saved: crash_boat_beach.txt
# Final cleaned and saved: cruceta_del_vigía.txt
# Final cleaned and saved: cuevas_las_cabachuelas.txt
# Final cleaned and saved: cueva_del_indio_(arecibo).txt
# Final cleaned and saved: cueva_del_indio_(las_piedras).txt
# Final cleaned and saved: cueva_lucero.txt
# Final cleaned and saved: cueva_ventana.txt
# Final cleaned and saved: culebra_barrio-pueblo.txt
# Final cleaned and saved: culebra_national_wildlife_refuge.txt
# Final cleaned and saved: culebrita.txt
# Final cleaned and saved: dead_dog_beach.txt
# Final cleaned and saved: desecheo_national_wildlife_refuge.txt
# Final cleaned and saved: destilería_serrallés.txt
# Final cleaned and saved: district_courthouse_(aguadilla,_puerto_rico).txt
# Final cleaned and saved: domes_beach.txt
# Final cleaned and saved: dorado_barrio-pueblo.txt
# Final cleaned and saved: dos_bocas_lake.txt
# Final cleaned and saved: dos_hermanos_bridge.txt
# Final cleaned and saved: dr._juan_a._rivero_zoo.txt
# Final cleaned and saved: edificio_aboy.txt
# Final cleaned and saved: edificio_comunidad_de_orgullo_gay_de_puerto_rico.txt
# Final cleaned and saved: edificio_del_valle.txt
# Final cleaned and saved: edificio_josé_de_diego.txt
# Final cleaned and saved: edificio_oliver.txt
# Final cleaned and saved: edificio_patio_español.txt
# Final cleaned and saved: edificio_victory_garden.txt
# Final cleaned and saved: el_falansterio_de_puerta_de_tierra.txt
# Final cleaned and saved: el_gigante_dormido.txt
# Final cleaned and saved: el_monumento_de_la_recordación.txt
# Final cleaned and saved: el_parterre.txt
# Final cleaned and saved: el_toro_wilderness.txt
# Final cleaned and saved: el_tuque.txt
# Final cleaned and saved: el_yunque_national_forest.txt
# Final cleaned and saved: enrique_laguerre.txt
# Final cleaned and saved: ensenada_honda_(culebra,_puerto_rico).txt
# Final cleaned and saved: episcopal_cathedral_of_st._john_the_baptist_(san_juan,_puerto_rico).txt
# Final cleaned and saved: ermita_nuestra_señora_de_la_valvanera.txt
# Final cleaned and saved: escuela_brambaugh.txt
# Final cleaned and saved: escuela_de_artes_plásticas_y_diseño_de_puerto_rico.txt
# Final cleaned and saved: esperanza_beach.txt
# Final cleaned and saved: estadio_country_club.txt
# Final cleaned and saved: estadio_francisco_montaner.txt
# Final cleaned and saved: estadio_sixto_escobar.txt
# Final cleaned and saved: fajardo_barrio-pueblo.txt
# Final cleaned and saved: farmers'_market.txt
# Final cleaned and saved: faro_del_puerto_de_ponce.txt
# Final cleaned and saved: faro_de_la_isla_de_caja_de_muertos.txt
# Final cleaned and saved: filardi_house.txt
# Final cleaned and saved: flamenco_beach.txt
# Final cleaned and saved: florida,_puerto_rico.txt
# Final cleaned and saved: fort_buchanan,_puerto_rico.txt
# Final cleaned and saved: fortín_de_san_gerónimo.txt
# Final cleaned and saved: fortín_san_antonio.txt
# Final cleaned and saved: fortín_san_juan_de_la_cruz.txt
# Final cleaned and saved: francisco_oller.txt
# Final cleaned and saved: fuerte_de_la_concepción.txt
# Final cleaned and saved: fuerte_de_vieques.txt
# Final cleaned and saved: galería_nacional.txt
# Final cleaned and saved: gatas_(ponce).txt
# Final cleaned and saved: general_norzagaray_bridge.txt
# Final cleaned and saved: general_store.txt
# Final cleaned and saved: guajataca_lake.txt
# Final cleaned and saved: guajataca_state_forest.txt
# Final cleaned and saved: guajataca_tunnel.txt
# Final cleaned and saved: guavate,_cayey,_puerto_rico.txt
# Final cleaned and saved: guayama_barrio-pueblo.txt
# Final cleaned and saved: guayanilla_barrio-pueblo.txt
# Final cleaned and saved: guaynabo_barrio-pueblo.txt
# Final cleaned and saved: guilarte_state_forest.txt
# Final cleaned and saved: gurabo_barrio-pueblo.txt
# Final cleaned and saved: guánica_barrio-pueblo.txt
# Final cleaned and saved: guánica_light.txt
# Final cleaned and saved: guánica_state_forest.txt
# Final cleaned and saved: gómez_residence.txt
# Final cleaned and saved: hacienda_azucarera_la_esperanza.txt
# Final cleaned and saved: hacienda_buena_vista.txt
# Final cleaned and saved: hacienda_el_jibarito.txt
# Final cleaned and saved: hacienda_juanita.txt
# Final cleaned and saved: hacienda_lealtad.txt
# Final cleaned and saved: hacienda_santa_rita.txt
# Final cleaned and saved: hacienda_san_francisco.txt
# Final cleaned and saved: hatillo_barrio-pueblo.txt
# Final cleaned and saved: henry_klumb_house.txt
# Final cleaned and saved: hermitage_of_san_antonio_de_padua_de_la_tuna.txt
# Final cleaned and saved: hipódromo_camarero.txt
# Final cleaned and saved: hiram_bithorn_stadium.txt
# Final cleaned and saved: hormigueros_barrio-pueblo.txt
# Final cleaned and saved: horse_racing.txt
# Final cleaned and saved: hotel_el_convento.txt
# Final cleaned and saved: hotel_melia.txt
# Final cleaned and saved: hotel_ponce_intercontinental.txt
# Final cleaned and saved: hotel_ponce_ramada.txt
# Final cleaned and saved: house_at_659_concordia_street.txt
# Final cleaned and saved: house_at_659_la_paz_street.txt
# Final cleaned and saved: house_at_663_la_paz_street.txt
# Final cleaned and saved: house_at_665_mckinley_street.txt
# Final cleaned and saved: humacao_barrio-pueblo.txt
# Final cleaned and saved: humacao_nature_reserve.txt
# Final cleaned and saved: húcares.txt
# Final cleaned and saved: iglesia_de_la_santísima_trinidad.txt
# Final cleaned and saved: iglesia_de_nuestra_señora_del_carmen.txt
# Final cleaned and saved: iglesia_de_san_antonio_de_padua.txt
# Final cleaned and saved: iglesia_san_germán_de_auxerre.txt
# Final cleaned and saved: iglesia_san_sebastián_mártir.txt
# Final cleaned and saved: industrias_vassallo.txt
# Final cleaned and saved: institute_of_puerto_rican_culture.txt
# Final cleaned and saved: interamerican_university_of_puerto_rico.txt
# Final cleaned and saved: interamerican_university_of_puerto_rico_at_ponce.txt
# Final cleaned and saved: isabela_barrio-pueblo.txt
# Final cleaned and saved: isabel_ii_barrio-pueblo.txt
# Final cleaned and saved: isla_del_frío.txt
# Final cleaned and saved: isla_de_cabras.txt
# Final cleaned and saved: isla_de_jueyes.txt
# Final cleaned and saved: isla_de_mona.txt
# Final cleaned and saved: isla_de_ratones_(cabo_rojo,_puerto_rico).txt
# Final cleaned and saved: isla_de_ratones_(ponce,_puerto_rico).txt
# Final cleaned and saved: isla_magueyes.txt
# Final cleaned and saved: isla_mata_la_gata.txt
# Final cleaned and saved: isla_palomino.txt
# Final cleaned and saved: isla_verde,_puerto_rico.txt
# Final cleaned and saved: jayuya_barrio-pueblo.txt
# Final cleaned and saved: jesús_izcoa_moure_bridge.txt
# Final cleaned and saved: jesús_t._piñero_house.txt
# Final cleaned and saved: jobos_beach.txt
# Final cleaned and saved: jose_v._toledo_federal_building_and_united_states_courthouse.txt
# Final cleaned and saved: josé_celso_barbosa.txt
# Final cleaned and saved: josé_miguel_agrelot_coliseum.txt
# Final cleaned and saved: joyuda,_puerto_rico.txt
# Final cleaned and saved: joyuda_lagoon.txt
# Final cleaned and saved: juana_díaz_barrio-pueblo.txt
# Final cleaned and saved: juan_boria.txt
# Final cleaned and saved: juan_ramón_loubriel_stadium.txt
# Final cleaned and saved: julia_de_burgos.txt
# Final cleaned and saved: julio_enrique_monagas_park.txt
# Final cleaned and saved: juncos_barrio-pueblo.txt
# Final cleaned and saved: lago_dos_bocas.txt
# Final cleaned and saved: laguna_cartagena_national_wildlife_refuge.txt
# Final cleaned and saved: lajas_barrio-pueblo.txt
# Final cleaned and saved: lake_luchetti.txt
# Final cleaned and saved: lares_barrio-pueblo.txt
# Final cleaned and saved: lares_ice_cream_parlor.txt
# Final cleaned and saved: las_cabañas_bridge.txt
# Final cleaned and saved: las_cascadas_water_park.txt
# Final cleaned and saved: las_catalinas_mall.txt
# Final cleaned and saved: las_marías_barrio-pueblo.txt
# Final cleaned and saved: las_piedras_barrio-pueblo.txt
# Final cleaned and saved: la_bombonera_(san_juan).txt
# Final cleaned and saved: la_concha_renaissance_san_juan_resort.txt
# Final cleaned and saved: la_cordillera_reef_nature_reserve.txt
# Final cleaned and saved: la_fortaleza.txt
# Final cleaned and saved: la_giralda_(san_juan,_puerto_rico).txt
# Final cleaned and saved: la_guancha_(ponce,_puerto_rico).txt
# Final cleaned and saved: la_liendre_bridge.txt
# Final cleaned and saved: la_mallorquina.txt
# Final cleaned and saved: la_parguera.txt
# Final cleaned and saved: la_perla,_san_juan,_puerto_rico.txt
# Final cleaned and saved: la_placita_de_santurce.txt
# Final cleaned and saved: la_plata_lake.txt
# Final cleaned and saved: la_pocita_de_las_golondrinas_beach.txt
# Final cleaned and saved: la_ventana_al_mar.txt
# Final cleaned and saved: lechon.txt
# Final cleaned and saved: legend_of_diego_salcedo.txt
# Final cleaned and saved: letras_de_ponce.txt
# Final cleaned and saved: lin-manuel_miranda.txt
# Final cleaned and saved: logia_masónica_hijos_de_la_luz.txt
# Final cleaned and saved: los_chinos_de_ponce.txt
# Final cleaned and saved: los_morrillos_lighthouse.txt
# Final cleaned and saved: los_tres_picachos.txt
# Final cleaned and saved: los_tres_picachos_state_forest.txt
# Final cleaned and saved: los_túneles_subterráneos_de_san_germán.txt
# Final cleaned and saved: loverbar.txt
# Final cleaned and saved: loíza_barrio-pueblo.txt
# Final cleaned and saved: loíza_lake.txt
# Final cleaned and saved: luis_a._ferré_performing_arts_center.txt
# Final cleaned and saved: luis_a._ferré_united_states_courthouse_and_post_office_building.txt
# Final cleaned and saved: luis_muñoz_marín_international_airport.txt
# Final cleaned and saved: luis_muñoz_marín_park.txt
# Final cleaned and saved: luis_muñoz_rivera_park.txt
# Final cleaned and saved: luquillo_barrio-pueblo.txt
# Final cleaned and saved: luquillo_beach.txt
# Final cleaned and saved: línea_avanzada.txt
# Final cleaned and saved: lópez_residence.txt
# Final cleaned and saved: manatí_barrio-pueblo.txt
# Final cleaned and saved: manatí_bridge_at_mata_de_plátano.txt
# Final cleaned and saved: maricao_barrio-pueblo.txt
# Final cleaned and saved: maricao_fish_hatchery.txt
# Final cleaned and saved: maricao_state_forest.txt
# Final cleaned and saved: mario_morales_coliseum.txt
# Final cleaned and saved: martín_peña_bridge.txt
# Final cleaned and saved: mar_bella_beach.txt
# Final cleaned and saved: maunabo_barrio-pueblo.txt
# Final cleaned and saved: mavilla_bridge.txt
# Final cleaned and saved: mayagüez_barrio-pueblo.txt
# Final cleaned and saved: mayagüez_city_hall.txt
# Final cleaned and saved: mayagüez_resort_&_casino.txt
# Final cleaned and saved: mccabe_memorial_church.txt
# Final cleaned and saved: miramar_(santurce).txt
# Final cleaned and saved: mizpa_pentecostal_university.txt
# Final cleaned and saved: moca_barrio-pueblo.txt
# Final cleaned and saved: mona_ground_iguana.txt
# Final cleaned and saved: monte_jayuya.txt
# Final cleaned and saved: monumento_al_jíbaro_puertorriqueño.txt
# Final cleaned and saved: monumento_a_la_abolición_de_la_exclavitud.txt
# Final cleaned and saved: monumento_a_los_heroes_de_el_polvorín_(obelisk).txt
# Final cleaned and saved: monumento_a_los_heroes_de_el_polvorín_(tomb).txt
# Final cleaned and saved: morovis_barrio-pueblo.txt
# Final cleaned and saved: morovis_national_cemetery.txt
# Final cleaned and saved: morrillito.txt
# Final cleaned and saved: museo_castillo_serrallés.txt
# Final cleaned and saved: museo_del_autonomismo_puertorriqueño.txt
# Final cleaned and saved: museo_de_arte_de_ponce.txt
# Final cleaned and saved: museo_de_la_arquitectura_ponceña.txt
# Final cleaned and saved: museo_de_la_historia_de_ponce.txt
# Final cleaned and saved: museo_de_la_masacre_de_ponce.txt
# Final cleaned and saved: museo_de_la_música_puertorriqueña.txt
# Final cleaned and saved: museo_de_vida_silvestre.txt
# Final cleaned and saved: museum_of_art_of_puerto_rico.txt
# Final cleaned and saved: museum_of_transportation_of_puerto_rico.txt
# Final cleaned and saved: naguabo_barrio-pueblo.txt
# Final cleaned and saved: naranjito_barrio-pueblo.txt
# Final cleaned and saved: normandie_hotel.txt
# Final cleaned and saved: nuestra_señora_de_lourdes_chapel.txt
# Final cleaned and saved: nuevo_milenio_state_forest.txt
# Final cleaned and saved: ocean_park_(santurce).txt
# Final cleaned and saved: old_piedras_river_aqueduct.txt
# Final cleaned and saved: old_san_juan.txt
# Final cleaned and saved: orocovis.txt
# Final cleaned and saved: orocovis_barrio-pueblo.txt
# Final cleaned and saved: orthodox_judaism.txt
# Final cleaned and saved: our_lady_of_lourdes.txt
# Final cleaned and saved: pablo_casals_museum.txt
# Final cleaned and saved: palacete_los_moreau.txt
# Final cleaned and saved: palmas_del_mar.txt
# Final cleaned and saved: panteón_nacional_román_baldorioty_de_castro.txt
# Final cleaned and saved: parque_del_litoral.txt
# Final cleaned and saved: parque_del_retiro.txt
# Final cleaned and saved: parque_del_tricentenario_(ponce,_puerto_rico).txt
# Final cleaned and saved: parque_de_bombas.txt
# Final cleaned and saved: parque_de_bombas_maximiliano_merced.txt
# Final cleaned and saved: parque_de_las_ciencias.txt
# Final cleaned and saved: parque_de_la_abolición.txt
# Final cleaned and saved: parque_de_la_ceiba.txt
# Final cleaned and saved: parque_ecológico_urbano.txt
# Final cleaned and saved: parque_familiar_julio_enrique_monagas.txt
# Final cleaned and saved: parque_lineal_veredas_del_labrador.txt
# Final cleaned and saved: parque_luis_a._wito_morales.txt
# Final cleaned and saved: parque_nacional_de_las_cavernas_del_río_camuy.txt
# Final cleaned and saved: parque_pedro_albizu_campos.txt
# Final cleaned and saved: parque_urbano_dora_colón_clavell.txt
# Final cleaned and saved: parroquia_del_espíritu_santo_y_san_patricio.txt
# Final cleaned and saved: paseo_atocha.txt
# Final cleaned and saved: paseo_de_la_princesa.txt
# Final cleaned and saved: paseo_tablado_la_guancha.txt
# Final cleaned and saved: paseo_víctor_rojas.txt
# Final cleaned and saved: patillas_barrio-pueblo.txt
# Final cleaned and saved: peñuelas_barrio-pueblo.txt
# Final cleaned and saved: pico_piedra.txt
# Final cleaned and saved: pico_rodadero.txt
# Final cleaned and saved: picó_pomar_residence.txt
# Final cleaned and saved: piñones_state_forest.txt
# Final cleaned and saved: playa_espinar.txt
# Final cleaned and saved: playita_del_condado.txt
# Final cleaned and saved: plaza_carolina.txt
# Final cleaned and saved: plaza_colón.txt
# Final cleaned and saved: plaza_colón_(san_juan).txt
# Final cleaned and saved: plaza_degetau.txt
# Final cleaned and saved: plaza_del_caribe.txt
# Final cleaned and saved: plaza_del_mercado_de_ponce.txt
# Final cleaned and saved: plaza_del_norte.txt
# Final cleaned and saved: plaza_del_quinto_centenario.txt
# Final cleaned and saved: plaza_del_sol_(puerto_rico).txt
# Final cleaned and saved: plaza_de_armas,_san_juan.txt
# Final cleaned and saved: plaza_de_la_catedral_(san_juan).txt
# Final cleaned and saved: plaza_de_san_josé.txt
# Final cleaned and saved: plaza_juan_ponce_de_león.txt
# Final cleaned and saved: plaza_las_américas_(puerto_rico).txt
# Final cleaned and saved: plaza_las_delicias.txt
# Final cleaned and saved: plaza_muñoz_rivera.txt
# Final cleaned and saved: plaza_rio_hondo.txt
# Final cleaned and saved: polvorín_de_miraflores.txt
# Final cleaned and saved: polytechnic_university_of_puerto_rico.txt
# Final cleaned and saved: ponce_cement,_inc..txt
# Final cleaned and saved: ponce_city_hall.txt
# Final cleaned and saved: ponce_high_school.txt
# Final cleaned and saved: ponce_historic_zone.txt
# Final cleaned and saved: ponce_school_of_medicine.txt
# Final cleaned and saved: ponce_ymca_building.txt
# Final cleaned and saved: pontificia_universidad_católica_de_puerto_rico.txt
# Final cleaned and saved: porta_coeli_(puerto_rico).txt
# Final cleaned and saved: pozo_de_jacinto.txt
# Final cleaned and saved: primera_iglesia_bautista_de_caguas.txt
# Final cleaned and saved: primera_iglesia_metodista_unida_de_ponce.txt
# Final cleaned and saved: pueblo,_san_juan,_puerto_rico.txt
# Final cleaned and saved: puente_blanco.txt
# Final cleaned and saved: puente_de_coloso.txt
# Final cleaned and saved: puente_de_las_calabazas.txt
# Final cleaned and saved: puente_no._6.txt
# Final cleaned and saved: puerta_de_tierra,_san_juan.txt
# Final cleaned and saved: puerto_del_rey_marina.txt
# Final cleaned and saved: puerto_rico.txt
# Final cleaned and saved: puerto_rico_convention_center.txt
# Final cleaned and saved: puerto_rico_iron_works.txt
# Final cleaned and saved: puerto_rico_museum_of_contemporary_art.txt
# Final cleaned and saved: puerto_rico_national_library.txt
# Final cleaned and saved: punta_borinquen_light.txt
# Final cleaned and saved: punta_de_las_figuras_light.txt
# Final cleaned and saved: punta_higuero_light.txt
# Final cleaned and saved: punta_mulas_light.txt
# Final cleaned and saved: punta_santiago,_humacao,_puerto_rico.txt
# Final cleaned and saved: punta_tuna_light.txt
# Final cleaned and saved: quebradillas_barrio-pueblo.txt
# Final cleaned and saved: rafael_hernández_marín.txt
# Final cleaned and saved: ramón_rivero_(diplo).txt
# Final cleaned and saved: residencia_aboy-lompré.txt
# Final cleaned and saved: residencia_armstrong-poventud.txt
# Final cleaned and saved: residencia_rosaly-batiz.txt
# Final cleaned and saved: residencia_subirá.txt
# Final cleaned and saved: rincón_barrio-pueblo.txt
# Final cleaned and saved: roberto_clemente_coliseum.txt
# Final cleaned and saved: roberto_clemente_stadium.txt
# Final cleaned and saved: roosevelt_roads_naval_station.txt
# Final cleaned and saved: rovira_biscuits_corporation.txt
# Final cleaned and saved: rum.txt
# Final cleaned and saved: rum_planetarium.txt
# Final cleaned and saved: río_abajo_state_forest.txt
# Final cleaned and saved: río_grande_barrio-pueblo.txt
# Final cleaned and saved: río_grande_de_loíza.txt
# Final cleaned and saved: río_matón_bridge.txt
# Final cleaned and saved: río_piedras_bridge.txt
# Final cleaned and saved: sabana_grande_barrio-pueblo.txt
# Final cleaned and saved: sabana_grande_masonic_cemetery.txt
# Final cleaned and saved: saint_john's_school_(san_juan).txt
# Final cleaned and saved: saliente_river.txt
# Final cleaned and saved: salinas_barrio-pueblo.txt
# Final cleaned and saved: samuel_morse.txt
# Final cleaned and saved: santa_ana_church_(san_juan).txt
# Final cleaned and saved: santa_isabel_barrio-pueblo.txt
# Final cleaned and saved: santa_maría_magdalena_de_pazzis_cemetery.txt
# Final cleaned and saved: santurce,_san_juan,_puerto_rico.txt
# Final cleaned and saved: san_cristóbal_canyon.txt
# Final cleaned and saved: san_germán_historic_district.txt
# Final cleaned and saved: san_josé_church.txt
# Final cleaned and saved: san_juan_botanical_garden.txt
# Final cleaned and saved: san_juan_city_hall.txt
# Final cleaned and saved: san_juan_marriott_resort_&_stellaris_casino.txt
# Final cleaned and saved: san_juan_natatorium.txt
# Final cleaned and saved: san_juan_puerto_rico_temple.txt
# Final cleaned and saved: san_lorenzo_barrio-pueblo.txt
# Final cleaned and saved: san_miguel_arcángel_church_(cabo_rojo).txt
# Final cleaned and saved: san_patricio_plaza.txt
# Final cleaned and saved: san_patricio_state_forest.txt
# Final cleaned and saved: san_sebastián_barrio-pueblo.txt
# Final cleaned and saved: school_of_tropical_medicine_(puerto_rico).txt
# Final cleaned and saved: sixto_escobar.txt
# Final cleaned and saved: stud_farm.txt
# Final cleaned and saved: supreme_court_building_(puerto_rico).txt
# Final cleaned and saved: susúa_state_forest.txt
# Final cleaned and saved: t-mobile_district.txt
# Final cleaned and saved: teatro_fox_delicias.txt
# Final cleaned and saved: teatro_la_perla.txt
# Final cleaned and saved: teatro_tapia.txt
# Final cleaned and saved: teatro_yagüez.txt
# Final cleaned and saved: teodoro_moscoso_bridge.txt
# Final cleaned and saved: the_mall_of_san_juan.txt
# Final cleaned and saved: tito_puente_amphitheatre.txt
# Final cleaned and saved: toa_alta_barrio-pueblo.txt
# Final cleaned and saved: toa_baja_barrio-pueblo.txt
# Final cleaned and saved: toro_negro_state_forest.txt
# Final cleaned and saved: tortuguero_lagoon.txt
# Final cleaned and saved: train_of_the_south.txt
# Final cleaned and saved: trujillo_alto_barrio-pueblo.txt
# Final cleaned and saved: u.s._custom_house_(san_juan,_puerto_rico).txt
# Final cleaned and saved: u.s._post_office_and_courthouse_(mayagüez,_puerto_rico).txt
# Final cleaned and saved: united_states_customs_house_(fajardo,_puerto_rico).txt
# Final cleaned and saved: united_states_customs_house_(ponce,_puerto_rico).txt
# Final cleaned and saved: united_states_district_court_for_the_district_of_puerto_rico.txt
# Final cleaned and saved: universidad_del_sagrado_corazón.txt
# Final cleaned and saved: university_gardens_high_school.txt
# Final cleaned and saved: university_high_school_(san_juan).txt
# Final cleaned and saved: university_of_puerto_rico,_medical_sciences_campus.txt
# Final cleaned and saved: university_of_puerto_rico,_río_piedras_campus.txt
# Final cleaned and saved: university_of_puerto_rico_at_cayey.txt
# Final cleaned and saved: university_of_puerto_rico_at_humacao.txt
# Final cleaned and saved: university_of_puerto_rico_at_mayagüez.txt
# Final cleaned and saved: university_of_puerto_rico_at_ponce.txt
# Final cleaned and saved: university_of_puerto_rico_school_of_medicine.txt
# Final cleaned and saved: uss_killen_(dd-593).txt
# Final cleaned and saved: utuado_barrio-pueblo.txt
# Final cleaned and saved: vega_alta_barrio-pueblo.txt
# Final cleaned and saved: vega_baja_barrio-pueblo.txt
# Final cleaned and saved: vega_state_forest.txt
# Final cleaned and saved: vieques_national_wildlife_refuge.txt
# Final cleaned and saved: villalba,_puerto_rico.txt
# Final cleaned and saved: villalba_barrio-pueblo.txt
# Final cleaned and saved: villa_pesquera.txt
# Final cleaned and saved: west_indian_manatee.txt
# Final cleaned and saved: whale_watching.txt
# Final cleaned and saved: william_miranda_marín_botanical_and_cultural_garden.txt
# Final cleaned and saved: world_war_ii.txt
# Final cleaned and saved: yabucoa_barrio-pueblo.txt
# Final cleaned and saved: yauco_barrio-pueblo.txt
# Final cleaned and saved: zona_historica_de_ponce.txt

# %% [markdown]
# # **Final Cleaning Step No. 3: Fix Special Characters on Title**

# %%
import os
import json

# Define input and output directories
final_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleaning\10Feb25_final_step02_links_clean"
final_cleaned_data_path = r"C:\Users\larry\OneDrive\Documents\GitHub\project-aieng-interactive-travel-planner\data\landmarks_cleaning\11Feb25_final_step03_chars_title_clean"

# Create final cleaned output directory if it doesn't exist
if not os.path.exists(final_cleaned_data_path):
    os.makedirs(final_cleaned_data_path)

# Define Main Special Characters Mapping
special_chars_mapping = {
    "\\xc3\\xa1": "á",
    "\\xc3\\xa9": "é",
    "\\xc3\\xad": "í",
    "\\xc3\\xb3": "ó",
    "\\xc3\\xba": "ú",
    "\\xc3\\xb1": "ñ",
    "\\xc3\\x9c": "Ü",
    "\\xc3\\xbc": "ü",
    "\\xe2\\x80\\x99": "'",
    "\\xe2\\x80\\x9c": "\"",
    "\\xe2\\x80\\x9d": "\"",
    "\\xca\\x9du\\xca\\x9d": "ü",
    "\\xcb\\x88": "'",
    "\\xa": " ",
    "\\xc2\\xb0F": "°F",
    "\\xc2\\xb0C": "°C",
    "\\xc2\\xb0": "°",
    "\\xe2\\x80\\x93": "-",
    "\\\\u0026amp;": "&"
}

# Function for Fixing Special Characters
def fix_special_characters(text):
    for wrong, correct in special_chars_mapping.items():
        text = text.replace(wrong, correct)
    return text

# Process each file in the final_data directory
for file_name in os.listdir(final_data_path):
    file_path = os.path.join(final_data_path, file_name)

    with open(file_path, "r", encoding="utf-8") as file:
        data = json.load(file)

    # Fix special characters in geo_metadata title
    if "geo_metadata" in data and "title" in data["geo_metadata"]:
        data["geo_metadata"]["title"] = fix_special_characters(data["geo_metadata"]["title"])

    # Save the cleaned file to final_cleaned_data directory
    output_file_path = os.path.join(final_cleaned_data_path, file_name)
    with open(output_file_path, "w", encoding="utf-8") as output_file:
        json.dump(data, output_file, indent=4, ensure_ascii=False)

    print(f"Final cleaned and saved: {file_name}")
# Out:
# Final cleaned and saved: academia_del_perpetuo_socorro.txt
# Final cleaned and saved: academia_interamericana_metro.txt
# Final cleaned and saved: academia_maria_reina.txt
# Final cleaned and saved: academia_san_jorge.txt
# Final cleaned and saved: adjuntas_barrio-pueblo.txt
# Final cleaned and saved: aguada_barrio-pueblo.txt
# Final cleaned and saved: aguada_transmission_station.txt
# Final cleaned and saved: aguadilla_barrio-pueblo.txt
# Final cleaned and saved: aguadilla_ice_skating_arena.txt
# Final cleaned and saved: aguas_buenas_barrio-pueblo.txt
# Final cleaned and saved: aguas_buenas_cave_system.txt
# Final cleaned and saved: aguirre_state_forest.txt
# Final cleaned and saved: aibonito_barrio-pueblo.txt
# Final cleaned and saved: aibonito_festival_of_flowers.txt
# Final cleaned and saved: albergue_olímpico.txt
# Final cleaned and saved: albizu_university.txt
# Final cleaned and saved: ana_g._méndez_university.txt
# Final cleaned and saved: antiguo_casino_de_ponce.txt
# Final cleaned and saved: antiguo_cuartel_militar_español_de_ponce.txt
# Final cleaned and saved: antiguo_hospital_militar_español_de_ponce.txt
# Final cleaned and saved: archivo_general_de_puerto_rico.txt
# Final cleaned and saved: arecibo_barrio-pueblo.txt
# Final cleaned and saved: arecibo_light.txt
# Final cleaned and saved: arecibo_observatory.txt
# Final cleaned and saved: arecibo_telescope.txt
# Final cleaned and saved: arenas_bridge.txt
# Final cleaned and saved: arroyo_barrio-pueblo.txt
# Final cleaned and saved: asilo_de_pobres.txt
# Final cleaned and saved: ateneo_puertorriqueño.txt
# Final cleaned and saved: auditorio_juan_pachín_vicéns.txt
# Final cleaned and saved: añasco_barrio-pueblo.txt
# Final cleaned and saved: bacardi.txt
# Final cleaned and saved: bahía_de_jobos.txt
# Final cleaned and saved: ballajá_barracks.txt
# Final cleaned and saved: balneario_de_rincón.txt
# Final cleaned and saved: banco_crédito_y_ahorro_ponceño_(building).txt
# Final cleaned and saved: banco_de_ponce_(building).txt
# Final cleaned and saved: barceloneta_barrio-pueblo.txt
# Final cleaned and saved: barranquitas_barrio-pueblo.txt
# Final cleaned and saved: basílica_menor_de_la_virgen_de_monserrate.txt
# Final cleaned and saved: bayamón_barrio-pueblo.txt
# Final cleaned and saved: bayamón_city_hall.txt
# Final cleaned and saved: bayamón_river.txt
# Final cleaned and saved: baños_de_coamo.txt
# Final cleaned and saved: biblical_magi.txt
# Final cleaned and saved: biblioteca_carnegie.txt
# Final cleaned and saved: biblioteca_municipal_de_ponce.txt
# Final cleaned and saved: birth_of_the_new_world.txt
# Final cleaned and saved: black_sand.txt
# Final cleaned and saved: blue_beach_(vieques).txt
# Final cleaned and saved: bobbin_lace.txt
# Final cleaned and saved: bolera_caribe.txt
# Final cleaned and saved: boquerón,_cabo_rojo,_puerto_rico.txt
# Final cleaned and saved: boquerón_state_forest.txt
# Final cleaned and saved: braulio_castillo.txt
# Final cleaned and saved: buyé_beach.txt
# Final cleaned and saved: cabo_rojo_barrio-pueblo.txt
# Final cleaned and saved: cabo_rojo_national_wildlife_refuge.txt
# Final cleaned and saved: café_rico.txt
# Final cleaned and saved: caguana_ceremonial_ball_courts_site.txt
# Final cleaned and saved: caguas_barrio-pueblo.txt
# Final cleaned and saved: caguas_city_hall.txt
# Final cleaned and saved: caguas_museum_of_art.txt
# Final cleaned and saved: caguas_museum_of_folk_arts.txt
# Final cleaned and saved: caguas_museum_of_tobacco.txt
# Final cleaned and saved: caguas_valley.txt
# Final cleaned and saved: caja_de_muertos.txt
# Final cleaned and saved: calle_25_de_enero.txt
# Final cleaned and saved: cambalache_forest_reserve.txt
# Final cleaned and saved: campamento_santiago.txt
# Final cleaned and saved: campo_atlético_charles_h._terry.txt
# Final cleaned and saved: camuy_barrio-pueblo.txt
# Final cleaned and saved: camuy_river.txt
# Final cleaned and saved: canóvanas_barrio-pueblo.txt
# Final cleaned and saved: caparra_archaeological_site.txt
# Final cleaned and saved: cape_san_juan_light.txt
# Final cleaned and saved: capilla_del_cristo.txt
# Final cleaned and saved: capitol_of_puerto_rico.txt
# Final cleaned and saved: caracas_beach_(vieques).txt
# Final cleaned and saved: cardona_(ponce).txt
# Final cleaned and saved: cardona_residence.txt
# Final cleaned and saved: caribe_hilton_hotel.txt
# Final cleaned and saved: carite_lake.txt
# Final cleaned and saved: carite_state_forest.txt
# Final cleaned and saved: carolina_barrio-pueblo.txt
# Final cleaned and saved: carraízo_dam.txt
# Final cleaned and saved: casa_alonso.txt
# Final cleaned and saved: casa_blanca_(san_juan).txt
# Final cleaned and saved: casa_cautiño.txt
# Final cleaned and saved: casa_del_rey.txt
# Final cleaned and saved: casa_de_españa.txt
# Final cleaned and saved: casa_dra._concha_melendez_ramirez.txt
# Final cleaned and saved: casa_fernando_luis_toro.txt
# Final cleaned and saved: casa_font-ubides.txt
# Final cleaned and saved: casa_franceschi_antongiorgi.txt
# Final cleaned and saved: casa_natal_de_luis_muñoz_rivera.txt
# Final cleaned and saved: casa_nemesio_canales.txt
# Final cleaned and saved: casa_oppenheimer.txt
# Final cleaned and saved: casa_paoli.txt
# Final cleaned and saved: casa_pueblo_puerto_rico.txt
# Final cleaned and saved: casa_roig_museum.txt
# Final cleaned and saved: casa_rosa.txt
# Final cleaned and saved: casa_rosita_serrallés.txt
# Final cleaned and saved: casa_salazar-candal.txt
# Final cleaned and saved: casa_serralles.txt
# Final cleaned and saved: casa_wiechers-villaronga.txt
# Final cleaned and saved: casona_césari.txt
# Final cleaned and saved: castillo_san_cristóbal_(san_juan).txt
# Final cleaned and saved: castillo_san_felipe_del_morro.txt
# Final cleaned and saved: castillo_san_felipe_del_morro_lighthouse.txt
# Final cleaned and saved: castillo_serrallés.txt
# Final cleaned and saved: cataño_barrio-pueblo.txt
# Final cleaned and saved: catedral_de_nuestra_señora_de_guadalupe.txt
# Final cleaned and saved: catedral_de_san_felipe_apóstol_(arecibo,_puerto_rico).txt
# Final cleaned and saved: catedral_dulce_nombre_de_jesús_(caguas,_puerto_rico).txt
# Final cleaned and saved: catedral_metropolitana_basílica_de_san_juan_bautista_(san_juan,_puerto_rico).txt
# Final cleaned and saved: cathedral_of_rum.txt
# Final cleaned and saved: cayey_barrio-pueblo.txt
# Final cleaned and saved: cayos_de_caña_gorda.txt
# Final cleaned and saved: cayo_icacos.txt
# Final cleaned and saved: cayo_luis_peña.txt
# Final cleaned and saved: caño_tiburones.txt
# Final cleaned and saved: ceiba_barrio-pueblo.txt
# Final cleaned and saved: cementerio_católico_san_vicente_de_paul.txt
# Final cleaned and saved: cementerio_civil_de_ponce.txt
# Final cleaned and saved: center_for_advanced_studies_on_puerto_rico_and_the_caribbean.txt
# Final cleaned and saved: central_aguirre_historic_district.txt
# Final cleaned and saved: central_cortada.txt
# Final cleaned and saved: central_guánica.txt
# Final cleaned and saved: central_high_school_(san_juan,_puerto_rico).txt
# Final cleaned and saved: centro_ceremonial_indígena_de_tibes.txt
# Final cleaned and saved: centro_cultural_baudilio_vega_berríos.txt
# Final cleaned and saved: centro_cultural_de_ponce_carmen_solá_de_pereira.txt
# Final cleaned and saved: centro_del_sur_mall.txt
# Final cleaned and saved: centro_de_convenciones_de_ponce.txt
# Final cleaned and saved: cerrillos_state_forest.txt
# Final cleaned and saved: cerro_de_punta.txt
# Final cleaned and saved: cerro_las_tetas.txt
# Final cleaned and saved: cerro_maravilla.txt
# Final cleaned and saved: cerro_morales_(utuado,_puerto_rico).txt
# Final cleaned and saved: cerro_rosa.txt
# Final cleaned and saved: cervecería_india.txt
# Final cleaned and saved: chalet_amill.txt
# Final cleaned and saved: christopher_columbus.txt
# Final cleaned and saved: church_of_saint_francis_of_assisi,_san_juan.txt
# Final cleaned and saved: church_of_san_francisco_de_asís.txt
# Final cleaned and saved: church_of_san_mateo_de_cangrejos_of_santurce.txt
# Final cleaned and saved: church_san_blas_de_illescas_of_coamo.txt
# Final cleaned and saved: church_san_josé_of_aibonito.txt
# Final cleaned and saved: church_san_miguel_arcángel_of_utuado.txt
# Final cleaned and saved: ciales_barrio-pueblo.txt
# Final cleaned and saved: cidra_barrio-pueblo.txt
# Final cleaned and saved: ciudad_deportiva_millito_navarro.txt
# Final cleaned and saved: club_deportivo_del_oeste.txt
# Final cleaned and saved: club_nautico_de_ponce.txt
# Final cleaned and saved: club_náutico_de_ponce.txt
# Final cleaned and saved: coamo_barrio-pueblo.txt
# Final cleaned and saved: coca-cola_music_hall.txt
# Final cleaned and saved: colegio_ponceño.txt
# Final cleaned and saved: colegio_san_conrado.txt
# Final cleaned and saved: coliseo_manuel_iguina.txt
# Final cleaned and saved: coliseo_rubén_rodríguez.txt
# Final cleaned and saved: coloso_sugar_cane_refinery.txt
# Final cleaned and saved: comerío_barrio-pueblo.txt
# Final cleaned and saved: complejo_recreativo_y_cultural_la_guancha.txt
# Final cleaned and saved: concatedral_dulce_nombre_de_jesús_(humacao,_puerto_rico).txt
# Final cleaned and saved: condado_(santurce).txt
# Final cleaned and saved: condado_lagoon.txt
# Final cleaned and saved: condado_vanderbilt_hotel.txt
# Final cleaned and saved: conservatory_of_music_of_puerto_rico.txt
# Final cleaned and saved: corozal_barrio-pueblo.txt
# Final cleaned and saved: couroupita_nicaraguarensis.txt
# Final cleaned and saved: crash_boat_beach.txt
# Final cleaned and saved: cruceta_del_vigía.txt
# Final cleaned and saved: cuevas_las_cabachuelas.txt
# Final cleaned and saved: cueva_del_indio_(arecibo).txt
# Final cleaned and saved: cueva_del_indio_(las_piedras).txt
# Final cleaned and saved: cueva_lucero.txt
# Final cleaned and saved: cueva_ventana.txt
# Final cleaned and saved: culebra_barrio-pueblo.txt
# Final cleaned and saved: culebra_national_wildlife_refuge.txt
# Final cleaned and saved: culebrita.txt
# Final cleaned and saved: dead_dog_beach.txt
# Final cleaned and saved: desecheo_national_wildlife_refuge.txt
# Final cleaned and saved: destilería_serrallés.txt
# Final cleaned and saved: district_courthouse_(aguadilla,_puerto_rico).txt
# Final cleaned and saved: domes_beach.txt
# Final cleaned and saved: dorado_barrio-pueblo.txt
# Final cleaned and saved: dos_bocas_lake.txt
# Final cleaned and saved: dos_hermanos_bridge.txt
# Final cleaned and saved: dr._juan_a._rivero_zoo.txt
# Final cleaned and saved: edificio_aboy.txt
# Final cleaned and saved: edificio_comunidad_de_orgullo_gay_de_puerto_rico.txt
# Final cleaned and saved: edificio_del_valle.txt
# Final cleaned and saved: edificio_josé_de_diego.txt
# Final cleaned and saved: edificio_oliver.txt
# Final cleaned and saved: edificio_patio_español.txt
# Final cleaned and saved: edificio_victory_garden.txt
# Final cleaned and saved: el_falansterio_de_puerta_de_tierra.txt
# Final cleaned and saved: el_gigante_dormido.txt
# Final cleaned and saved: el_monumento_de_la_recordación.txt
# Final cleaned and saved: el_parterre.txt
# Final cleaned and saved: el_toro_wilderness.txt
# Final cleaned and saved: el_tuque.txt
# Final cleaned and saved: el_yunque_national_forest.txt
# Final cleaned and saved: enrique_laguerre.txt
# Final cleaned and saved: ensenada_honda_(culebra,_puerto_rico).txt
# Final cleaned and saved: episcopal_cathedral_of_st._john_the_baptist_(san_juan,_puerto_rico).txt
# Final cleaned and saved: ermita_nuestra_señora_de_la_valvanera.txt
# Final cleaned and saved: escuela_brambaugh.txt
# Final cleaned and saved: escuela_de_artes_plásticas_y_diseño_de_puerto_rico.txt
# Final cleaned and saved: esperanza_beach.txt
# Final cleaned and saved: estadio_country_club.txt
# Final cleaned and saved: estadio_francisco_montaner.txt
# Final cleaned and saved: estadio_sixto_escobar.txt
# Final cleaned and saved: fajardo_barrio-pueblo.txt
# Final cleaned and saved: farmers'_market.txt
# Final cleaned and saved: faro_del_puerto_de_ponce.txt
# Final cleaned and saved: faro_de_la_isla_de_caja_de_muertos.txt
# Final cleaned and saved: filardi_house.txt
# Final cleaned and saved: flamenco_beach.txt
# Final cleaned and saved: florida,_puerto_rico.txt
# Final cleaned and saved: fort_buchanan,_puerto_rico.txt
# Final cleaned and saved: fortín_de_san_gerónimo.txt
# Final cleaned and saved: fortín_san_antonio.txt
# Final cleaned and saved: fortín_san_juan_de_la_cruz.txt
# Final cleaned and saved: francisco_oller.txt
# Final cleaned and saved: fuerte_de_la_concepción.txt
# Final cleaned and saved: fuerte_de_vieques.txt
# Final cleaned and saved: galería_nacional.txt
# Final cleaned and saved: gatas_(ponce).txt
# Final cleaned and saved: general_norzagaray_bridge.txt
# Final cleaned and saved: general_store.txt
# Final cleaned and saved: guajataca_lake.txt
# Final cleaned and saved: guajataca_state_forest.txt
# Final cleaned and saved: guajataca_tunnel.txt
# Final cleaned and saved: guavate,_cayey,_puerto_rico.txt
# Final cleaned and saved: guayama_barrio-pueblo.txt
# Final cleaned and saved: guayanilla_barrio-pueblo.txt
# Final cleaned and saved: guaynabo_barrio-pueblo.txt
# Final cleaned and saved: guilarte_state_forest.txt
# Final cleaned and saved: gurabo_barrio-pueblo.txt
# Final cleaned and saved: guánica_barrio-pueblo.txt
# Final cleaned and saved: guánica_light.txt
# Final cleaned and saved: guánica_state_forest.txt
# Final cleaned and saved: gómez_residence.txt
# Final cleaned and saved: hacienda_azucarera_la_esperanza.txt
# Final cleaned and saved: hacienda_buena_vista.txt
# Final cleaned and saved: hacienda_el_jibarito.txt
# Final cleaned and saved: hacienda_juanita.txt
# Final cleaned and saved: hacienda_lealtad.txt
# Final cleaned and saved: hacienda_santa_rita.txt
# Final cleaned and saved: hacienda_san_francisco.txt
# Final cleaned and saved: hatillo_barrio-pueblo.txt
# Final cleaned and saved: henry_klumb_house.txt
# Final cleaned and saved: hermitage_of_san_antonio_de_padua_de_la_tuna.txt
# Final cleaned and saved: hipódromo_camarero.txt
# Final cleaned and saved: hiram_bithorn_stadium.txt
# Final cleaned and saved: hormigueros_barrio-pueblo.txt
# Final cleaned and saved: horse_racing.txt
# Final cleaned and saved: hotel_el_convento.txt
# Final cleaned and saved: hotel_melia.txt
# Final cleaned and saved: hotel_ponce_intercontinental.txt
# Final cleaned and saved: hotel_ponce_ramada.txt
# Final cleaned and saved: house_at_659_concordia_street.txt
# Final cleaned and saved: house_at_659_la_paz_street.txt
# Final cleaned and saved: house_at_663_la_paz_street.txt
# Final cleaned and saved: house_at_665_mckinley_street.txt
# Final cleaned and saved: humacao_barrio-pueblo.txt
# Final cleaned and saved: humacao_nature_reserve.txt
# Final cleaned and saved: húcares.txt
# Final cleaned and saved: iglesia_de_la_santísima_trinidad.txt
# Final cleaned and saved: iglesia_de_nuestra_señora_del_carmen.txt
# Final cleaned and saved: iglesia_de_san_antonio_de_padua.txt
# Final cleaned and saved: iglesia_san_germán_de_auxerre.txt
# Final cleaned and saved: iglesia_san_sebastián_mártir.txt
# Final cleaned and saved: industrias_vassallo.txt
# Final cleaned and saved: institute_of_puerto_rican_culture.txt
# Final cleaned and saved: interamerican_university_of_puerto_rico.txt
# Final cleaned and saved: interamerican_university_of_puerto_rico_at_ponce.txt
# Final cleaned and saved: isabela_barrio-pueblo.txt
# Final cleaned and saved: isabel_ii_barrio-pueblo.txt
# Final cleaned and saved: isla_del_frío.txt
# Final cleaned and saved: isla_de_cabras.txt
# Final cleaned and saved: isla_de_jueyes.txt
# Final cleaned and saved: isla_de_mona.txt
# Final cleaned and saved: isla_de_ratones_(cabo_rojo,_puerto_rico).txt
# Final cleaned and saved: isla_de_ratones_(ponce,_puerto_rico).txt
# Final cleaned and saved: isla_magueyes.txt
# Final cleaned and saved: isla_mata_la_gata.txt
# Final cleaned and saved: isla_palomino.txt
# Final cleaned and saved: isla_verde,_puerto_rico.txt
# Final cleaned and saved: jayuya_barrio-pueblo.txt
# Final cleaned and saved: jesús_izcoa_moure_bridge.txt
# Final cleaned and saved: jesús_t._piñero_house.txt
# Final cleaned and saved: jobos_beach.txt
# Final cleaned and saved: jose_v._toledo_federal_building_and_united_states_courthouse.txt
# Final cleaned and saved: josé_celso_barbosa.txt
# Final cleaned and saved: josé_miguel_agrelot_coliseum.txt
# Final cleaned and saved: joyuda,_puerto_rico.txt
# Final cleaned and saved: joyuda_lagoon.txt
# Final cleaned and saved: juana_díaz_barrio-pueblo.txt
# Final cleaned and saved: juan_boria.txt
# Final cleaned and saved: juan_ramón_loubriel_stadium.txt
# Final cleaned and saved: julia_de_burgos.txt
# Final cleaned and saved: julio_enrique_monagas_park.txt
# Final cleaned and saved: juncos_barrio-pueblo.txt
# Final cleaned and saved: lago_dos_bocas.txt
# Final cleaned and saved: laguna_cartagena_national_wildlife_refuge.txt
# Final cleaned and saved: lajas_barrio-pueblo.txt
# Final cleaned and saved: lake_luchetti.txt
# Final cleaned and saved: lares_barrio-pueblo.txt
# Final cleaned and saved: lares_ice_cream_parlor.txt
# Final cleaned and saved: las_cabañas_bridge.txt
# Final cleaned and saved: las_cascadas_water_park.txt
# Final cleaned and saved: las_catalinas_mall.txt
# Final cleaned and saved: las_marías_barrio-pueblo.txt
# Final cleaned and saved: las_piedras_barrio-pueblo.txt
# Final cleaned and saved: la_bombonera_(san_juan).txt
# Final cleaned and saved: la_concha_renaissance_san_juan_resort.txt
# Final cleaned and saved: la_cordillera_reef_nature_reserve.txt
# Final cleaned and saved: la_fortaleza.txt
# Final cleaned and saved: la_giralda_(san_juan,_puerto_rico).txt
# Final cleaned and saved: la_guancha_(ponce,_puerto_rico).txt
# Final cleaned and saved: la_liendre_bridge.txt
# Final cleaned and saved: la_mallorquina.txt
# Final cleaned and saved: la_parguera.txt
# Final cleaned and saved: la_perla,_san_juan,_puerto_rico.txt
# Final cleaned and saved: la_placita_de_santurce.txt
# Final cleaned and saved: la_plata_lake.txt
# Final cleaned and saved: la_pocita_de_las_golondrinas_beach.txt
# Final cleaned and saved: la_ventana_al_mar.txt
# Final cleaned and saved: lechon.txt
# Final cleaned and saved: legend_of_diego_salcedo.txt
# Final cleaned and saved: letras_de_ponce.txt
# Final cleaned and saved: lin-manuel_miranda.txt
# Final cleaned and saved: logia_masónica_hijos_de_la_luz.txt
# Final cleaned and saved: los_chinos_de_ponce.txt
# Final cleaned and saved: los_morrillos_lighthouse.txt
# Final cleaned and saved: los_tres_picachos.txt
# Final cleaned and saved: los_tres_picachos_state_forest.txt
# Final cleaned and saved: los_túneles_subterráneos_de_san_germán.txt
# Final cleaned and saved: loverbar.txt
# Final cleaned and saved: loíza_barrio-pueblo.txt
# Final cleaned and saved: loíza_lake.txt
# Final cleaned and saved: luis_a._ferré_performing_arts_center.txt
# Final cleaned and saved: luis_a._ferré_united_states_courthouse_and_post_office_building.txt
# Final cleaned and saved: luis_muñoz_marín_international_airport.txt
# Final cleaned and saved: luis_muñoz_marín_park.txt
# Final cleaned and saved: luis_muñoz_rivera_park.txt
# Final cleaned and saved: luquillo_barrio-pueblo.txt
# Final cleaned and saved: luquillo_beach.txt
# Final cleaned and saved: línea_avanzada.txt
# Final cleaned and saved: lópez_residence.txt
# Final cleaned and saved: manatí_barrio-pueblo.txt
# Final cleaned and saved: manatí_bridge_at_mata_de_plátano.txt
# Final cleaned and saved: maricao_barrio-pueblo.txt
# Final cleaned and saved: maricao_fish_hatchery.txt
# Final cleaned and saved: maricao_state_forest.txt
# Final cleaned and saved: mario_morales_coliseum.txt
# Final cleaned and saved: martín_peña_bridge.txt
# Final cleaned and saved: mar_bella_beach.txt
# Final cleaned and saved: maunabo_barrio-pueblo.txt
# Final cleaned and saved: mavilla_bridge.txt
# Final cleaned and saved: mayagüez_barrio-pueblo.txt
# Final cleaned and saved: mayagüez_city_hall.txt
# Final cleaned and saved: mayagüez_resort_&_casino.txt
# Final cleaned and saved: mccabe_memorial_church.txt
# Final cleaned and saved: miramar_(santurce).txt
# Final cleaned and saved: mizpa_pentecostal_university.txt
# Final cleaned and saved: moca_barrio-pueblo.txt
# Final cleaned and saved: mona_ground_iguana.txt
# Final cleaned and saved: monte_jayuya.txt
# Final cleaned and saved: monumento_al_jíbaro_puertorriqueño.txt
# Final cleaned and saved: monumento_a_la_abolición_de_la_exclavitud.txt
# Final cleaned and saved: monumento_a_los_heroes_de_el_polvorín_(obelisk).txt
# Final cleaned and saved: monumento_a_los_heroes_de_el_polvorín_(tomb).txt
# Final cleaned and saved: morovis_barrio-pueblo.txt
# Final cleaned and saved: morovis_national_cemetery.txt
# Final cleaned and saved: morrillito.txt
# Final cleaned and saved: museo_castillo_serrallés.txt
# Final cleaned and saved: museo_del_autonomismo_puertorriqueño.txt
# Final cleaned and saved: museo_de_arte_de_ponce.txt
# Final cleaned and saved: museo_de_la_arquitectura_ponceña.txt
# Final cleaned and saved: museo_de_la_historia_de_ponce.txt
# Final cleaned and saved: museo_de_la_masacre_de_ponce.txt
# Final cleaned and saved: museo_de_la_música_puertorriqueña.txt
# Final cleaned and saved: museo_de_vida_silvestre.txt
# Final cleaned and saved: museum_of_art_of_puerto_rico.txt
# Final cleaned and saved: museum_of_transportation_of_puerto_rico.txt
# Final cleaned and saved: naguabo_barrio-pueblo.txt
# Final cleaned and saved: naranjito_barrio-pueblo.txt
# Final cleaned and saved: normandie_hotel.txt
# Final cleaned and saved: nuestra_señora_de_lourdes_chapel.txt
# Final cleaned and saved: nuevo_milenio_state_forest.txt
# Final cleaned and saved: ocean_park_(santurce).txt
# Final cleaned and saved: old_piedras_river_aqueduct.txt
# Final cleaned and saved: old_san_juan.txt
# Final cleaned and saved: orocovis.txt
# Final cleaned and saved: orocovis_barrio-pueblo.txt
# Final cleaned and saved: orthodox_judaism.txt
# Final cleaned and saved: our_lady_of_lourdes.txt
# Final cleaned and saved: pablo_casals_museum.txt
# Final cleaned and saved: palacete_los_moreau.txt
# Final cleaned and saved: palmas_del_mar.txt
# Final cleaned and saved: panteón_nacional_román_baldorioty_de_castro.txt
# Final cleaned and saved: parque_del_litoral.txt
# Final cleaned and saved: parque_del_retiro.txt
# Final cleaned and saved: parque_del_tricentenario_(ponce,_puerto_rico).txt
# Final cleaned and saved: parque_de_bombas.txt
# Final cleaned and saved: parque_de_bombas_maximiliano_merced.txt
# Final cleaned and saved: parque_de_las_ciencias.txt
# Final cleaned and saved: parque_de_la_abolición.txt
# Final cleaned and saved: parque_de_la_ceiba.txt
# Final cleaned and saved: parque_ecológico_urbano.txt
# Final cleaned and saved: parque_familiar_julio_enrique_monagas.txt
# Final cleaned and saved: parque_lineal_veredas_del_labrador.txt
# Final cleaned and saved: parque_luis_a._wito_morales.txt
# Final cleaned and saved: parque_nacional_de_las_cavernas_del_río_camuy.txt
# Final cleaned and saved: parque_pedro_albizu_campos.txt
# Final cleaned and saved: parque_urbano_dora_colón_clavell.txt
# Final cleaned and saved: parroquia_del_espíritu_santo_y_san_patricio.txt
# Final cleaned and saved: paseo_atocha.txt
# Final cleaned and saved: paseo_de_la_princesa.txt
# Final cleaned and saved: paseo_tablado_la_guancha.txt
# Final cleaned and saved: paseo_víctor_rojas.txt
# Final cleaned and saved: patillas_barrio-pueblo.txt
# Final cleaned and saved: peñuelas_barrio-pueblo.txt
# Final cleaned and saved: pico_piedra.txt
# Final cleaned and saved: pico_rodadero.txt
# Final cleaned and saved: picó_pomar_residence.txt
# Final cleaned and saved: piñones_state_forest.txt
# Final cleaned and saved: playa_espinar.txt
# Final cleaned and saved: playita_del_condado.txt
# Final cleaned and saved: plaza_carolina.txt
# Final cleaned and saved: plaza_colón.txt
# Final cleaned and saved: plaza_colón_(san_juan).txt
# Final cleaned and saved: plaza_degetau.txt
# Final cleaned and saved: plaza_del_caribe.txt
# Final cleaned and saved: plaza_del_mercado_de_ponce.txt
# Final cleaned and saved: plaza_del_norte.txt
# Final cleaned and saved: plaza_del_quinto_centenario.txt
# Final cleaned and saved: plaza_del_sol_(puerto_rico).txt
# Final cleaned and saved: plaza_de_armas,_san_juan.txt
# Final cleaned and saved: plaza_de_la_catedral_(san_juan).txt
# Final cleaned and saved: plaza_de_san_josé.txt
# Final cleaned and saved: plaza_juan_ponce_de_león.txt
# Final cleaned and saved: plaza_las_américas_(puerto_rico).txt
# Final cleaned and saved: plaza_las_delicias.txt
# Final cleaned and saved: plaza_muñoz_rivera.txt
# Final cleaned and saved: plaza_rio_hondo.txt
# Final cleaned and saved: polvorín_de_miraflores.txt
# Final cleaned and saved: polytechnic_university_of_puerto_rico.txt
# Final cleaned and saved: ponce_cement,_inc..txt
# Final cleaned and saved: ponce_city_hall.txt
# Final cleaned and saved: ponce_high_school.txt
# Final cleaned and saved: ponce_historic_zone.txt
# Final cleaned and saved: ponce_school_of_medicine.txt
# Final cleaned and saved: ponce_ymca_building.txt
# Final cleaned and saved: pontificia_universidad_católica_de_puerto_rico.txt
# Final cleaned and saved: porta_coeli_(puerto_rico).txt
# Final cleaned and saved: pozo_de_jacinto.txt
# Final cleaned and saved: primera_iglesia_bautista_de_caguas.txt
# Final cleaned and saved: primera_iglesia_metodista_unida_de_ponce.txt
# Final cleaned and saved: pueblo,_san_juan,_puerto_rico.txt
# Final cleaned and saved: puente_blanco.txt
# Final cleaned and saved: puente_de_coloso.txt
# Final cleaned and saved: puente_de_las_calabazas.txt
# Final cleaned and saved: puente_no._6.txt
# Final cleaned and saved: puerta_de_tierra,_san_juan.txt
# Final cleaned and saved: puerto_del_rey_marina.txt
# Final cleaned and saved: puerto_rico.txt
# Final cleaned and saved: puerto_rico_convention_center.txt
# Final cleaned and saved: puerto_rico_iron_works.txt
# Final cleaned and saved: puerto_rico_museum_of_contemporary_art.txt
# Final cleaned and saved: puerto_rico_national_library.txt
# Final cleaned and saved: punta_borinquen_light.txt
# Final cleaned and saved: punta_de_las_figuras_light.txt
# Final cleaned and saved: punta_higuero_light.txt
# Final cleaned and saved: punta_mulas_light.txt
# Final cleaned and saved: punta_santiago,_humacao,_puerto_rico.txt
# Final cleaned and saved: punta_tuna_light.txt
# Final cleaned and saved: quebradillas_barrio-pueblo.txt
# Final cleaned and saved: rafael_hernández_marín.txt
# Final cleaned and saved: ramón_rivero_(diplo).txt
# Final cleaned and saved: residencia_aboy-lompré.txt
# Final cleaned and saved: residencia_armstrong-poventud.txt
# Final cleaned and saved: residencia_rosaly-batiz.txt
# Final cleaned and saved: residencia_subirá.txt
# Final cleaned and saved: rincón_barrio-pueblo.txt
# Final cleaned and saved: roberto_clemente_coliseum.txt
# Final cleaned and saved: roberto_clemente_stadium.txt
# Final cleaned and saved: roosevelt_roads_naval_station.txt
# Final cleaned and saved: rovira_biscuits_corporation.txt
# Final cleaned and saved: rum.txt
# Final cleaned and saved: rum_planetarium.txt
# Final cleaned and saved: río_abajo_state_forest.txt
# Final cleaned and saved: río_grande_barrio-pueblo.txt
# Final cleaned and saved: río_grande_de_loíza.txt
# Final cleaned and saved: río_matón_bridge.txt
# Final cleaned and saved: río_piedras_bridge.txt
# Final cleaned and saved: sabana_grande_barrio-pueblo.txt
# Final cleaned and saved: sabana_grande_masonic_cemetery.txt
# Final cleaned and saved: saint_john's_school_(san_juan).txt
# Final cleaned and saved: saliente_river.txt
# Final cleaned and saved: salinas_barrio-pueblo.txt
# Final cleaned and saved: samuel_morse.txt
# Final cleaned and saved: santa_ana_church_(san_juan).txt
# Final cleaned and saved: santa_isabel_barrio-pueblo.txt
# Final cleaned and saved: santa_maría_magdalena_de_pazzis_cemetery.txt
# Final cleaned and saved: santurce,_san_juan,_puerto_rico.txt
# Final cleaned and saved: san_cristóbal_canyon.txt
# Final cleaned and saved: san_germán_historic_district.txt
# Final cleaned and saved: san_josé_church.txt
# Final cleaned and saved: san_juan_botanical_garden.txt
# Final cleaned and saved: san_juan_city_hall.txt
# Final cleaned and saved: san_juan_marriott_resort_&_stellaris_casino.txt
# Final cleaned and saved: san_juan_natatorium.txt
# Final cleaned and saved: san_juan_puerto_rico_temple.txt
# Final cleaned and saved: san_lorenzo_barrio-pueblo.txt
# Final cleaned and saved: san_miguel_arcángel_church_(cabo_rojo).txt
# Final cleaned and saved: san_patricio_plaza.txt
# Final cleaned and saved: san_patricio_state_forest.txt
# Final cleaned and saved: san_sebastián_barrio-pueblo.txt
# Final cleaned and saved: school_of_tropical_medicine_(puerto_rico).txt
# Final cleaned and saved: sixto_escobar.txt
# Final cleaned and saved: stud_farm.txt
# Final cleaned and saved: supreme_court_building_(puerto_rico).txt
# Final cleaned and saved: susúa_state_forest.txt
# Final cleaned and saved: t-mobile_district.txt
# Final cleaned and saved: teatro_fox_delicias.txt
# Final cleaned and saved: teatro_la_perla.txt
# Final cleaned and saved: teatro_tapia.txt
# Final cleaned and saved: teatro_yagüez.txt
# Final cleaned and saved: teodoro_moscoso_bridge.txt
# Final cleaned and saved: the_mall_of_san_juan.txt
# Final cleaned and saved: tito_puente_amphitheatre.txt
# Final cleaned and saved: toa_alta_barrio-pueblo.txt
# Final cleaned and saved: toa_baja_barrio-pueblo.txt
# Final cleaned and saved: toro_negro_state_forest.txt
# Final cleaned and saved: tortuguero_lagoon.txt
# Final cleaned and saved: train_of_the_south.txt
# Final cleaned and saved: trujillo_alto_barrio-pueblo.txt
# Final cleaned and saved: u.s._custom_house_(san_juan,_puerto_rico).txt
# Final cleaned and saved: u.s._post_office_and_courthouse_(mayagüez,_puerto_rico).txt
# Final cleaned and saved: united_states_customs_house_(fajardo,_puerto_rico).txt
# Final cleaned and saved: united_states_customs_house_(ponce,_puerto_rico).txt
# Final cleaned and saved: united_states_district_court_for_the_district_of_puerto_rico.txt
# Final cleaned and saved: universidad_del_sagrado_corazón.txt
# Final cleaned and saved: university_gardens_high_school.txt
# Final cleaned and saved: university_high_school_(san_juan).txt
# Final cleaned and saved: university_of_puerto_rico,_medical_sciences_campus.txt
# Final cleaned and saved: university_of_puerto_rico,_río_piedras_campus.txt
# Final cleaned and saved: university_of_puerto_rico_at_cayey.txt
# Final cleaned and saved: university_of_puerto_rico_at_humacao.txt
# Final cleaned and saved: university_of_puerto_rico_at_mayagüez.txt
# Final cleaned and saved: university_of_puerto_rico_at_ponce.txt
# Final cleaned and saved: university_of_puerto_rico_school_of_medicine.txt
# Final cleaned and saved: uss_killen_(dd-593).txt
# Final cleaned and saved: utuado_barrio-pueblo.txt
# Final cleaned and saved: vega_alta_barrio-pueblo.txt
# Final cleaned and saved: vega_baja_barrio-pueblo.txt
# Final cleaned and saved: vega_state_forest.txt
# Final cleaned and saved: vieques_national_wildlife_refuge.txt
# Final cleaned and saved: villalba,_puerto_rico.txt
# Final cleaned and saved: villalba_barrio-pueblo.txt
# Final cleaned and saved: villa_pesquera.txt
# Final cleaned and saved: west_indian_manatee.txt
# Final cleaned and saved: whale_watching.txt
# Final cleaned and saved: william_miranda_marín_botanical_and_cultural_garden.txt
# Final cleaned and saved: world_war_ii.txt
# Final cleaned and saved: yabucoa_barrio-pueblo.txt
# Final cleaned and saved: yauco_barrio-pueblo.txt
# Final cleaned and saved: zona_historica_de_ponce.txt
